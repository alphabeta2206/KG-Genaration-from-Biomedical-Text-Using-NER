# %%
import spacy
import scispacy
import deplacy
from spacy import displacy
import stanza
import re
import pandas as pd
from scispacy.abbreviation import AbbreviationDetector
from scispacy.hyponym_detector import HyponymDetector
from spacy.matcher import Matcher
import matplotlib.pyplot as plt
import networkx as nx

# %%
#loading the data
with open ("/Users/abhinavshinow/Documents/GitHub/KG-Genaration-from-Biomedical-Text-Using-NER/Data_Collection/heart_basic-data.txt","r") as f:
    text=f.read().replace("\n\n"," ").replace("\n"," ")
text=text[:100000]

# %%
len(text)
# Out:
# 100000

# %%
#loading the scispacy core model
nlp_core = spacy.load("en_core_sci_lg")
nlp_core.add_pipe("abbreviation_detector")
nlp_core.add_pipe("hyponym_detector", last=True, config={"extended": False})

#loading the scispacy ner models
nlp_jnlpba = spacy.load('en_ner_jnlpba_md')
nlp_craft = spacy.load('en_ner_craft_md')
nlp_bionlp = spacy.load('en_ner_bionlp13cg_md')
nlp_bc5cdr = spacy.load('en_ner_bc5cdr_md')

#loading the stanza model
nlp_stanza = stanza.Pipeline('en', package='mimic', processors={'ner': 'i2b2'})
# Out:
# 2021-12-11 07:40:47 INFO: Loading these models for language: en (English):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | mimic   |
# | pos       | mimic   |
# | lemma     | mimic   |
# | depparse  | mimic   |
# | ner       | i2b2    |
# =======================
#
# 2021-12-11 07:40:47 INFO: Use device: cpu
# 2021-12-11 07:40:47 INFO: Loading: tokenize
# 2021-12-11 07:40:47 INFO: Loading: pos
# 2021-12-11 07:40:47 INFO: Loading: lemma
# 2021-12-11 07:40:47 INFO: Loading: depparse
# 2021-12-11 07:40:48 INFO: Loading: ner
# 2021-12-11 07:40:48 INFO: Done loading processors!

# %%
nlp_core.pipe_labels['ner']
# Out:
# ['ENTITY']

# %%
doc=nlp_core(text)

# %%
for ent in doc.ents:
    print(ent)
# Out:
# heart
# muscular organ
# animals
# pumps blood
# blood vessels
# circulatory system
# pumped blood carries oxygen
# nutrients
# body
# metabolic
# waste
# carbon dioxide
# lungs
# humans
# heart
# size
# closed fist
# lungs
# middle compartment
# chest
# humans
# mammals
# birds
# heart
# chambers
# upper left
# right atria
# lower left
# right ventricles
# right atrium
# ventricle
# right heart
# left counterparts
# left heart
# Fish
# chambers
# atrium
# ventricle
# reptiles
# chambers
# healthy
# heart blood
# heart
# heart valves
# prevent
# backflow
# heart
# enclosed
# protective sac
# pericardium
# amount
# fluid
# heart
# layers
# epicardium
# myocardium
# endocardium
# heart pumps
# blood
# rhythm
# group
# pacemaker cells
# sinoatrial node
# contraction
# heart
# traveling
# atrioventricular node
# conduction system
# heart
# heart
# blood low
# oxygen
# systemic
# circulation
# right atrium
# superior
# inferior venae cavae
# right ventricle
# pumped
# pulmonary circulation
# lungs
# oxygen
# carbon dioxide
# Oxygenated blood
# left atrium
# left ventricle
# aorta
# systemic
# circulation−where the oxygen
# metabolized
# carbon dioxide
# heart beats
# resting rate
# beats
# Exercise
# increases
# rate
# resting heart rate
# long term
# heart health
# Cardiovascular diseases
# CVD
# death
# deaths
# coronary artery disease
# stroke
# Risk factors
# smoking
# overweight
# exercise
# veins
# superior
# inferior venae cavae
# amount
# blood
# coronary circulation
# drains
# right atrium
# coronary sinus
# opening
# inferior vena cava
# right atrium
# oval-shaped depression
# fossa ovalis
# remnant
# opening
# fetal heart
# foramen ovale
# internal surface
# right atrium
# smooth
# depression
# fossa ovalis
# medial
# anterior
# surface
# ridges
# pectinate muscles
# right atrial appendage
# right atrium
# right ventricle
# tricuspid valve
# walls
# right ventricle
# trabeculae
# carneae
# ridges
# cardiac muscle
# endocardium
# muscular
# ridges
# cardiac muscle
# endocardium
# moderator
# thin walls
# right ventricle
# cardiac conduction
# interventricular septum
# crosses
# interior space
# right ventricle
# inferior papillary muscle
# right ventricle tapers
# pulmonary trunk
# blood
# contracting
# pulmonary trunk branches
# left
# right pulmonary arteries
# blood
# lung
# pulmonary valve
# right heart
# pulmonary trunk
# Left heart
# left heart
# chambers
# left atrium
# left ventricle
# mitral valve
# left atrium
# oxygenated blood back
# lungs
# pulmonary veins
# left atrium
# outpouching
# left atrial appendage
# right atrium
# left atrium
# pectinate muscles
# left atrium
# left ventricle
# mitral valve
# left ventricle
# thicker
# right
# force
# pump
# blood
# entire body
# right ventricle
# left
# trabeculae
# carneae
# left ventricle pumps
# body
# aortic valve
# aorta
# openings
# aortic valve
# blood
# heart muscle
# left coronary artery
# left cusp
# valve
# right coronary artery
# right cusp
# heart wall
# layers
# inner endocardium
# middle myocardium
# outer
# epicardium
# surrounded
# double-membraned sac
# pericardium
# innermost layer
# heart
# endocardium
# lining
# squamous epithelium
# heart chambers
# valves
# continuous
# endothelium
# veins
# arteries
# heart
# myocardium
# layer
# connective tissue
# endocardium
# secreting
# endothelins
# regulating
# contraction
# myocardium
# middle layer
# heart wall
# myocardium
# cardiac muscle
# layer
# involuntary
# striated muscle
# surrounded
# framework
# collagen
# cardiac muscle
# elegant
# complex
# muscle cells
# swirl
# spiral
# chambers
# heart
# outer muscles
# pattern
# atria
# bases
# vessels
# inner muscles
# ventricles
# apex
# complex
# heart
# pump
# blood
# effectively
# cells
# cardiac muscle
# muscle cells
# contract
# pacemaker cells
# conducting system
# muscle cells
# cells
# atria
# ventricles
# contractile cells
# intercalated
# discs
# response
# impulses
# action
# potential
# pacemaker cells
# intercalated
# discs
# cells
# syncytium
# contractions
# pump
# blood
# heart
# arteries
# pacemaker cells
# cells
# conduction system
# heart
# contractile cells
# myofibrils
# contractibility
# function
# neurons
# Cardiac muscle
# autorhythmicity
# initiate
# cardiac action
# potential
# fixed rate
# spreading
# impulse
# cell
# cell
# contraction
# entire heart
# proteins
# expressed
# cardiac muscle cells
# associated with
# muscle contraction
# bind
# actin
# myosin
# tropomyosin
# troponin
# MYH6
# ACTC1
# TNNI3
# CDH2
# PKP2
# proteins
# expressed
# MYH7
# LDB3
# expressed
# skeletal muscle
# Pericardium
# pericardium
# sac
# heart
# outer
# surface
# pericardium
# fibrous membrane
# double inner membrane
# serous membrane
# pericardial fluid
# lubricate
# surface
# heart
# serous membrane
# fibrous membrane
# parietal pericardium
# serous membrane
# heart
# visceral pericardium
# pericardium
# lubricate
# movement
# structures
# chest
# heart's
# stabilised
# chest
# heart
# infection
# Coronary circulation
# Heart tissue
# cells
# body
# oxygen
# nutrients
# metabolic
# wastes
# coronary circulation
# arteries
# veins
# lymphatic vessels
# Blood flow
# coronary vessels
# peaks
# troughs
# heart muscle's
# relaxation
# contraction
# Heart tissue
# blood
# arteries
# aortic valve
# left main coronary artery
# right coronary artery
# aorta
# vessels
# left anterior descending
# left circumflex artery
# left anterior descending artery supplies
# heart tissue
# front
# outer side
# septum
# left ventricle
# branching
# arteries
# diagonal
# septal branches
# left circumflex
# supplies
# back
# underneath
# left ventricle
# right coronary artery supplies
# right atrium
# right ventricle
# sections
# left ventricle
# right coronary artery
# supplies
# blood
# atrioventricular node
# people
# sinoatrial node
# people
# right coronary artery runs
# groove
# heart
# left anterior descending artery runs
# groove
# front
# variation
# people
# anatomy
# arteries
# supply
# heart
# arteries
# branches
# edges
# arterial
# distribution
# coronary sinus
# vein
# drains
# right atrium
# venous drainage
# heart
# blood
# cardiac vein
# left atrium
# ventricles
# posterior cardiac vein
# draining
# left ventricle
# middle cardiac vein
# draining
# left
# right ventricles
# small cardiac veins
# anterior
# cardiac veins
# drain
# right ventricle
# drain
# right atrium
# lymphatic networks
# plexuses
# layers
# heart
# networks
# left
# right trunk
# travel
# groove
# ventricles
# heart's
# surface
# vessels
# travel
# vessels
# travel
# atrioventricular groove
# third vessel
# drains
# section
# left ventricle sitting
# diaphragm
# left vessel
# third vessel
# pulmonary artery
# left atrium
# inferior tracheobronchial node
# right vessel
# right atrium
# right ventricle sitting
# diaphragm
# ascending aorta
# ends
# brachiocephalic node
# Nerve
# supply
# heart
# signals
# vagus nerve
# nerves
# sympathetic trunk
# nerves
# influence
# heart rate
# Sympathetic nerves
# influence
# force
# heart contraction
# Signals
# travel
# nerves
# cardiovascular centres
# medulla oblongata
# vagus nerve
# parasympathetic nervous system
# decrease
# heart rate
# nerves
# sympathetic trunk
# increase
# heart rate
# nerves
# network
# nerves
# heart
# cardiac plexus
# vagus nerve
# wandering nerve
# brainstem
# parasympathetic stimulation
# organs
# thorax
# abdomen
# heart
# nerves
# sympathetic trunk
# emerge
# T1-T4 thoracic ganglia
# travel
# sinoatrial
# atrioventricular nodes
# atria
# ventricles
# ventricles
# richly
# innervated
# sympathetic fibers
# parasympathetic fibers
# Sympathetic stimulation
# release
# neurotransmitter
# norepinephrine
# noradrenaline
# neuromuscular junction
# cardiac nerves
# repolarization
# period
# rate
# depolarization
# contraction
# results
# increased
# heart rate
# chemical
# ligand-gated sodium
# calcium ion channels
# influx
# positively charged ions
# Norepinephrine
# binds
# beta–1 receptor
# Development
# heart
# functional
# organ
# beat
# pump
# blood
# weeks
# embryogenesis
# early
# embryonic
# prenatal development
# heart
# splanchnopleuric mesenchyme
# neural plate
# cardiogenic region
# endocardial tubes
# fuse
# primitive
# heart tube
# tubular heart
# week
# heart tube
# lengthens
# S-shape
# pericardium
# chambers
# vessels
# correct
# alignment
# heart
# development
# formation
# septa
# valves
# remodeling
# heart chambers
# week
# ventricles
# mitral
# tricuspid valves
# open
# cycle
# Cardiac output
# Cardiac output
# CO
# measurement
# amount
# blood pumped
# ventricle
# stroke
# volume
# minute
# multiplying
# stroke
# volume
# SV
# beats
# heart rate
# HR
# CO
# SV
# HR
# cardiac output
# body size
# body surface area
# cardiac index
# average
# cardiac output
# average
# stroke
# volume
# stroke
# volume
# measured
# echocardiogram
# influenced
# size
# heart
# physical
# mental condition
# individual
# sex
# contractility
# duration
# contraction
# preload
# afterload
# Preload
# filling pressure
# atria
# diastole
# ventricles
# ventricles
# ventricles
# contract
# preload
# Preload
# affected
# person's
# blood volume
# force
# contraction
# heart muscle
# proportional
# preload
# Frank-Starling
# mechanism
# states
# force
# contraction
# proportional
# length
# muscle fiber
# ventricle
# contract
# stretched
# Afterload
# pressure
# heart
# blood
# systole
# vascular resistance
# influenced
# narrowing
# heart valves
# stenosis
# contraction
# relaxation
# peripheral blood vessels
# strength
# heart muscle
# contractions
# stroke
# volume
# influenced
# positively
# negatively
# agents
# inotropes
# agents
# changes
# body
# drugs
# treatment
# medical disorder
# life support
# intensive care units
# Inotropes
# increase
# force
# contraction
# positive
# inotropes
# sympathetic agents
# adrenaline
# noradrenaline
# dopamine
# Negative
# inotropes
# decrease
# force
# contraction
# calcium channel blockers
# Electrical conduction
# normal rhythmical heart beat
# sinus rhythm
# heart's
# pacemaker
# sinoatrial node
# sinus node
# SA
# node
# electrical signal
# heart
# heart muscle
# contract
# sinoatrial node
# upper part
# right atrium
# junction
# superior vena cava
# electrical signal
# sinoatrial node
# right atrium
# radial
# left atrium
# Bachmann's bundle
# muscles
# left
# right atria
# contract
# signal
# atrioventricular node
# right atrium
# atrioventricular septum
# right atrium
# left ventricle
# septum
# cardiac skeleton
# tissue
# heart
# electrical signal
# forces
# signal
# atrioventricular node
# signal
# bundle
# right bundle branches
# ventricles
# heart
# ventricles
# signal
# specialized tissue
# Purkinje fibers
# transmit
# electric charge
# heart muscle
# Heart rate
# normal resting heart rate
# sinus rhythm
# sustained
# sinoatrial node
# group
# pacemaking cells
# wall
# right atrium
# Cells
# sinoatrial node
# action
# potential
# cardiac action
# potential
# movement
# electrolytes
# pacemaker cells
# action
# potential
# spreads
# nearby cells
# sinoatrial cells
# resting
# negative
# membranes
# influx
# sodium ions
# membrane's charge
# positive
# depolarisation
# spontaneously
# cell
# sodium channels
# calcium ions
# cell
# potassium
# ions
# travel
# ion channels
# membrane
# sinoatrial cells
# potassium
# calcium
# cell
# voltage-gated
# calcium channels
# potassium channels open
# potassium
# cell
# cell
# negative
# repolarization
# membrane
# potential
# −60 mV
# potassium channels
# process
# ions
# areas
# sodium
# cell
# outside
# potassium
# cell
# cell
# Calcium
# influx
# slow channels
# sinoatrial cells
# prolonged
# plateau
# phase
# positive charge
# absolute
# refractory
# period
# Calcium ions
# regulatory protein troponin C
# troponin complex
# contraction
# cardiac muscle
# protein
# relaxation
# adult
# resting heart rate ranges
# bpm
# resting heart rate
# newborn
# beats
# bpm
# decreases
# maturity
# athlete's
# heart rate
# bpm
# exercise
# rate
# maximum
# rates
# bpm
# Influences
# normal sinus rhythm
# heart
# resting heart rate
# factors
# cardiovascular centres
# brainstem control
# sympathetic
# parasympathetic
# influences
# heart
# vagus nerve
# sympathetic trunk
# cardiovascular centres
# receptors
# baroreceptors
# sensing stretch
# stretching
# blood vessels
# chemoreceptors
# sensing
# amount
# oxygen
# carbon dioxide
# blood
# pH.
# reflexes
# regulate
# sustain
# blood flow
# Baroreceptors
# stretch receptors
# aortic sinus
# carotid bodies
# venae cavae
# locations
# pulmonary vessels
# right side
# heart
# Baroreceptors
# fire
# rate
# stretched
# influenced
# blood pressure
# level
# physical activity
# distribution
# blood
# increased
# pressure
# stretch
# rate
# baroreceptor
# firing
# increases
# cardiac centers
# decrease
# sympathetic stimulation
# increase
# parasympathetic stimulation
# pressure
# stretch
# decrease
# rate
# baroreceptor
# firing
# decreases
# cardiac centers
# increase
# sympathetic stimulation
# decrease
# parasympathetic stimulation
# reflex
# atrial reflex
# Bainbridge reflex
# associated with
# rates
# blood flow
# atria
# Increased
# venous return stretches
# walls
# atria
# specialized baroreceptors
# atrial baroreceptors
# increase
# rate
# firing
# stretch
# increased
# blood pressure
# cardiac center
# sympathetic stimulation
# inhibiting
# parasympathetic stimulation
# increase
# heart rate
# Chemoreceptors
# carotid body
# adjacent
# aorta
# aortic body
# blood's oxygen
# carbon dioxide
# levels
# Low oxygen
# stimulate
# firing
# receptors
# Exercise
# fitness
# levels
# age
# body temperature
# basal
# metabolic
# rate
# person's
# emotional state
# heart rate
# levels
# hormones
# epinephrine
# norepinephrine
# thyroid hormones
# increase
# heart rate
# levels
# electrolytes
# calcium
# potassium
# sodium
# influence
# speed
# regularity
# heart rate
# low blood oxygen
# low blood pressure
# dehydration
# increase
# Clinical significance Diseases
# Cardiovascular diseases
# diseases
# heart
# death
# worldwide
# cardiovascular disease
# noncommunicable
# lifestyle
# factors
# prevalent
# ageing
# Heart disease
# death
# average
# deaths
# rate
# high-income countries
# Doctors
# heart
# cardiologists
# medical professionals
# treating
# diseases
# heart
# doctors
# cardiothoracic surgeons
# intensivists
# allied health practitioners
# physiotherapists
# dieticians
# Ischaemic heart disease
# Coronary artery disease
# ischaemic heart disease
# atherosclerosis
# build-up
# fatty material
# inner walls
# arteries
# fatty deposits
# atherosclerotic
# plaques
# narrow
# coronary arteries
# severe
# reduce
# blood flow
# heart
# narrowing
# stenosis
# patient
# symptoms
# Severe
# narrowings
# chest pain
# angina
# breathlessness
# exercise
# rest
# atherosclerotic plaque
# rupture
# fatty centre
# circulating blood
# clot
# thrombus
# blocking
# artery
# restricting
# blood flow
# area
# heart muscle
# myocardial infarction
# heart attack
# unstable angina
# case
# cardiac arrest
# sudden
# utter loss
# output
# heart
# Obesity
# high blood pressure
# uncontrolled
# diabetes
# smoking
# high cholesterol
# increase
# risk
# atherosclerosis
# coronary artery disease
# Heart failure
# Heart failure
# condition
# heart
# pump
# blood
# demands
# body
# Patients
# heart failure
# breathlessness
# flat
# ankle swelling
# peripheral oedema
# Heart failure
# diseases
# affecting
# heart
# associated with
# ischaemic heart disease
# valvular heart disease
# high blood pressure
# cardiomyopathies
# Heart failure
# associated with
# weakness
# heart muscle
# ventricles
# systolic heart failure
# patients
# heart muscle
# stiff
# diastolic heart failure
# condition
# left ventricle
# breathlessness
# right ventricle
# swelling
# legs
# elevated
# jugular
# venous pressure
# ventricles
# Patients
# heart failure
# risk
# heart rhythm
# disturbances
# arrhythmias
# Cardiomyopathies Cardiomyopathies
# diseases
# affecting
# muscle
# heart
# abnormal
# thickening
# heart muscle
# hypertrophic cardiomyopathy
# heart
# dilated cardiomyopathy
# heart muscle
# stiff
# contractions
# restrictive cardiomyopathy
# heart
# abnormal
# arrhythmogenic cardiomyopathy
# conditions
# genetic
# inherited
# dilated cardiomyopathy
# damage
# toxins
# alcohol
# cardiomyopathies
# hypertrophic cardiomopathy
# risk
# sudden cardiac death
# athletes
# cardiomyopathies
# heart failure
# stages
# disease
# Valvular heart disease
# Healthy heart valves
# blood
# flow
# direction
# prevent
# flowing
# direction
# Diseased heart valves
# opening
# flow
# blood
# forward direction
# stenotic valve
# blood
# leak
# reverse direction
# valvular regurgitation
# Valvular heart disease
# breathlessness
# blackouts
# chest pain
# asymptomatic
# detected
# routine
# examination
# hearing
# abnormal
# heart sounds
# heart murmur
# valvular heart disease
# degeneration
# secondary to old age
# infection
# heart valves
# endocarditis
# parts
# world
# rheumatic heart disease
# valvular heart disease
# mitral
# aortic stenosis
# body's
# immune system
# streptococcal throat infection
# Cardiac arrhythmias
# healthy heart
# waves
# electrical impulses
# sinus node
# spreading
# atria
# atrioventricular node
# ventricles
# normal sinus rhythm
# normal rhythm
# disrupted
# Abnormal
# heart rhythms
# arrhythmias
# asymptomatic
# palpitations
# blackouts
# breathlessness
# arrhythmia
# atrial fibrillation
# increase
# long term
# risk
# stroke
# arrhythmias
# heart
# beat
# bradycardia
# bradyarrhythmia
# damage
# cardiac conduction system
# heart block
# arrhythmias
# heart
# beat
# abnormally
# tachycardia
# tachyarrhythmia
# arrhythmias
# structures
# heart
# atria
# atrial flutter
# atrioventricular node
# AV nodal re-entrant tachycardia
# ventricles
# ventricular tachycardia
# tachyarrhythmias
# scarring
# heart
# ventricular tachycardia
# irritable focus
# focal atrial tachycardia
# abnormal
# conduction tissue
# birth
# Wolff-Parkinson-White syndrome
# heart racing
# ventricular fibrillation
# ventricles
# quiver
# contract
# untreated
# fatal
# Pericardial disease
# sac
# heart
# pericardium
# inflamed
# condition
# pericarditis
# condition
# chest pain
# spread
# back
# viral infection
# glandular fever
# cytomegalovirus
# coxsackievirus
# Fluid
# pericardial sac
# pericardial effusion
# Pericardial effusions
# secondary to
# pericarditis
# kidney failure
# tumours
# symptoms
# effusions
# effusions
# accumulate
# compress
# heart
# condition
# cardiac tamponade
# breathlessness
# fatal
# low blood pressure
# Fluid
# removed
# pericardial space
# diagnosis
# tamponade
# syringe
# procedure
# pericardiocentesis
# Congenital heart disease
# people
# born
# hearts
# abnormal
# abnormalities
# congenital heart defects
# minor
# patent foramen ovale
# variant
# normal
# life-threatening abnormalities
# hypoplastic left heart syndrome
# abnormalities
# heart muscle
# heart
# heart
# ventricular septal defect
# defects
# affecting
# heart valves
# congenital aortic stenosis
# blood vessels
# heart
# coarctation
# aorta
# complex syndromes
# heart
# Tetralogy
# Fallot
# congenital heart defects
# blood
# low
# oxygen
# lungs
# pumped back
# body
# cyanotic congenital heart defects
# serious
# congenital heart defects
# childhood
# birth
# child
# born
# transposition
# arteries
# breathlessness
# rate
# growth
# congenital heart disease
# years
# adult
# life
# atrial septal defect
# Diagnosis Heart disease
# diagnosed
# medical history
# cardiac examination
# investigations
# blood tests
# echocardiograms
# ECGs
# imaging
# invasive procedures
# cardiac catheterisation
# Examination
# cardiac examination
# inspection
# feeling
# chest
# hands
# palpation
# listening
# stethoscope
# auscultation
# assessment
# signs
# person's hands
# splinter haemorrhages
# joints
# person's
# pulse
# radial artery
# wrist
# assess
# rhythm
# strength
# pulse
# blood pressure
# manual
# automatic sphygmomanometer
# invasive
# measurement
# artery
# elevation
# jugular
# venous pulse
# person's
# chest
# transmitted
# vibrations
# heart
# listened
# stethoscope
# Heart sounds
# healthy
# hearts
# audible
# heart sounds
# S1
# S2
# heart sound S1
# sound
# closing
# atrioventricular valves
# ventricular contraction
# heart sound
# S2
# sound
# semilunar valves
# closing
# ventricular diastole
# sound
# components
# valves
# S2
# sounds
# inspiration
# valvular
# cardiac problems
# heart sounds
# gallop rhythms
# third heart sound
# S3
# increase
# ventricular blood volume
# atrial gallop
# sound
# forced
# stiff ventricle
# presence
# S3
# quadruple gallop
# Heart murmurs
# abnormal
# heart sounds
# disease
# benign
# heart sounds
# abnormal
# heart sounds
# extra sounds
# murmurs
# flow
# blood
# sounds
# Murmurs
# volume
# quietest
# loudest
# evaluated
# relationship
# heart sounds
# position
# cardiac cycle
# features
# radiation
# sites
# changes
# person's
# position
# frequency
# sound
# stethoscope
# site
# Murmurs
# damaged
# heart valves
# congenital heart disease
# ventricular septal defects
# normal
# hearts
# pericardial friction rub
# cases
# pericarditis
# inflamed
# membranes
# rub
# Blood tests
# Blood tests
# diagnosis
# treatment
# cardiovascular conditions
# Troponin
# sensitive
# biomarker
# heart
# insufficient
# blood supply
# 4–6 hours
# injury
# peaks
# hours
# tests
# troponin
# time
# initial
# presentation
# 3–6
# hours
# level
# significant
# diagnostic
# brain natriuretic peptide
# BNP
# evaluate
# presence
# heart failure
# rises
# increased
# left ventricle
# tests
# biomarkers
# cardiac disease
# Testing
# MB
# creatine kinase
# information
# heart's
# blood supply
# specific
# sensitive
# blood tests
# person's
# general health
# risk factors
# heart disease
# investigating
# anaemia
# metabolic panel
# disturbances
# electrolytes
# coagulation
# right level
# anticoagulation
# Fasting
# lipids
# fasting blood glucose
# HbA1c
# level
# evaluate
# person's
# cholesterol
# diabetes status
# Electrocardiogram
# surface
# electrodes
# body
# record
# electrical activity
# heart
# electrical signal
# electrocardiogram
# ECG
# EKG
# ECG
# bedside test
# placement
# body
# ECG
# calculated
# ground).There
# features
# ECG
# P wave
# atrial depolarisation
# QRS complex
# ventricular depolarisation
# T wave
# ventricular repolarisation
# heart cells
# contract
# heart
# downward deflection
# ECG
# cells
# positive
# charge
# direction
# inflection
# cells
# negative
# repolarising
# direction
# position
# lead
# wave
# moved
# left
# negative deflection
# right
# positive deflection
# ECG
# tool
# detecting
# rhythm
# disturbances
# insufficient
# blood supply
# heart
# abnormalities
# suspected
# visible
# ECG
# Testing
# exercising
# abnormality
# ECG
# worn
# period
# 24-hour Holter
# monitor
# suspected
# rhythm
# abnormality
# time
# assessment
# Imaging
# imaging methods
# assess
# anatomy
# function
# heart
# ultrasound (echocardiography
# angiography
# CT scans
# MRI
# PET
# echocardiogram
# ultrasound
# heart
# measure
# heart's function
# assess
# valve disease
# abnormalities
# Echocardiography
# probe
# chest
# transthoracic
# probe
# esophagus
# transoesophageal
# echocardiography
# report
# information
# width
# valves
# stenosis
# backflow of blood
# regurgitation
# information
# blood volumes
# systole
# diastole
# ejection fraction
# blood
# ejected
# left
# right ventricles
# systole
# Ejection fraction
# dividing
# volume
# ejected
# heart
# stroke
# volume
# volume
# filled heart
# end-diastolic volume
# Echocardiograms
# body
# stressed
# signs
# lack
# blood supply
# cardiac stress test
# exercise
# injection
# drug
# dobutamine
# CT scans
# chest X-rays
# imaging
# evaluate
# heart's
# size
# evaluate
# signs
# pulmonary oedema
# fluid
# heart
# evaluating
# aorta
# blood vessel
# leaves
# heart
# Treatment Diseases
# affecting
# heart
# treated
# methods
# lifestyle
# modification
# drug treatment
# surgery
# Ischaemic heart disease
# Narrowings
# coronary arteries
# ischaemic heart disease
# treated
# symptoms
# chest pain
# angina pectoris
# heart muscle
# damage
# artery
# myocardial infarction
# prevent
# myocardial infarction
# occurring
# Medications
# angina
# symptoms
# nitroglycerin
# beta blockers
# calcium channel blockers
# preventative
# treatments
# antiplatelets
# aspirin
# statins
# lifestyle
# measures
# smoking
# weight loss
# treatment
# risk factors
# high blood pressure
# diabetes
# medications
# heart arteries
# treated
# narrowings
# flow
# blood
# bypass
# obstruction
# percutaneous coronary intervention
# narrowings
# coronary arteries
# inflating
# balloon
# narrowing
# metal
# scaffold
# stent
# artery open
# narrowings
# coronary arteries
# treatment
# percutaneous coronary intervention
# open surgery
# coronary artery bypass graft
# blood vessel
# body
# saphenous vein
# radial artery
# internal mammary artery
# blood
# narrowing
# aorta
# obstruction
# Valvular heart disease
# Diseased heart valves
# narrow
# abnormally
# leaky
# surgery
# damaged
# heart valve
# tissue
# metallic
# tricuspid
# mitral valves
# repaired surgically
# valve replacement
# Heart valves
# treated percutaneously
# techniques
# similarities
# percutaneous coronary intervention
# Transcatheter aortic valve replacement
# patients
# risk
# open valve replacement
# Cardiac arrhythmias
# Abnormal heart rhythms
# arrhythmias
# treated
# antiarrhythmic drugs
# flow
# electrolytes
# cell membrane
# calcium channel blockers
# sodium channel blockers
# amiodarone
# digoxin
# modify
# autonomic nervous system's
# effect
# heart
# beta blockers
# atropine
# arrhythmias
# atrial fibrillation
# increase
# risk
# stroke
# risk
# reduced
# anticoagulants
# warfarin
# oral anticoagulants
# medications
# contractile apparatus
# Cardiac
# ACTC1
# skeletal
# ACTA1
# amino acids
# Asp4Glu
# Glu5Asp
# Leu301Met
# Ser360Thr
# cardiac/skeletal
# actin monomer
# asymmetric domains
# inner domain
# sub-domains
# outer domain
# sub-domains
# amino
# carboxy-termini
# outer domain
# Function Actin
# dynamic structure
# states
# flexibility
# states
# movement
# sub-domain 2
# Myosin binding
# increases
# flexibility
# actin
# cross-linking studies
# myosin subfragment-1
# binds
# actin
# amino acid residues
# actin sub-domain 2
# effect
# ACTC1 gene
# development
# Experiments
# chick
# embryos
# association
# ACTC1
# knockdown
# reduction
# atrial septa
# Clinical significance
# Polymorphisms
# ACTC1
# Dilated Cardiomyopathy
# Japanese
# patients
# studies
# patients
# South Africa
# association
# E101K missense mutation
# associated with
# Hypertrophic Cardiomyopathy
# Left Ventricular Noncompaction
# mutation
# ACTC1 gene
# associated with
# atrial septal defects
# References
# reading
# characterization
# human
# ACTC1
# COPaKB
# GeneReviews/NIH/NCBI/UW
# entry
# Familial Hypertrophic Cardiomyopathy
# Human
# ACTC1
# genome
# location
# ACTC1 gene
# page
# UCSC Genome Browser
# Refractoriness
# object
# autowave
# nature
# excitable medium
# stimuli
# object stays
# refractory state
# refractory
# period
# recovery
# period
# associated with
# motion
# image
# left branch
# isocline                                                                u               ˙
# details
# Reaction
# diffusion
# Parabolic partial differential equation
# physiology
# refractory
# period
# period
# time
# organ
# cell
# action
# amount
# excitable membrane
# stimulus
# resting state
# excitation
# electrically excitable muscle cells
# neurons
# Absolute
# refractory
# period
# depolarization
# repolarization
# period
# hyperpolarization
# Electrochemical usage
# initiation
# action
# potential
# refractory
# period
# absolute
# refractory
# period
# duration
# action
# potential
# neurons
# inactivation
# Na+ channels
# depolarize
# membrane
# channels
# inactivated
# membrane hyperpolarizes
# channels
# de-inactivate
# regain
# response
# stimulus
# period
# absolute
# voltage-gated potassium channels
# terminate
# action
# potential
# repolarizing
# membrane
# potassium conductance
# membrane
# increases
# K+ ions
# moving
# cell
# membrane
# potential
# equilibrium
# potential
# potassium
# hyperpolarization
# membrane
# membrane
# potential
# negative
# normal resting potential
# potassium conductance
# resting value
# stimulus
# initiation
# threshold
# depolarization
# equilibrium resting potential
# period
# Cardiac refractory
# period
# refractory
# period
# cardiac physiology
# ion currents
# cardiac cells
# nerve cells
# flow
# cell freely
# flow
# ions
# change
# voltage
# inside
# cell
# extracellular space
# nerve cells
# voltage
# action
# potential
# nerve cells
# cardiac action potential
# duration
# variations
# cell type
# autonomic tone
# action
# initiates
# cardiac cell
# initiate
# action
# potential
# duration of time
# shorter
# duration
# period
# refractory
# period
# duration
# heart
# cardiac refractory
# period
# absolute
# refractory
# period
# period
# absolute
# refractory
# period
# action
# potential
# period
# action
# potential
# circumstances
# cardiac refractory
# period
# re-entry
# tachycardia
# Vortices
# excitation
# myocardium
# autowave
# vortices
# re-entry
# vortices
# mechanism
# life-threatening
# cardiac arrhythmias
# autowave reverberator
# spiral waves
# rotors
# atria
# atrial fibrillation
# Neuronal refractory
# period
# refractory
# period
# neuron
# action
# potential
# millisecond
# action
# potential
# phases
# Phase
# depolarization
# depolarization
# voltage-gated sodium ion channels open
# increasing
# neuron's
# membrane conductance
# sodium ions
# depolarizing
# cell's membrane
# potential
# mV
# positive
# potential
# words
# membrane
# negative
# potential
# activation
# threshold
# depolarization
# neuron
# overshoots
# equilibrium
# potential
# activated membrane
# Phase
# repolarization
# repolarization
# voltage-gated sodium ion channels
# inactivate
# closed state
# now-depolarized membrane
# voltage-gated potassium channels activate
# inactivation
# sodium ion channels
# opening
# potassium ion channels
# repolarize
# cell's membrane
# potential
# resting membrane potential
# cell's membrane
# resting membrane potential
# near
# cell
# phase
# hyperpolarization
# larger-than-resting potassium conductance
# cell membrane
# potassium conductance
# drops
# cell
# resting membrane potential
# refractory
# periods
# inactivation
# voltage-gated sodium channels
# potassium channels
# closing
# Voltage-gated sodium channels
# gating
# mechanisms
# activation
# mechanism
# channel
# depolarization
# inactivation
# mechanism
# channel
# repolarization
# channel
# inactive state
# response
# depolarization
# period
# sodium channels
# inactive state
# absolute
# refractory
# period
# period
# voltage-activated sodium channels
# closed
# depolarization
# voltage-gated potassium channels
# response
# repolarization
# voltage-gated sodium channels
# active closed state
# time
# potassium conductance
# membrane
# threshold
# stimulus
# action potentials
# fire
# words
# membrane
# potential
# axon
# negative
# membrane
# stronger
# stimulus
# threshold
# voltage
# initiate
# action
# potential
# period
# period
# Skeletal muscle
# period
# muscle action
# potential
# absolute
# refractory
# period
# 1–3 ms
# shorter
# cells
# References
# Books Papers
# heart beats
# rhythm set
# sinus node
# pacemaker
# nervous system
# hormones
# blood
# venous return
# amount
# blood
# heart
# nerves
# heart
# vagus nerve
# slows
# heart rate
# acetylcholine
# accelerans nerve
# speeds
# noradrenaline
# results
# increased
# bloodflow
# body
# sudden
# increase
# activity
# nerve fibres
# autonomic nervous system
# fight
# flight' system
# References
# AV-nodal reentrant tachycardia
# AVNRT
# abnormal
# supraventricular tachycardia
# SVT
# location
# heart
# bundle of His
# supraventricular tachycardia
# women
# men
# cases
# females
# symptom
# palpitations
# Treatment
# physical maneuvers
# medications
# rarely
# synchronized cardioversion
# Frequent
# attacks
# radiofrequency ablation
# tissue
# heart
# destroyed
# AVNRT
# reentrant circuit forms
# atrioventricular node
# circuit
# anatomical pathways
# fast pathway
# slow pathway
# right atrium
# slow pathway
# targeted
# ablation
# inferior
# posterior
# AV node
# anterior
# margin
# coronary sinus
# fast pathway
# superior
# posterior
# AV node
# pathways
# tissue
# behaves
# AV node
# authors
# AV node
# fast
# slow pathways
# accessory pathways
# Wolff-Parkinson-White syndrome
# WPW syndrome
# atrioventricular reciprocating tachycardia (AVRT
# AVNRT
# fast
# slow pathways
# right atrium
# AV node
# electrophysiologic
# properties
# AV
# Accessory pathways
# WPW syndrome
# AVRT
# atrioventricular valvular rings
# connection
# atria
# ventricles
# electrophysiologic
# properties
# muscular heart tissue
# heart's
# ventricles
# Signs and
# symptoms
# symptom
# AVNRT
# sudden development
# palpitations
# palpitations
# associated with
# fluttering
# sensation
# neck
# near-simultaneous
# contraction
# atria
# ventricles
# closed
# tricuspid valve
# pressure
# atrial contraction
# transmitted
# venous system
# heart rate
# feelings
# anxiety
# panic
# attacks
# cases
# fast heart
# associated with
# drop
# blood pressure
# someone
# dizziness
# rarely lose consciousness
# faint
# coronary artery disease
# narrowing
# arteries
# heart
# atherosclerosis
# heart rate
# chest pain
# angina
# pain
# pressure-like
# chest
# radiates
# left arm
# angle
# left jaw
# Symptoms
# trigger
# palpitations
# lifting heavy items
# bending forwards
# palpitations
# sudden
# acceleration
# heart rate
# heart skipping
# beat
# heart
# race
# minutes
# hours
# termination
# arrhythmia
# AVNRT
# heart rate
# beats
# inspection
# neck
# pulsation
# jugular vein
# cannon A-waves
# right atrium contracts
# closed
# Mechanisms
# mechanism
# AVNRT
# re-entrant circuit
# atrioventricular node
# AVNRT
# slow AV nodal pathway
# ventricle
# anterograde limb
# circuit
# fast AV nodal pathway
# atria
# retrograde
# limb
# re-entrant circuit
# reversed
# fast AV nodal pathway
# anterograde limb
# slow AV nodal pathway
# retrograde
# limb
# atypical
# AVNRT
# Atypical AVNRT
# slow AV nodal pathway
# anterograde limb
# left atrial fibres
# AV node
# left side
# inter-atrial septum
# retrograde
# limb
# AVNRT
# AVNRT
# AVNRT
# anterograde
# conduction
# slow pathway
# retrograde
# conduction
# fast pathway
# retrograde
# conduction
# fast pathway
# stimulation
# atria
# inverted P wave
# stimulation
# ventricles
# QRS complex
# result
# time
# QRS complex
# P wave
# RP interval
# time
# consecutive
# QRS complexes
# RP
# interval
# inverted P waves
# surface electrocardiogram
# ECG
# buried
# QRS complexes
# lead V1
# inferior
# Atypical
# AVNRT
# atypical
# AVNRT
# anterograde
# conduction
# fast pathway
# retrograde
# conduction
# slow pathway
# AVNRT).Multiple slow pathways
# anterograde
# retrograde
# conduction
# slow pathways
# retrograde
# conduction
# slow pathway
# stimulation
# atria
# delayed
# slow conduction tissue
# inverted P wave
# falls
# QRS complex
# surface
# ECG
# Diagnosis
# symptoms
# person
# medical care
# emergency department
# ECG
# changes
# confirm
# diagnosis
# QRS duration
# heart block
# suspected
# palpitations
# recurrent
# doctor
# Holter monitor
# portable
# wearable ECG recorder
# diagnosis
# recorder
# time
# symptoms
# cases
# disabling
# infrequent
# episodes
# palpitations
# insertion
# small device
# skin
# record
# heart activity
# implantable loop recorder
# ECG-based
# technologies
# AVNRT
# abnormal
# fast heart rhythms
# atrial fibrillation
# atrial flutter
# sinus tachycardia
# ventricular tachycardia
# tachyarrhythmias
# Wolff-Parkinson-White syndrome
# symptoms
# AVNRT.Blood tests
# people
# palpitations
# thyroid function tests
# TFTs
# overactive thyroid
# increases
# risk
# AVNRT
# electrolytes
# disturbances
# potassium
# calcium
# magnesium
# AVNRT
# cardiac
# markers
# –
# myocardial infarction
# heart attack
# cause
# AVNRT
# case
# patient
# chest pain
# Treatment
# Treatments
# AVNRT
# episodes
# tachycardia
# prevent
# episodes
# future
# treatments
# physical manoeuvres
# medication
# invasive procedures
# ablation
# Arrhythmia
# termination
# episode
# supraventricular tachycardia
# AVNRT
# action
# transiently blocks
# AV node
# AVNRT
# stop
# attack
# physical manoeuvres
# increase
# activity
# vagus nerve
# heart
# atrioventricular node
# manoeuvres
# carotid sinus massage
# pressure
# carotid sinus
# neck
# Valsalva manoeuvre
# increasing
# pressure
# chest
# exhale
# closed
# airway
# breath).Medications
# slow
# electrical conduction
# AV node
# AVNRT
# adenosine
# beta blockers
# non-dihydropyridine calcium channel blockers
# verapamil
# diltiazem
# adenosine
# beta blockers
# airways
# caution
# people
# asthma
# drugs
# antiarrhythmic drugs
# flecainide
# amiodarone
# fast heart rate
# tolerated
# development
# heart failure
# symptoms
# low blood pressure
# coma
# AVNRT
# electrically
# cardioversion
# procedure
# administering
# sedative
# general anaesthetic
# electric shock
# heart
# normal rhythm
# Arrhythmia
# prevention
# preventative
# treatment
# unpleasant
# symptoms
# associated with
# AVNRT
# arrhythmia
# benign condition
# preventative
# treatment
# treatment
# asymptomatic
# treatment
# long term
# antiarrhythmic medication
# drugs
# calcium channel antagonists
# beta blockers
# flecainide
# amiodarone
# digoxin
# drugs
# effective
# preventing
# episodes
# long term
# invasive procedure
# electrophysiology
# EP
# study
# catheter ablation
# confirm
# diagnosis
# cure
# procedure
# wires
# catheters
# heart
# vein
# leg
# tip
# catheters
# heat
# freeze
# slow pathway
# AV node
# electrical impulses
# preventing
# AVNRT
# risks
# benefits
# weighed
# Catheter ablation
# slow pathway
# cure
# AVNRT
# success rates
# small risk
# complications
# AV node
# pacemaker
# External links
# Angiotensin-converting-enzyme inhibitors
# ACE inhibitors
# medication
# treatment
# high blood pressure
# heart failure
# relaxation
# blood vessels
# decrease
# blood volume
# lower blood pressure
# decreased
# oxygen demand
# heart
# ACE inhibitors
# inhibit
# activity
# angiotensin-converting enzyme
# renin
# angiotensin system
# angiotensin I
# angiotensin II
# hydrolyses
# bradykinin
# ACE inhibitors
# decrease
# formation
# angiotensin II
# vasoconstrictor
# increase
# level
# bradykinin
# peptide vasodilator
# combination
# synergistic
# lowering
# blood pressure
# inhibiting
# ACE
# enzyme
# bradykinin system
# ACE inhibitor
# drugs
# increased
# levels
# bradykinin
# degraded
# mechanism
# side effects
# ACE Inhibitors
# angioedema
# cough
# Bradykinin
# prostaglandin
# prescribed
# ACE inhibitors
# benazepril
# zofenopril
# perindopril
# trandolapril
# captopril
# enalapril
# lisinopril
# ramipril
# ACE
# inhibitors
# treatment
# hypertension
# combination
# anti-hypertensive medications
# cardiovascular
# kidney diseases
# Acute myocardial infarction
# heart attack
# left ventricular systolic dysfunction
# Kidney
# complications
# diabetes mellitus
# diabetic nephropathy
# decreasing
# blood pressure
# increasing
# perfusion
# glomerular arterioles
# treating
# high blood pressure
# ACE inhibitors
# drug choice
# diabetes
# age
# choices
# drug
# improvement
# fixed-dose combination drugs
# ACE inhibitor
# thiazide combinations
# ACE inhibitors
# chronic kidney failure
# kidney
# involvement
# systemic sclerosis
# hardening
# tissues
# scleroderma renal crisis
# stable
# heart failure
# benefits
# treatments
# meta-analysis
# published
# BMJ
# ACE inhibitors
# reducing
# risk
# pneumonia
# ARBs
# Angiotensin II Receptor Blockers
# authors
# decreased
# risk
# patients
# stroke
# risk reduction
# heart failure
# risk reduction
# Asian descent
# risk reduction
# risk reduction
# non-Asian population
# pneumonia
# mortality
# observed
# ACE inhibitors
# decrease
# excessive
# water
# consumption
# people
# schizophrenia
# psychogenic polydipsia
# double-blind
# placebo-controlled trial
# enalapril
# decreased
# consumption
# urine output
# osmolality
# people
# effect
# ACE inhibitors
# ACEi
# renal transplant
# post-transplant erythrocytosis
# condition
# characterised
# persistently
# months
# transplantation
# ACEi
# decrease
# erythropoietin
# production
# Adverse effects
# side effects
# low blood pressure
# cough
# hyperkalemia
# headache
# dizziness
# fatigue
# nausea
# kidney impairment
# adverse effects
# ACE
# inhibition
# pharmacological action
# adverse effects
# liver problems
# effects
# fetus
# Kidney problems
# ACE inhibitors
# mechanism
# action
# Patients
# ACE inhibitor
# reduction
# glomerular filtration rate
# GFR
# decrease
# significant
# conditions
# decreased
# renal perfusions
# renal artery stenosis
# heart failure
# polycystic kidney disease
# volume depletion
# patients
# maintenance
# GFR
# angiotensin-II-dependent efferent
# vasomotor tone
# renal function
# monitored
# days
# initiation
# treatment
# ACE inhibitor
# patients
# decreased
# renal perfusion
# moderate
# reduction
# renal function
# serum creatinine
# stabilized
# week
# treatment
# therapeutic effect
# residual renal function
# Reduced
# GFR
# problem
# patient
# NSAID
# diuretic
# drugs
# risk
# renal failure
# increased
# High blood potassium
# complication
# treatment
# ACE inhibitor
# effect
# aldosterone
# Suppression
# angiotensin II
# decrease
# aldosterone
# levels
# aldosterone
# increasing
# excretion
# potassium
# ACE inhibitors
# retention
# potassium
# people
# potassium
# ACE inhibitor
# Hyperkalemia
# decrease
# velocity
# impulse conduction
# nerves
# muscles
# cardiac tissues
# cardiac dysfunction
# neuromuscular
# consequences
# muscle weakness
# paresthesia
# nausea
# diarrhea
# monitoring
# potassium
# levels
# patients
# treatment
# ACE inhibitors
# risk
# hyperkalemia
# adverse effect
# ACE inhibitors
# RAAS bloc

# %%
#Hearst Patterns
doc._.hearst_patterns
# Out:
# [('such_as', waste, carbon dioxide),
#  ('include', They, MYH6),
#  ('include', They, ACTC1),
#  ('include', They, TNNI3),
#  ('include', They, CDH2),
#  ('include', They, PKP2),
#  ('such_as', agents, adrenaline),
#  ('such_as', agents, noradrenaline),
#  ('such_as', agents, dopamine),
#  ('include', receptors, baroreceptors),
#  ('other', locations, cavae),
#  ('other', locations, stretch receptors),
#  ('other', locations, side),
#  ('include', electrolytes, calcium),
#  ('include', electrolytes, potassium),
#  ('include', electrolytes, sodium),
#  ('other', factors, lifestyle),
#  ('include', heart, doctors),
#  ('include', heart, surgeons),
#  ('include', heart, intensivists),
#  ('include', heart, health practitioners),
#  ('include', health practitioners, physiotherapists),
#  ('include', health practitioners, dieticians),
#  ('such_as', toxins, alcohol),
#  ('include', investigations, blood tests),
#  ('include', investigations, echocardiograms),
#  ('include', investigations, ECGs),
#  ('include', investigations, imaging),
#  ('include', examination, inspection),
#  ('such_as', hands, splinter haemorrhages),
#  ('other', areas, joints),
#  ('other', areas, It involves assessment),
#  ('such_as', features, their radiation),
#  ('include', heart, ultrasound),
#  ('include', heart, angiography),
#  ('include', heart, CT scans),
#  ('include', heart, MRI),
#  ('include', heart, PET),
#  ('such_as', drug, dobutamine),
#  ('other', forms, X-rays),
#  ('other', forms, CT scans),
#  ('include', methods, lifestyle modification),
#  ('include', methods, drug treatment),
#  ('include', methods, surgery),
#  ('include', symptoms, nitroglycerin),
#  ('include', symptoms, beta blockers),
#  ('include', treatments, antiplatelets),
#  ('such_as', antiplatelets, aspirin),
#  ('such_as', antiplatelets, statins),
#  ('such_as', antiplatelets, lifestyle measures),
#  ('such_as', cell membrane, calcium channel blockers),
#  ('such_as', anticoagulants, warfarin),
#  ('such_as', anticoagulants, anticoagulants),
#  ('include', heart, diet),
#  ('include', heart, exercise),
#  ('include', heart, medications),
#  ('such_as', medications, aspirin),
#  ('such_as', word ib, Awi-ib),
#  ('include', scientists, Aristotle),
#  ('other', tetrapods, lungfish),
#  ('such_as', invertebrates, earthworms),
#  ('other', cephalopods, hearts"".Squids),
#  ('include', chordates, vertebrates),
#  ('include', Human Heart, vessels),
#  ('such_as', procedures, ablation),
#  ('include', manoeuvres, pressure),
#  ('include', AVNRT, adenosine),
#  ('include', AVNRT, beta blockers),
#  ('include', AVNRT, calcium channel blockers),
#  ('such_as', calcium channel blockers, verapamil),
#  ('such_as', calcium channel blockers, diltiazem),
#  ('such_as', drugs, flecainide),
#  ('such_as', drugs, amiodarone),
#  ('include', line agents, flecainide),
#  ('include', line agents, amiodarone),
#  ('include', line agents, digoxin),
#  ('include', ACE inhibitors, benazepril),
#  ('include', ACE inhibitors, zofenopril),
#  ('include', ACE inhibitors, perindopril),
#  ('include', ACE inhibitors, trandolapril),
#  ('include', ACE inhibitors, captopril),
#  ('include', ACE inhibitors, enalapril),
#  ('include', ACE inhibitors, lisinopril),
#  ('include', ACE inhibitors, ramipril),
#  ('such_as', combination drugs, ACE inhibitor),
#  ('such_as', combination drugs, thiazide combinations),
#  ('such_as', consequences, muscle weakness),
#  ('such_as', consequences, paresthesia),
#  ('such_as', consequences, nausea),
#  ('such_as', consequences, diarrhea),
#  ('such_as', consequences, others)]

# %%
#Abbreviations
for abrv in doc._.abbreviations:
	print(str(abrv),str(abrv._.long_form))
# Out:
# CVD Cardiovascular diseases
# bpm beats per minute
# bpm beats per minute
# bpm beats per minute
# bpm beats per minute
# bpm beats per minute
# bpm beats per minute
# bpm beats per minute
# bpm beats per minute
# bpm beats per minute
# week week after the LMP
# week week after the LMP
# week week after the LMP
# week week after the LMP
# week week after the LMP
# week week after the LMP
# week week after the LMP
# CO Cardiac output
# CO Cardiac output
# SV stroke volume
# SV stroke volume
# HR heart rate
# HR heart rate
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# node nodal re-entrant tachycardia
# BNP brain natriuretic peptide
# ECG electrocardiogram
# ECG electrocardiogram
# ECG electrocardiogram
# ECG electrocardiogram
# ECG electrocardiogram
# ECG electrocardiogram
# ECG electrocardiogram
# ECG electrocardiogram
# ECG electrocardiogram
# ECG electrocardiogram
# ECG electrocardiogram
# ECG electrocardiogram
# ECG electrocardiogram
# ischaemic heart disease Ischaemic heart disease Narrowings of the coronary arteries
# ischaemic heart disease Ischaemic heart disease Narrowings of the coronary arteries
# ischaemic heart disease Ischaemic heart disease Narrowings of the coronary arteries
# ischaemic heart disease Ischaemic heart disease Narrowings of the coronary arteries
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# heart heart chambers
# G-actin globular actin
# potential potential
# potential potential
# potential potential
# potential potential
# potential potential
# potential potential
# potential potential
# potential potential
# potential potential
# potential potential
# potential potential
# potential potential
# potential potential
# potential potential
# potential potential
# potential potential
# potential potential
# potential potential
# potential potential
# potential potential
# potential potential
# potential potential
# potential potential
# potential potential
# potential potential
# potential potential
# potential potential
# potential potential
# potential potential
# potential potential
# potential potential
# potential potential
# potential potential
# potential potential
# active voltage-activated sodium channels in the closed
# active voltage-activated sodium channels in the closed
# AVNRT AV-nodal reentrant tachycardia
# AVNRT AV-nodal reentrant tachycardia
# AVNRT AV-nodal reentrant tachycardia
# AVNRT AV-nodal reentrant tachycardia
# AVNRT AV-nodal reentrant tachycardia
# AVNRT AV-nodal reentrant tachycardia
# AVNRT AV-nodal reentrant tachycardia
# AVNRT AV-nodal reentrant tachycardia
# AVNRT AV-nodal reentrant tachycardia
# AVNRT AV-nodal reentrant tachycardia
# AVNRT AV-nodal reentrant tachycardia
# AVNRT AV-nodal reentrant tachycardia
# AVNRT AV-nodal reentrant tachycardia
# AVNRT AV-nodal reentrant tachycardia
# AVNRT AV-nodal reentrant tachycardia
# AVNRT AV-nodal reentrant tachycardia
# AVNRT AV-nodal reentrant tachycardia
# AVNRT AV-nodal reentrant tachycardia
# AVNRT AV-nodal reentrant tachycardia
# AVNRT AV-nodal reentrant tachycardia
# AVNRT AV-nodal reentrant tachycardia
# AVNRT AV-nodal reentrant tachycardia
# AVNRT AV-nodal reentrant tachycardia
# AVNRT AV-nodal reentrant tachycardia
# AVNRT AV-nodal reentrant tachycardia
# AVNRT AV-nodal reentrant tachycardia
# SVT supraventricular tachycardia
# WPW syndrome Wolff-Parkinson-White syndrome
# WPW syndrome Wolff-Parkinson-White syndrome
# AVRT atrioventricular reciprocating tachycardia
# AVRT atrioventricular reciprocating tachycardia
# TFTs thyroid function tests
# EP electrophysiology
# sclerosis scleroderma renal crisis
# ARBs Angiotensin II Receptor Blockers
# GFR glomerular filtration rate
# GFR glomerular filtration rate
# GFR glomerular filtration rate

# %%
abbreviations=[]
long_form=[]
for abrv in doc._.abbreviations:
    if str(abrv) not in abbreviations:
        if str(abrv)!=str(abrv._.long_form):
            abbreviations.append(str(abrv))
            long_form.append(str(abrv._.long_form))

hyponyms=list(doc._.hearst_patterns)
sources=[str(source[1]) for source in hyponyms]
targets=[str(target[2]) for target in hyponyms]
relations=[str(relation[0]) for relation in hyponyms]

for abrv,abrv_long in zip(abbreviations,long_form):
    sources.append(abrv)
    targets.append(abrv_long)
    relations.append('abbreviated-as')

# %%
#Pos Tagging and Dependency parsing
def extract(sent):

  doc=nlp_core(sent)
  matcher = Matcher(nlp_core.vocab)
  pattern = [{'DEP':'ROOT'}, 
            {'DEP':'prep','OP':"?"},
            {'DEP':'agent','OP':"?"},  
            {'POS':'ADJ','OP':"?"}] 
  matcher.add("relation",[pattern]) 
  matches = matcher(doc)
  k = len(matches) - 1
  span = doc[matches[k][1]:matches[k][2]] 

  ent1,ent2,prv_tok_dep,prv_tok_text,prefix,modifier = "","","","","",""
  for tok in nlp_core(sent):
    if tok.dep_ != "punct":
      if tok.dep_ == "compound":
        prefix = tok.text
        if prv_tok_dep == "compound":
          prefix = prv_tok_text + " "+ tok.text
      
      if tok.dep_.endswith("mod") == True:
        modifier = tok.text
        if prv_tok_dep == "compound":
          modifier = prv_tok_text + " "+ tok.text

      if tok.dep_.find("subj") == True:
        ent1 = modifier +" "+ prefix + " "+ tok.text
        prefix = ""
        modifier = ""
        prv_tok_dep = ""
        prv_tok_text = ""   

      if tok.dep_.find("obj") == True:
        ent2 = modifier +" "+ prefix +" "+ tok.text
      prv_tok_dep = tok.dep_
      prv_tok_text = tok.text
      
  return [ent1.strip(),span.text,ent2.strip()]

# %%
ner_core=[]
for sent in doc.sents:
    source=extract(str(sent))[0]
    relation=extract(str(sent))[1]
    target=extract(str(sent))[2]
    if not any(re.search("^\s*$",s) for s in [source,target,relation]):
        ner_core.append(extract(str(sent)))
        sources.append(source)
        relations.append(relation)
        targets.append(target)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/scispacy/abbreviation.py:216: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   global_matches = self.global_matcher(doc)

# %%
for enitity_relations in ner_core:
    print(enitity_relations)
# Out:
# ['animals  which', 'organ', 'blood']
# ['pumped  blood', 'carries', 'metabolic  waste']
# ['two  reptiles', 'have', 'three  chambers']
# ['heart valves heart which', 'flows', 'backflow']
# ['sac  which', 'enclosed', 'small  amount']
# ['heart', 'pumps', 'blood']
# ['that', 'generate', 'contraction']
# ['circulation  which', 'receives', 'right  atrium']
# ['where  it', 'pumped', 'carbon dioxide']
# ['Exercise', 'increases', 'resting heart rate']
# ['Cardiovascular  diseases', 'have', 'chest  pain']
# ['Structure Location', 'situated', 'human  heart']
# ['double-membraned  sac', 'surrounds', 'heart']
# ['left  lung', 'smaller', 'border  heart']
# ['adult  heart', 'has', 'mass']
# ['Well-trained  athletes', 'have', 'larger  hearts']
# ['Chambers', 'has', 'four  chambers']
# ['tissue  this', 'made', 'structure']
# ['fibrous  which', 'forms', 'atria']
# ['conduction system conduction collagen', 'provides', 'electricity']
# ['interventricular  septum', 'separates', 'ventricles']
# ['when  they', 'thicker', 'greater  pressure']
# ['four  which', 'has', 'chambers']
# ['three  which', 'has', 'three  cusps']
# ['mitral  valve', 'lies', 'atrium  ventricle']
# ['bicuspid valve bicuspid its', 'known', 'two  cusps']
# ['when  they', 'prevent', 'valves']
# ['This', 'creates', 'place chordae them']
# ['three  which', 'has', 'three  cusps']
# ['cusps  which', 'flows', 'valve']
# ['three  which', 'has', 'three  cusps']
# ['right  atrium', 'receives', 'blood']
# ['muscles  which', 'smooth', 'prominent  ridges']
# ['endocardium moderator band', 'addition', 'crucial  role']
# ['It', 'arises', 'interior  space']
# ['which  it', 'tapers', 'blood']
# ['arteries trunk that', 'branches', 'blood']
# ['left  heart', 'has', 'left  atrium']
# ['left  atrium', 'receives', 'oxygenated  blood']
# ['left  atrium', 'has', 'outpouching']
# ['left  ventricle', 'thicker', 'force  blood']
# ['ventricle  left', 'has', 'trabeculae  carneae']
# ['left  ventricle', 'pumps', 'blood']
# ['coronary heart artery', 'carry', 'valve  blood']
# ['It', 'made', 'epithelium heart chambers']
# ['endocardium', 'play', 'also  contraction']
# ['muscle cells', 'elegant', 'inner figure figure']
# ['swirling  pattern', 'allows', 'blood']
# ['muscle muscle which', 'are', 'ability']
# ['muscle cells', 'make', 'bulk']
# ['discs  which', 'connected', 'rapid  response']
# ['syncytium  that', 'allow', 'blood']
# ['pacemaker cells', 'make', 'cells conduction system']
# ['few  which', 'smaller', 'limited  contractibility']
# ['Cardiac muscle tissue', 'has', 'cell rate contraction']
# ['They', 'include', 'MYH6']
# ['that', 'sac', 'heart']
# ['serous  that', 'lined', 'pericardial  surface']
# ['pericardium', 'present', 'chest  heart']
# ['Coronary circulation Heart tissue', 'needs', 'metabolic  wastes']
# ['circulation  which', 'achieved', 'arteries']
# ['arteries  which', 'receives', 'blood']
# ['coronary  artery', 'splits', 'shortly  aorta']
# ['It', 'does', 'this']
# ['coronary  artery', 'supplies', 'posterior  sections']
# ['coronary  artery', 'supplies', 'also  blood']
# ['large  that', 'vein', 'atrium  most']
# ['It', 'receives', 'cardiac  bottom']
# ['cardiac  veins', 'drain', 'front']
# ['smaller  they', 'collect', 'smaller  vessels']
# ['third  which', 'travel', 'section']
# ['left  vessel', 'joins', 'artery  atrium']
# ['Nerve supply heart', 'receives', 'nerve signals']
# ['nerves', 'act', 'heart rate']
# ['Sympathetic  nerves', 'influence', 'also  force']
# ['vagus  nerve', 'acts', 'trunk act heart rate']
# ['nerves  that', 'form', 'network']
# ['wandering  that', 'nerve', 'parasympathetic  stimulation']
# ['Sympathetic  stimulation', 'causes', 'release']
# ['depolarization repolarization which', 'shortens', 'thus repolarization rate']
# ['It', 'opens', 'chemical ion influx']
# ['Development heart', 'organ', 'functional  blood']
# ['plate  which', 'derives', 'cardiogenic  region']
# ['here  that', 'form', 'primitive heart tube']
# ['week heart tube', 'lengthens', 'S-shape']
# ['Further  development', 'include', 'formation']
# ['atrium  blood', 'allowed', 'lungs']
# ['septum primum septum that', 'closes', 'cardiac circulation pattern']
# ['embryonic heart rate', 'accelerates', 'peak  rate']
# ['Physiology Blood flow', 'functions', 'continuous heart flow']
# ['systemic  circulation', 'transports', 'deoxygenated carbon blood']
# ['right  heart', 'collects deoxygenated', 'deoxygenated  blood']
# ['Blood', 'collects', 'right  atrium']
# ['inferior vena cava', 'drains', 'blood']
# ['lungs  it', 'divides', 'capillaries']
# ['which  ventricles', 'period', 'blood']
# ['atria', 'relaxed', 'blood']
# ['When  ventricles', 'contract', 'diastole atria blood']
# ['ventricles', 'completed most', 'ventricles atria pump']
# ['aortic aorta valves', 'open', 'further  pressure']
# ['Blood', 'ejected', 'heart  pressure']
# ['This', 'calculated', 'stroke volume']
# ['So  CO', '=', 'SV HR']
# ['cardiac  output', 'L/min', 'average stroke volume']
# ['stroke volume', 'measured', 'normally  echocardiogram']
# ['less  preload', 'is', 'ventricles']
# ['much  heart', 'influenced', 'blood']
# ['strength', 'controls', 'muscle contractions stroke volume']
# ['adrenaline  inotropes', 'decrease', 'contraction calcium channel blockers']
# ['that', 'created', 'heart heart muscle']
# ['which', 'part', 'signal']
# ['signal', 'travels', 'right bundle branches']
# ['tissue Purkinje which', 'carried', 'electric  charge']
# ['Cells', 'do', 'node action potential']
# ['they', 'have', 'negative  charge']
# ['rapid  influx', 'causes', 'sodium ions sodium charge']
# ['potassium', 'close', 'it']
# ['only  it', 'has', 'high  charge']
# ['potassium', 'close', 'cell']
# ['This', 'causes', 'resting  charge']
# ['process', 'close', '−60  mV']
# ['Calcium', 'plays', 'critical  role']
# ['when plateau they', 'means', 'positive  charge']
# ['Calcium ions', 'combine', 'protein troponin relaxation']
# ['Influences', 'influenced', 'resting heart rate']
# ['cardiovascular  centres', 'control', 'sympathetic  influences']
# ['reflexes carbon help', 'receive', 'blood flow']
# ['cardiac baroreceptor firing centers', 'decrease sympathetic', 'parasympathetic  stimulation']
# ['pressure  rate', 'increase sympathetic', 'parasympathetic baroreceptor firing stimulation']
# ['specialized  baroreceptors', 'stretches', 'walls']
# ['cardiac blood center', 'responds', 'parasympathetic heart rate']
# ['Low  oxygen', 'stimulate', 'high carbon firing']
# ['Exercise levels', 'affect', 'all heart rate']
# ['High  levels', 'increase', 'hormones heart rate']
# ['low blood oxygen', 'increase', 'low blood it']
# ['which', 'cause', 'diseases']
# ['medical  professionals', 'involved', 'diseases']
# ['coronary  severe', 'narrow', 'blood flow']
# ['then  patient', 'experience', 'symptoms']
# ['Severe  narrowings', 'cause chest', 'chest  pain']
# ['thin  covering', 'rupture', 'fatty  centre']
# ['case  clot', 'form', 'myocardial heart infarction']
# ['case  this', 'cause cardiac', 'cardiac  arrest']
# ['Obesity', 'increase', 'all blood atherosclerosis']
# ['which  heart', 'defined', 'enough  demands']
# ['Patients', 'experience', 'heart failure heart breathlessness']
# ['Heart failure', 'result', 'diseases end heart']
# ['common  causes', 'include various', 'various  cardiomyopathies']
# ['condition', 'affect', 'right  ventricle']
# ['Patients', 'risk', 'dangerous heart rhythm disturbances']
# ['Cardiomyopathies Cardiomyopathies', 'diseases', 'muscle']
# ['heart', 'cause', 'dilated  cardiomyopathy']
# ['blood', 'allow', 'direction  it']
# ['Diseased heart valves', 'have', 'valve  blood']
# ['Valvular heart disease', 'cause', 'abnormal  heart']
# ['Abnormal heart rhythms', 'asymptomatic', 'palpitations']
# ['types', 'increase', 'long term risk']
# ['re-entrant AV others', 'take many', 'heart  arise']
# ['which', 'become inflamed', 'heart']
# ['chest  that', 'causes chest', 'chest  pain']
# ['Pericardial  effusions', 'occur secondary', 'frequently kidney symptoms']
# ['which', 'compress', 'tamponade  breathlessness']
# ['Fluid', 'removed', 'diagnosis  syringe']
# ['heart that', 'include', 'heart  hole']
# ['main blood that', 'include', 'e.g.  coarctation']
# ['that', 'seen', 'one  part']
# ['oxygen  that', 'allow', 'blood']
# ['transposition', 'picked', 'arteries  breathlessness']
# ['minor  forms', 'remain undetected', 'only heart themselves']
# ['invasive  procedures', 'play', 'also  role']
# ['cardiac Examination examination', 'includes', 'chest']
# ['signs  that', 'involves', 'assessment']
# ['blood pressure', 'taken', 'invasive  measurement']
# ['healthy  hearts', 'sounds', 'audible heart sounds']
# ['two  valves', 'consists', 'slight  difference']
# ['also  these', 'present', 'rise']
# ['S3', 'indicates', 'usually  increase']
# ['combined  presence', 'give', 'quadruple  gallop']
# ['tests Blood tests', 'play', 'important  role']
# ['It', 'released', '4–6 hours']
# ['significant  rise', 'taken', 'often  one']
# ['frequently blood it', 'provides', 'creatine kinase creatine information']
# ['general health that', 'taken', 'general health factors']
# ['metabolic blood that', 'include', 'disturbances']
# ['Fasting  lipids', 'ordered', 'often cholesterol status']
# ['body surface it', 'possible', 'electrical  activity']
# ['ECG', 'test', 'bedside placement']
# ['ground).There', 'produces', '12  lead']
# ['that', 'create', 'current']
# ['negative  lead', 'depends', 'positive  deflection']
# ['ECG', 'tool', 'insufficient blood supply']
# ['suspected rhythm abnormality', 'worn', 'abnormality']
# ['Several imaging methods', 'used', 'anatomy']
# ['echocardiogram', 'ultrasound', 'heart  function']
# ['much  blood', 'include', 'valves  stenosis']
# ['Ejection fraction', 'obtained', 'then  volume']
# ['where  this', 'involves', 'injection']
# ['CT scans', 'help', 'imaging  size']
# ['major blood which', 'useful', 'heart']
# ['Treatment Diseases', 'treated', 'heart']
# ['when heart muscle artery', 'treated', 'myocardial  infarction']
# ['preventative calcium channel treatments', 'include', 'aspirin lifestyle smoking']
# ['narrowed heart arteries', 'treated', 'blood  obstruction']
# ['which  narrowings', 'performed', 'stent artery open']
# ['whereby blood vessel', 'performed', 'mammary  blood']
# ['that', 'require', 'abnormally  surgery']
# ['This', 'performed', 'damaged heart valve']
# ['circumstances tricuspid valves', 'repaired', 'surgically  need']
# ['percutaneously  that', 'treated', 'many  similarities']
# ['Transcatheter aortic valve replacement', 'used', 'high  risk']
# ['Cardiac  arrhythmias', 'treated', 'antiarrhythmic heart drugs']
# ['These', 'work', 'nervous sodium channel effect']
# ['stroke  risk', 'reduced', 'anticoagulants']
# ['treatment option', 'ablation', 'arrhythmia']
# ['tissue  that', 'passed', 'arrhythmia']
# ['abnormal  tissue', 'damaged', 'further heart rhythm disturbances']
# ['invasive catheter arrhythmias', 'treated', 'open  surgery']
# ['electric  shock', 'used', 'heart']
# ['Cardiac  devices', 'required', 'also  arrhythmias']
# ['skin  that', 'leads', 'slow heart rhythms']
# ['Implantable  defibrillators', 'used', 'rapid heart rhythms']
# ['dangerous heart racing', 'monitor', 'automatically  heart']
# ['Heart failure', 'medication', 'underlying  cause']
# ['that', 'include', 'resynchronisation therapy pumping efficiency']
# ['which', 'implanted', 'own pumping ability']
# ['blood  Hippocrates', 'considered', 'blood']
# ['they', 'noted', 'pump  dilation']
# ['He', 'discovered', 'also heart valves']
# ['Greek physician Galen', 'knew', 'brighter blood blood']
# ['body  it', 'concluded', 'heat']
# ['diastole  blood', 'pump', 'blood']
# ['academic  doctrines', 'continued', 'academic  community']
# ['authorities  he', 'questioned', 'some']
# ['Christianismi Restitutio Christianismi blood', 'wrote', 'Christianismi Restitutio Christianismi that']
# ['William Harvey physician William book', 'came', 'systemic  circulation']
# ['English  who', 'physiologist', 'also  heart']
# ['heart Sunao Tawara', 'recognized', 'Reizleitungssystem des Säugetierherzens']
# ['discovery', 'prompted', 'node Arthur Keith']
# ['electrocardiogram  inventor', 'form', 'Nobel Prize']
# ['This', 'marked', 'surgery  attention']
# ['American surgeon Norman Shumway', 'credited', 'efforts transplantation techniques']
# ['United States United it', 'surpassed infectious', 'infectious  disease']
# ['ongoing Framingham Heart Study', 'shed', 'light']
# ['heart failure heart disease', 'continues', 'year 30 diagnosis']
# ['heart', 'symbol', 'religions  temple']
# ['expressions  which', 'evidenced', 'ib']
# ['where nether it', 'conceived', 'evidence']
# ['Maat  which', 'weighed more', 'ideal  standard']
# ['it', 'devoured', 'just  afterlife']
# ['Chinese  character', 'derives', 'heart heart chambers']
# ['Chinese  word', 'takes', 'metaphorical  meanings']
# ['heart', 'associated', 'six  organs']
# ['Sanskrit  it', 'mean', 'anatomical  seat']
# ['classical  philosophers', 'considered', 'often  brain']
# ['physician Galen physician who', 'due', 'also  seat']
# ['heart', 'played', 'also  role']
# ['Jesus Christ Jesus which', 'consider', 'prominence']
# ['tradition', 'influenced', 'development']
# ['that', 'ancient', 'explicit']
# ['little Renaissance that', 'theme', 'little heart symbols']
# ['Many  recipes', 'combined', 'them']
# ['Australian  recipe', 'braised', 'stuffed beef heart']
# ['Other  animals', 'Vertebrates', 'size']
# ['which', 'continuous', 'beat']
# ['systems Adult systems amphibians', 'have', 'circulatory  system']
# ['lungs  which', 'allows', 'oxygenated  blood']
# ['fact  snakes', 'different', 'elongated  body']
# ['that', 'tend', 'higher blood pressure']
# ['rule  which', 'crocodiles', 'four-chambered  heart']
# ['spongy  nature', 'seem', 'ventricle  more']
# ['valve  that', 'replaced', 'two  bloodstreams']
# ['four-chambered  heart', 'thought', 'complete  separation']
# ['what', 'have', 'one  it']
# ['sometimes  what', 'has', 'entry compartments']
# ['primitive  heart', 'considered', 'four-chambered  heart']
# ['sinus which', 'venosus', 'deoxygenated  blood']
# ['main pumping action', 'flows', 'place']
# ['conus  which', 'arteriosus', 'several  blood']
# ['two  chambers', 'delivers', 'instead  S-shape']
# ['Invertebrates Arthropods', 'have', 'circulatory  system']
# ['blood', 'permeates', 'slowly  heart']
# ['heart', 'pumps', 'then  blood']
# ['muscular  that', 'tube', 'length']
# ['which', 'haemolymph', 'pigment copper-based pigment haemocyanin']
# ['circulatory  system', 'used', 'much  veins']
# ['animals  that', 'travels', 'two gill hearts']
# ['systemic  heart', 'have', 'two  atria']
# ['central  which', 'have', 'aorta  blood']
# ['This', 'suggests', 'presence']
# ['article', 'Notes', 'text']
# ['– NIH Atlas', 'discussion', 'human development Animal Heart']
# ['ACTC1', 'encodes cardiac', 'cardiac muscle alpha actin']
# ['sarcomeres  which', 'protein', 'force pump function']
# ['same Kabsch et group', 'solved', 'structure']
# ['actin monomer', 'has', 'asymmetric  domains']
# ['dynamic  that', 'structure', 'two  states']
# ['2 actin which', 'increases', 'flexibility']
# ['ACTC1 gene', 'suggested', 'role']
# ['Experiments', 'found', 'chick embryos chick association']
# ['Further  studies', 'found', 'South Africa South association']
# ['stimuli  object', 'reading External', 'genome location gene details']
# ['characteristic recovery that', 'time', '–          diffusion']
# ['stimulus   it', 'period', 'particular  action']
# ['refractory  period', 'defined', 'two  ways']
# ['Na+ channels Na+ that', 'caused', 'originally  membrane']
# ['channels', 'close', 'then  ability']
# ['refractory  period', 'follows', 'immediately  absolute']
# ['potassium conductance', 'increases', 'action membrane']
# ['K+ ions', 'bring', 'cell membrane potential']
# ['that membrane potential', 'becomes', 'brief  hyperpolarization']
# ['greater  stimulus', 'required', 'initiation threshold']
# ['return', 'marks', 'potential  end']
# ['time action which', 'unable', 'action potential']
# ['period  which', 'referred to', 'duration  heart']
# ['refractory  period', 'occurs', 'one action millisecond']
# ['voltage-gated sodium ion channels', 'open', 'sodium ions membrane potential']
# ['-55 activation depolarization', 'driven', 'equilibrium   potential']
# ['inactivation', 'act', 'ion channels membrane potential']
# ['resting membrane cell', 'enters', 'phase']
# ['depolarization inactivation that', 'have', 'channel']
# ['membrane', 'means', 'greater action potentials']
# ['stronger  stimulus', 'required', 'thus action potential']
# ['refractory  period', 'lasts', '2–4  ms']
# ['References Books heart', 'See', 'References Books Papers']
# ['accelerans which', 'nerve', 'it']
# ['conducting radiofrequency tissue', 'require', 'radiofrequency ablation']
# ['slow  which', 'involves', 'anatomical  pathways']
# ['AV node AV authors', 'formed', 'them']
# ['accessory pathways accessory that', 'confused', 'rise']
# ['fast  pathways', 'located', 'electrophysiologic AV properties']
# ['that', 'located', 'rise']
# ['They', 'provide', 'electrophysiologic  properties']
# ['someone', 'experience', 'rarely  consciousness']
# ['angina heart pain', 'band-', 'chest heart pain']
# ['palpitations', 'occur', 'heavy  forwards']
# ['feeling heart heart', 'sudden', 'beat']
# ['Close  inspection', 'reveal', 'neck  pulsation']
# ['Mechanisms', 'circuit', 'fundamental  mechanism']
# ['Typical  AVNRT', 'take several', 'AV nodal AV pathway']
# ['atrial anterograde that', 'use', 'AV node']
# ['ventricles P which', 'occurs', 'QRS complex']
# ['inverted P that', 'delayed', 'inverted P wave']
# ['120 heart block', 'show typical', 'diagnosis']
# ['doctor', 'request', 'Holter monitor']
# ['recorder', 'show', 'diagnosis']
# ['skin  that', 'require', 'continuously heart activity']
# ['only  patient', 'case', 'further pain Treatment episodes']
# ['treatments', 'include physical', 'physical  manoeuvres']
# ['action  that', 'terminated', 'transiently AV node']
# ['physical  that', 'able', 'activity']
# ['airway Valsalva slow', 'include', 'AV node AV AVNRT']
# ['people  who', 'cause', 'asthma']
# ['used  drugs', 'include antiarrhythmic', 'antiarrhythmic  drugs']
# ['then blood AVNRT', 'terminated', 'electrically  cardioversion']
# ['electric  shock', 'applied', 'normal  rhythm']
# ['preventative  treatment', 'helpful', 'unpleasant  symptoms']
# ['those  who', 'become asymptomatic', 'further  treatment']
# ['who', 'choose', 'term antiarrhythmic term medication']
# ['drugs', 'effective', 'long  term']
# ['invasive  procedure', 'used', 'potentially catheter cure']
# ['procedure', 'involves', 'wires']
# ['tip', 'used', 'electrical AV AVNRT']
# ['Catheter  ablation', 'cure', 'subsequently AV pacemaker']
# ['Angiotensin-converting-enzyme  inhibitors', 'class', 'External  links']
# ['blood volume blood which', 'work', 'blood pressure oxygen demand']
# ['angiotensin system angiotensin which', 'inhibit', 'II angiotensin bradykinin']
# ['Therefore ACE inhibitors', 'decrease', 'II  level']
# ['bradykinin  which', 'allow', 'result ACE enzyme']
# ['mechanism', 'explain', 'side  effects']
# ['Bradykinin', 'produces', 'prostaglandin']
# ['prescribed ACE inhibitors', 'include', 'benazepril']
# ['use', 'approved', 'ACE inhibitors']
# ['Later  they', 'found useful', 'means blood pressure']
# ['choices  it', 'lead', 'desired  improvement']
# ['BMJ  that', 'was', 'ACE inhibitors ACE risk']
# ['authors', 'found', 'decreased  risk']
# ['Other ACE inhibitors', 'used', 'excessive water consumption']
# ['transplantation  ACEi', 'used', 'erythropoietin production']
# ['side  effects', 'effects Common', 'low blood pressure']
# ['Patients', 'have', 'modest ACE reduction']
# ['serum creatinine serum that', 'deemed acceptable', 'renal  function']
# ['especially  patient', 'problem', 'concomitantly  NSAID']
# ['together   risk', 'increased', 'renal  failure']
# ['potassium ACE inhibitors', 'cause', 'retention']
# ['people', 'continue', 'however  potassium']
# ['Hyperkalemia', 'decrease', 'velocity']
# ['ACE inhibitors ACE who', 'required', 'patients potassium treatment']
# ['ACE inhibitors ACE role', 'effect', 'bradykinin  symptoms']
# ['who', 'switched', 'cough']
# ['Some', 'develop', '0.7  angioedema']
# ['allergic  reaction', 'affect', 'abdominal bowel pain']
# ['women ACE inhibitors', 'reported', 'congenital  malformations']
# ['fetal  abnormalities', 'include', 'hypotension']
# ['use', 'associated', 'nervous  systems']
# ['Treatment', 'symptomatic', 'further volume absorption']
# ['ACE inhibitors', 'contraindicated', 'drugs ACE effects']
# ['Concomitant  use', 'tends', 'hypotensive ACE effect']
# ['Mechanism', 'reduce', 'ACE inhibitors action ACE activity']
# ['Markers', 'decreased', 'sympathetic blood release']
# ['Renin', 'activates', 'two angiotensin converting angiotensin']
# ['very blood vessels', 'increases', 'potent  vasoconstrictor']
# ['Effects ACE inhibitors', 'block', 'conversion']
# ['They', 'lower arteriolar', 'cardiac  output']
# ['II  Vasoconstriction', 'has', 'II  effects']
# ['cortex  that', 'causes', 'kidney tubules sodium retention']
# ['Stimulation', 'acts', 'kidneys water retention']
# ['ATII  which', 'decreased', 'aldosterone release']
# ['This', 'allows', 'water potassium ions']
# ['This', 'decreases', 'blood volume']
# ['ACE inhibitors', 'shown', 'progress']
# ['events heart it', 'justified', 'clinical  outcomes']
# ['Such  therapy', 'requires careful', 'dose  effects']
# ['ACE inhibitors', 'shown', 'central  enhancement']
# ['action', 'reduce', 'prevalence']
# ['system activation angiotensin system which', 'reduce', 'cardiac ACE inhibitor cachexia']
# ['ZofenoprilThese agents', 'appear', 'antioxidative  properties']
# ['only Inhibace member', 'available', 'comprehensive  resource']
# ['It', 'contains', 'antihypertensive  peptides']
# ['Val-Pro-Pro', 'shown', 'ACE-inhibiting Lactobacillus functions']
# ['equivalent  doses', 'have similar', 'antihypertensive  efficacy']
# ['Captopril', 'has', 'shorter  duration']
# ['brain barrier brain significance', 'inhibitor capable', 'clinical  effects']
# ['study  one', 'demonstrated', 'subsequent mortality development']
# ['regular  use', 'made', 'ramipril mortality rates']
# ['effective  treatment', 'expect', 'broad  spectrum']
# ['hypertension ACE inhibitors', 'have different', 'different  strengths']
# ['when  patients', 'possess many', 'common  characteristics']
# ['AT2 receptor AT2 latter', 'have', 'further  study']
# ['combination', 'increase', 'bradykinin  generation']
# ['alone ACE angiotensin', 'effective', 'more ACE inhibitor']
# ['Preliminary  studies', 'suggest', 'combination']
# ['recent ONTARGET study', 'showed', 'agents']
# ['clinical  significance', 'lacking', 'role  hypertension']
# ['Patients', 'benefit', 'terms heart morbidity']
# ['nephropathy combination therapy', 'found', 'renoprotective  effect']
# ['Leonard T. Skeggs', 'discovered', 'Norman Shumway Norman ACE']
# ['Brazilian Sérgio Henrique Ferreira', 'reported', 'bradykinin-potentiating  factor']
# ['conversion', 'thought', 'II  place']
# ['Subsequent  investigation', 'showed rapid', 'rapid  conversion']
# ['Ferreira  conversion', 'showed', 'BPF']
# ['20,881 BPF which', 'yielded', 'greatest ACE inhibition potency']
# ['Teprotide', 'limited clinical', 'clinical  value']
# ['David Cushman', 'used', 'ACE carboxypeptidase A']
# ['Japanese  scientists', 'created', 'specific tripeptide isoleucine-proline-proline']
# ['human  study', 'confirmed', 'blood pressure-lowering blood effect']
# ['IPP  VPP', 'assumed', 'ACE-inhibiting  activity']
# ['Note', 'See', 'receptor blockers angiotensin receptor Loop']
# ['Citation Reports Journal Citation it', 'has', '2017 impact factor']
# ['journal', 'established', 'current Acta Physiologica name']
# ['second Christiaan Barnard', 'surgeon', 'second heart transplant attempt']
# ['Kantrowitz', 'invented', 'intra-aortic balloon pump']
# ['costume designer', 'ran', 'clinic']
# ['three-year-old  he', 'told', 'child  electrocardiograph']
# ['origin  he', 'has', 'Polish  ancestry']
# ['He', 'graduated', '1940 New York majored']
# ['He', 'attended', 'effort Downstate Medical availability']
# ['which Galea he', 'developed', 'clamp  craniotomy']
# ['16 New York he', 'screened', 'sequential  opening']
# ['which blood vessels', 'developed', 'left  heart']
# ['bladders', 'developed', 'individuals']
# ['1970  he', 'held surgical', 'surgical  posts']
# ['heart  that', 'used', 'one-inch  hole']
# ['which  portion', 'reported', '25 booster %']
# ['1960s  Kantrowitz', 'developed', 'artificial  pacemaker']
# ['minute pacing patient', 'included', 'physical  stress']
# ['team  that', 'collaborated', 'brother']
# ['patient', 'performed', '24  hours']
# ['13  patient', 'lasted', '13  days']
# ['electrical valveless impulses', 'used', 'heart  action']
# ['heart transplantation Dr. James Hardy', 'performed', 'first heart transplant attempt']
# ['brain death brain Hardy', 'acquired', 'four  chimpanzees']
# ['surgery  Hardy', 'brought', 'fellow  doctors']
# ['Rush', 'proceeded', 'consciousness']
# ['newspaper articles newspaper donor', 'put', 'newspaper articles newspaper assumption']
# ['disdain   Hardy', 'treated', 'International Transplantation Conference']
# ['surgeon Richard Kantrowitz', 'prepared', 'heart transplant heart hearts']
# ['infant  who', 'completed', 'new  heart']
# ['her', 'located', 'anencephalic  baby']
# ['brain death donor which', 'forced', 'brain death donor heart']
# ['Barnard', 'performed', 'human-to-human heart transplant']
# ['100 December transplants', 'were more', 'December 1967 December transplant']
# ['pediatric heart transplant attempt', 'performed', 'pediatric heart transplant attempt']
# ['grossly  who', 'Bashaw', 'startle Moro reflex response']
# ['However  infant', 'move', 'feeble  cry']
# ['then donor heart', 'had', 'beating']
# ['19-day-old Jamie who', 'Scudero', 'heart conditions']
# ['Jordan Haller', 'flat-lined', 'heart']
# ['He', 'sutured', 'heart']
# ['This', 'took', '40  minutes']
# ['Scudero  which', 'relying', 'entire  operation']
# ['heart  it', 'warmed', 'electrical  shock']
# ['he', 'emphasized', 'operation']
# ['Alex Faltine', 'technician', 'head Scudero']
# ['Faltine', 'held', 'hands  anything']
# ['long  he', 'astonished', 'pipes']
# ['fifties  who', 'shrugged', 'simply  it']
# ['intra-aortic balloon pump', 'invented', 'heart']
# ['thigh  it', 'directed', 'order  strain']
# ['when  heart', 'inflated', 'blood']
# ['pump', 'require', 'local  anesthetic']
# ['woman  who', 'used', 'heart attack']
# ['where Sinai-Grace he', 'relocated', 'surgeon']
# ['weakened heart heart', 'implanted', 'oxygenated  blood']
# ['Personal  life', 'married', 'Jean Rosensaft']
# ['1983  they', 'co-founded', 'L.VAD Technology']
# ['Achievement American References', 'contains', 'high-definition State University images']
# ['epinephrine National which', 'aid', 'visceral  functions']
# ['It', 'plays', 'muscles blood output']
# ['It', 'does', 'this']
# ['medication  it', 'used', 'number']
# ['Inhaled  adrenaline', 'used', 'symptoms']
# ['Common side effects', 'include shakiness', 'shakiness']
# ['conclusively  infusions', 'needed', 'successfully  rates']
# ['plasma  it', 'concentration', '90  %']
# ['neurons  which', 'found', 'adrenaline']
# ['Pharmacological  doses', 'stimulate', 'adrenaline  α1']
# ['neural  connection', 'have', 'adrenoceptor-mediated  effect']
# ['This', 'demonstrated', 'biological  assay']
# ['Biochemical  methods', 'published', 'catecholamines']
# ['total catecholamine method', 'non-specific', 'small  quantities']
# ['development', 'transformed', 'derivate radio-enzymatic derivate analysis']
# ['Infusion', 'has little', 'haemodynamic exercise effect']
# ['Infusion', 'suppresses human', 'sufficiently constrictor effects']
# ['stimulation', 'shown', 'muscarine-induced airway constriction']
# ['patients  those', 'reported', 'asthma  protection']
# ['subjects airway that', 'induces progressive', 'progressive airway dilation']
# ['time course time bronchoconstriction', 'causes', 'propranolol  rebound']
# ['reduction', 'reduces', 'exercise airway work']
# ['emotional  response', 'has', 'behavioral  component']
# ['stress  that', 'includes', 'release']
# ['who', 'expressed', 'facial  films']
# ['subjects', 'reported', 'intense  fear']
# ['heart rate knee which', 'effect', 'sympathetic  responses']
# ['other  emotions', 'had such', 'such  results']
# ['study  subjects', 'express', 'greater  amusement']
# ['rodent  that', 'supported', 'either  adrenaline']
# ['adrenaline', 'support', 'encoding']
# ['adrenergic  hormones', 'found', 'adrenaline retrograde enhancement']
# ['events memory that', 'modulate', 'events memory strength']
# ['adrenaline', 'is', 'role']
# ['Adrenaline', 'play', 'arousal  memory']
# ['epinephrine', 'indicates', 'memory consolidation']
# ['mechanism  that', 'found', 'adrenaline']
# ['blood – brain effects', 'cross', 'blood – brain barrier']
# ['β adrenoceptor that', 'found', 'enhancing  effects']
# ['β adrenoceptors', 'suggest', 'adrenaline  effect']
# ['familial  tremor', 'responsive', 'blockers β tremor']
# ['Patients', 'found', 'increased plasma adrenaline']
# ['cortisol adrenaline that', 'suppress', 'disease adrenaline secretion']
# ['glands  which', 'patented', 'purified  extract']
# ['However  pharmacologist', 'prepared', '1897 name it']
# ['International name adrenaline', 'became', 'Adopted  Name']
# ['preferentially term converse', 'true', 'preferentially term adrenaline']
# ['that', 'called adrenergic', 'effects']
# ['muscle muscle that', 'causes smooth', 'most  arterioles']
# ['binding', 'triggers', 'receptors  number']
# ['Binding', 'inhibits', 'insulin-mediated insulin glycogenesis']
# ['β adrenergic receptor binding', 'triggers', 'adrenocorticotropic hormone secretion']
# ['Together  effects', 'lead', 'fatty blood substrates']
# ['Adrenaline', 'causes', 'adrenergic alpha glycogenolysis']
# ['liver cells liver which', 'binds', 'heterotrimeric G GDP']
# ['Gs alpha', 'stimulates adenylyl', 'thus adenosine triphosphate']
# ['Cyclic  AMP', 'activates', 'partially phosphorylase kinase']
# ['Adrenaline', 'binds', 'inositol trisphosphate calcium cytoplasm']
# ['glycogen which', 'phosphorylates', 'then  glycogen']
# ['Adrenaline', 'has significant', 'significant  effects']
# ['It', 'increases peripheral', 'cardiac  output']
# ['goal', 'is', 'therefore oxygen exchange']
# ['carotid circulation it', 'lowers', 'carotid blood flow']
# ['actual  perfusion', 'appears', 'place']
# ['fluids  Adrenaline', 'quantified', 'causative  agent']
# ['terms 100,000 adrenaline', 'have', 'patients plasma concentrations']
# ['pathway medulla that', 'synthesized', 'amino acids']
# ['Then  it', 'decarboxylated', 'subsequently  dopamine']
# ['dopamine beta-hydroxylase dopamine which', 'converted', 'ascorbic  acid']
# ['phenylethanolamine N-methyltransferase enzyme phenylethanolamine which', 'catalyzed', 'S-adenosyl  methionine']
# ['Adrenocorticotropic  hormone', 'stimulate', 'key dopamine enzymes']
# ['adrenal  which', 'stimulates', 'cells adrenaline synthesis']
# ['nervous  system', 'stimulates', 'medulla  release']
# ['Acetylcholine', 'acts', 'acetylcholine receptors cell depolarization']
# ['Calcium', 'triggers', 'thus  release']
# ['VMAT1', 'responsible', 'synthesized  adrenaline']
# ['he', 'contained', 'adrenaline']
# ['American William H. Bates', 'discovered', 'usage']
# ['glands  he', 'finds', 'epinephrine']
# ['it', 'remains', 'crucial firstline treatment']
# ['Japanese chemist Jōkichi Takamine', 'discovered', 'independently assistant Keizo adrenaline']
# ['1901  Takamine', 'isolated', 'successfully  hormone']
# ['1895 George Oliver', 'published', 'gland extract gland increase']
# ['1897 John Jacob Abel', 'found', 'pharmacology U.S compound']
# ['Abel', 'claimed', 'principle']
# ['Japanese  chemist', 'worked', 'active Keizo principle']
# ['Takamine', 'got', '1901  patent']
# ['Such  activities', 'include extreme', 'extreme  sports']
# ['adrenal  gland', 'secondary', 'adrenal  medulla']
# ['it', 'activates many', 'behavior']
# ['Nevertheless adrenaline infusion', 'increase', 'alone  roles']
# ['when  child', 'are', 'parent  part']
# ['rapidly cell depolarization', 'causes adjacent', 'adjacent  locations']
# ['excitable  which', 'occur', 'neurons']
# ['axon  signals', 'connect', 'conduction  propagation']
# ['main  function', 'is', 'intracellular  processes']
# ['pancreas beta they', 'provoke', 'release']
# ['that', 'said', 'action potential']
# ['rapidly membrane potential', 'shut', 'transmembrane  potential']
# ['electrochemical  which', 'allow', 'further  rise']
# ['This', 'causes more', 'electric  current']
# ['plasma membrane ion channels', 'causes', 'sodium ions sodium polarity']
# ['longer  they', 'enter', 'longer  neuron']
# ['state action potential', 'activated', 'electrochemical potassium gradient']
# ['slow calcium spikes', 'provide', 'driving force']
# ['calcium spike calcium which', 'provides', 'then muscle contraction']
# ['Nearly cell membranes', 'maintain', 'animals voltage difference']
# ['interior', 'mV.', 'negative  voltage']
# ['neurons voltage fluctuations', 'take', 'frequently  form']
# ['up-and-down  cycle', 'takes', 'place']
# ['cells action potential', 'last', 'three  seconds']
# ['membrane  that', 'determined', 'it']
# ['which  ions', 'provide', 'contrast  channels']
# ['words  they', 'maintain', 'voltage difference']
# ['neurons  types', 'vary', 'cell ion dendrites']
# ['neuron action others', 'excitable', 'neuron action potentials']
# ['initial  axon', 'shown', 'cell body']
# ['long membrane nothing', 'has', 'cell']
# ['enough  depolarization', 'triggered', 'membrane potential']
# ['rise', 'stereotyped', 'same  amplitude']
# ['entire  process', 'takes', 'place']
# ['Many  types', 'emit', 'neurons action potentials']
# ['However  types', 'quieter', 'minutes action potentials']
# ['key  It', 'protein', 'one  conformation']
# ['membrane  that', 'creates', 'conformations  channel']
# ['however  relationship', 'probabilistic', 'membrane potential time delay']
# ['times membrane potential', 'switch', 'rate']
# ['ion channels ion state', 'capable', 'ion channels membrane potential']
# ['situations  rise', 'cause', 'further ion rise']
# ['ion channels ion that', 'determined', 'it']
# ['Several  types', 'exist', 'necessary action potential']
# ['studied  type', 'comprises', 'ion channels sodium channels']
# ['voltage NaV channel', 'stands', 'possible  states']
# ['channel', 'spends most', 'most']
# ['level  channel', 'shows', 'increased  probability']
# ['individual  channel', 'make', 'principle  transition']
# ['global  dynamics', 'difficult', 'major  voltage']
# ['parameters  that', 'approached', 'ion channel states']
# ['equations', 'modified', 'research starting point']
# ['sodium ion channels', 'open', 'entry']
# ['ion channels potassium ion that', 'followed', 'exit']
# ['where sodium potential', 'increases', 'cell sodium depolarization']
# ['action potential action potassium', 'close', 'cell']
# ['efflux', 'decreases', 'potassium ions membrane cell']
# ['However voltage voltage', 'exceeds', 'sodium current sodium dominates']
# ['positive runaway feedback', 'results', 'more sodium channels']
# ['which  neuron', 'referred to', 'action potentials']
# ['synaptic membrane which', 'property', 'sets action it']
# ['potassium ions', 'enter', 'equilibrium']
# ['few  ions', 'need', 'membrane']
# ['ions', 'exchanged', 'negligible action change']
# ['potassium pump potassium which', 'pumped', 'normal ion ratio']
# ['resulting  currents', 'trigger', 'domino-like neighboring propagation']
# ['axons action signal', 'excitable', 'axons action potentials']
# ['unmyelinated  patches', 'generate', 'Ranvier action signal']
# ['conduction  type', 'provides', 'favorable signal tradeoff']
# ['Depolarization', 'triggers', 'general axon release']
# ['These', 'thought', 'role']
# ['contradictory  measurements', 'disputed', 'entropy changes capacitance model']
# ['more  channels', 'added', 'membrane  decrease']
# ['mature  neuron', 'undergoes shorter', 'shorter  changes']
# ['P0 voltage they', 'have', 'constant voltage deflection']
# ['Immature  neurons', 'prone', 'more  depression']
# ['sodium channels sodium that', 'slower', 'action potential']
# ['initially action that', 'have', '60–90  ms']
# ['delayed  rectifier', 'increases', 'initial potassium channel strength']
# ['electrical  activity', 'play', 'cell  role']
# ['heart muscle which', 'support', 'cardiac action potential']
# ['which', 'neuron', 'simplest  mechanism']
# ['primary  function', 'projections', 'synaptic  signals']
# ['protrusions', 'designed', 'spines  neurotransmitters']
# ['They', 'have', 'high  concentration']
# ['spines', 'have', 'bulbous  protrusion']
# ['changes', 'ensures', 'less neighboring spines']
# ['dendritic  spine', 'see', 'exception  LTP']
# ['soma  which', 'extend', 'nucleus']
# ['channels', 'help', 'signals']
# ['region', 'characterized', 'high  concentration']
# ['signals  they', 'communicate', 'biochemical  support']
# ['fatty myelin that', 'wraps multiple', 'axon']
# ['insulation', 'prevents significant', 'faster signal speed']
# ['however  channels', 'has', 'however  restriction']
# ['membrane  which', 'are', 'insulation']
# ['Ranvier mini axon purpose', 'considered', 'significant signal decay']
# ['end  axon', 'loses', 'insulation']
# ['cell  that', 'area', 'neurotransmitters']
# ['which action potentials', 'helpful', 'methods']
# ['binding', 'opens various', 'various  types']
# ['opening', 'has', 'local  permeability']
# ['synapse', 'excitatory', 'membrane']
# ['it', 'inhibitory', 'membrane']
# ['fraction', 'reach', 'new action potential']
# ['excitatory  potentials', 'work', 'new action potential']
# ['free  flow', 'enables rapid', 'non-chemical-mediated  transmission']
# ['current action that', 'found', 'it']
# ['larger  currents', 'create larger', 'larger action potentials']
# ['ion channels ion which', 'coupled', 'ionic  permeabilities']
# ['combined  effects', 'excitatory', 'enough action potentials']
# ['olfactory receptor which', 'include', 'olfactory receptor neuron']
# ['action potentials action some', 'have', 'even  axon']
# ['potentials  either', 'convert', 'subsequent action potential']
# ['neurotransmitter  molecules', 'convert', 'incoming sound']
# ['third action which', 'produce', 'optic  nerve']
# ['such  They', 'depolarize', 'spontaneously axon hillock']
# ['cardiac pacemaker cells', 'provide', 'good  example']
# ['instance heart rate', 'altered', 'natural  rhythm']
# ['external  stimuli', 'cause', 'merely  timing']
# ['stage membrane potential', 'reaches', 'maximum']
# ['This', 'changes', 'permeability']
# ['Goldman equation Goldman change', 'changes', 'potential  Em']
# ['which', 'affects', 'further membrane potential']
# ['feedback  which', 'sets', 'possibility']
# ['internal  that', 'is', 'internal  gates']
# ['sodium channel sodium it', 'closes', 'also inactivation gate']
# ['which Andrew they', 'modeled', 'Nobel Prize']
# ['internal ion gates', 'considers', 'several ion assumptions']
# ['depolarization axon that', 'begins', 'Vm']
# ['concentrations  which', 'responsible', 'ions']
# ['inside', 'has', 'negative  charge']
# ['Na+  channels', 'drive', 'them']
# ['membrane sodium ions', 'opens', 'sodium channels']
# ['which', 'overwhelms', 'inward  current']
# ['more sodium which', 'causes', 'Vm']
# ['immediately Na+ channels', 'fire', 'just action one']
# ['which action potentials', 'stimulated', 'stronger action depolarization']
# ['slowly sodium channels', 'shuts', 'slowly sodium pores']
# ['This', 'lowers', 'potassium membrane voltage']
# ['voltage-sensitive potassium increase', 'opens voltage-sensitive', 'potassium permeability potassium Vm']
# ['permeability sodium Vm', 'cause', 'falling  phase']
# ['voltage-dependent potassium some', 'opens additional', 'voltage-dependent potassium channels']
# ['Hence  that', 'is', 'value membrane potential']
# ['stronger-than-usual action stimulus', 'followed', 'action potential']
# ['membrane potential membrane this', 'enter', 'rise']
# ['potassium channels potassium it', 'transitioned', 'thereby membrane rise']
# ['currents', 'spread', 'adjacent action sections']
# ['sufficiently  depolarization', 'provokes', 'similar action potential']
# ['blocked action segment', 'showed', 'block action potential']
# ['even  some', 'inactivate fast', 'A-type  currents']
# ['action potential action moves', 'ensures', 'frequency']
# ['just action potential', 'respond', 'range  part']
# ['neuronal  axons', 'covered', 'fast  transduction']
# ['multilamellar  that', 'membrane', 'axon']
# ['Myelin  sheath', 'reduces', 'saltatory membrane movement']
# ['example  axons', 'myelinated', 'nervous  system']
# ['Myelin', 'prevents', 'axon']
# ['action potentials action them', 'increases', 'conduction velocity']
# ['cytoplasm  which', 'carried', 'subsequent  node']
# ['apparent action hopping', 'provokes', 'Ranvier action potential']
# ['axons action potential', 'provokes', 'another']
# ['Myelin', 'has', 'important  advantages']
# ['1  myelination', 'increases', 'conduction velocity']
# ['giant frog axon', 'move', 'cross-sectional  area']
# ['ionic  currents', 'confined', 'metabolic  energy']
# ['nervous  system', 'advantage', '20  %']
# ['arriving  signal', 'long as possible', 'too action potential']
# ['propagated  signal', 'enough', 'enough action potential']
# ['Thus safety factor', 'high', 'conduction  transmission']
# ['diseases', 'degrade', 'saltatory conduction velocity']
# ['which  breakdown', 'sclerosis', 'coordinated  movement']
# ['Cable theory', 'developed', 'transatlantic telegraph cable']
# ['which length voltages', 'treated', '\\partial ^{2}V}{\\partial']
# ['τ', '=', 'time \\lambda dependence']
# ['unit time unit equilibration', 'transferred', '= equation CV']
# ['likewise  λ', 'increased', 'conduction velocity']
# ['synaptic  neurotransmitter', 'cause', 'synaptic  knobs']
# ['most ion axons', 'have', 'same  neurotransmitter']
# ['membrane calcium influx', 'opens voltage-sensitive', 'surface  contents']
# ['Electrical  synapses', 'synapses', 'presynaptic  cells']
# ['ionic  currents', 'cross', 'postsynaptic cell cell']
# ['ionic  currents', 'stimulate', 'postsynaptic action cell']
# ['transmission  they', 'allow', 'slow  diffusion']
# ['which  axon', 'junctions', 'special  case']
# ['muscle  which', 'reduces', 'degree']
# ['poisons', 'inactivate', 'control']
# ['which action membrane', 'potentials', 'extended action plateau']
# ['even sodium channels', 'due', 'calcium channels membrane voltage']
# ['cardiac action potential', 'plays', 'important  contraction']
# ['node pacemaker that', 'provide', 'heart']
# ['Muscular  action', 'potentials', 'action potential']
# ['membrane', 'result', 'voltage-sensitive sodium channels']
# ['1–3 conduction velocity', 'lasts', '2–4  ms']
# ['muscle', 'releases', 'tropomyosin']
# ['plants action which', 'published', 'first  measurements']
# ['This', 'makes', 'calcium precursor']
# ['full  depolarization', 'poses', 'cellular calcium depolarization']
# ['plants', 'use sodium-gated', 'sodium-gated Dionaea movements']
# ['how action they', 'done', 'movement']
# ['it', 'makes', 'action potential']
# ['plant  it', 'triggers', 'hair-like  mechanoreceptor']
# ['then action which', 'activates', '1.5  ms']
# ['Ultimately  this', 'causes', 'slightly Calcium it']
# ['Instead  it', 'requires', 'activation']
# ['it', 'throws', 'activation']
# ['time interval time it', 'reaches', 'Calcium trap']
# ['subsequent  release', 'involves', 'osmotic action loss']
# ['equal  amounts', 'neutral', 'other']
# ['interaction', 'appears', 'plants salinity conditions']
# ['cell', 'requires', 'movement']
# ['fully plant cell', 'differs', 'cell – cell transporter']
# ['organisms', 'seem', 'form']
# ['evolution conduction velocity', 'varied', 'action potential action much']
# ['evolution action potential', 'seems', 'evolutionary  advantages']
# ['110  which', 'rapid', '110  m/s']
# ['transmission distance action potential', 'has similar', 'similar  advantages']
# ['computation action that', 'form', 'central pattern generators']
# ['which', 'believed', 'voltage-gated four channels']
# ['functionality', 'likely', 'point communication mechanism']
# ['single-celled  bacteria', 'utilize', 'action potentials']
# ['study', 'required', 'action potentials action development']
# ['Lloyd Hodgkin Andrew Fielding who', 'carried', '1963 Nobel Prize']
# ['first  problem', 'solved', 'giant  axons']
# ['voltage clamp voltage which', 'addressed', 'key action source']
# ['that', 'design', 'zero  rate']
# ['Thus  current', 'reflection', 'Vm']
# ['voltage', 'included', 'use']
# ['micropipette electrode glass micropipette which', 'solved', 'axon  it']
# ['10 100 which', 'able', 'high input impedance']
# ['glass micropipette electrodes', 'became possible', 'electrical ion properties']
# ['discovery  they', 'awarded', 'Nobel Prize']
# ['ionic  channels', 'verified', 'discrete  states']
# ['Optical imaging technologies', 'developed', 'years action potentials']
# ['voltage-sensitive action potentials', 'recorded', 'voltage-sensitive  dyes']
# ['Neurotoxins Several Neurotoxins neurotoxins', 'designed', 'action potential']
# ['similarly sodium dendrotoxin', 'inhibits', 'voltage-sensitive potassium channel']
# ['other  they', 'serve', 'affinity chromatography affinity concentration']
# ['such  inhibitors', 'make effective', 'effective  neurotoxins']
# ['synthetic  which', 'insecticides', 'activation']
# ['Luigi Galvani Luigi who', 'observed', 'it']
# ['which pile he', 'stimulated', 'animal electricity']
# ['nervous  tissue', 'studied', 'century  propagation']
# ['cell membranes', 'followed', 'direct  current']
# ['German Emil du who', 'inspired', 'action potential']
# ['neurons Camillo they', 'used', 'neurons Camillo which']
# ['discoveries  Golgi', 'awarded', '1906 Nobel Prize']
# ['century  Golgi', 'argued', 'long-standing  controversy']
# ['action potential', 'advanced', 'hypothesis']
# ['particular  they', 'refined', 'crucial  role']
# ['membrane  that', 'made', 'action potential']
# ['which sodium they', 'line', 'action potential']
# ['ion channels ion that', 'correlated', 'properties']
# ['Erwin Neher Bert who', 'confirmed', 'patch clamping conductance states']
# ['century  researchers', 'beginning', 'structural  basis']
# ['membrane Nernst this', 'generalized', 'also Nernst equation']
# ['molecular  machines', 'solved', 'broader  view']
# ['action that', 'essential', 'stringent  test']
# ['Hodgkin – Huxley which', 'model', 'action potential']
# ['FitzHugh – Nagumo both', 'inspired several', 'coupled  ODEs']
# ['simple  models', 'fail', 'spike rate shape']
# ['dendrites  researchers', 'focused', 'neural  computation']
# ['proteins  that', 'simulate neuronal', 'microfilaments']
# ['diverse  range', 'believed', 'large  range']
# ['it', 'provides', 'order cell tissue']
# ['cell membrane cell which', 'anchored', 'endocytosis']
# ['It', 'produce', 'also  movement']
# ['It', 'plays', 'embryogenesis  healing']
# ['cells  which', 'traced', 'equivalent  proteins']
# ['Lastly  actin', 'plays', 'important  role']
# ['genes  that', 'caused', 'production']
# ['genes  that', 'cause muscular', 'muscular actin variations']
# ['make-up', 'related', 'related  actions']
# ['myosin  he', 'observed', 'myosin  that']
# ['further  discovery', 'unable', 'further  findings']
# ['novel muscle that', 'developed', 'substantial  amounts']
# ['myosin  it', 'dubbed', 'coagulation']
# ['well  Szent-Györgyi', 'called', 'actin']
# ['War II World War Szent-Gyorgyi', 'meant', 'work']
# ['inorganic  which', 'continued', 'bound  ATP']
# ['transformation', 'suggested', 'actin  role']
# ['year  model', 'proposed', 'experiments  co-crystallization']
# ['rhodamine conjugate rhodamine that', 'possible due', 'amino acid cys-374']
# ['actin dimers actin that', 'able', 'exact  model']
# ['Other  approaches', 'allowed', 'increasing synchrotron resolution']
# ['proteins  it', 'one', 'little']
# ['It', 'considered', 'optimised  structure']
# ['that', 'is', 'universal energy currency']
# ['However  ATP', 'required', 'structural  integrity']
# ['protein  which', 'able', 'wider  variety']
# ['which', 'villin', 'bundles  filaments']
# ['muscle fibres muscle it', 'comprises', '20  %']
# ['actin  that', 'is', '60 gene elements']
# ['called actin that', 'means', 'different  functions']
# ['mobility  which', 'means', 'projection']
# ['that  filaments', 'has', 'two  forms']
# ['parallel F-actin strands', 'rotate', '166  degrees']
# ['This', 'creates', 'double helix structure']
# ['Microfilaments', 'measure', '37  nm']
# ['each', 'indicate', 'globular  structure']
# ['catalysis  that', 'represents', 'former']
# ['energy metabolism protein that', 'motif', 'important  part']
# ['when  actin', 'functional', 'ADP']
# ['67  Å', 'has', 'molecular  mass']
# ['Primary  structureElzinga', 'determined', 'further peptide detail']
# ['It', 'contains', '374 amino acid residues']
# ['cysteine  which', 'alkaline', 'degree']
# ['names  both', 'have', 'comparable  depth']
# ['larger  domain', 'divided', 'III  residues']
# ['domains  “', 'referred to', 'subdomains “ ends']
# ['authors', 'call', 'subdomains']
# ['nucleotide  that', 'form', 'movements']
# ['protein  withdrawal', 'maintains', 'actin monomer']
# ['centres', 'suggested', 'role']
# ['domain  which', 'has', 'appearance']
# ['filamentous  that', 'F-actin', 'filamentous  structure']
# ['that', 'have', 'cryo-electron electron crystallization']
# ['27.5 Å subunit rotation data', 'talk', 'considerable  variability']
# ['again  this', 'appear', 'cofilin  angle']
# ['Å. X-ray diffraction studies', 'is less', 'precise contact points']
# ['monomers', 'make lateral', 'bodies  residues']
# ...
# ['pumped  blood', 'carries', 'metabolic  waste']
# ['two  reptiles', 'have', 'three  chambers']
# ['heart valves heart which', 'flows', 'backflow']
# ['sac  which', 'enclosed', 'small  amount']
# ['heart', 'pumps', 'blood']
# ['that', 'generate', 'contraction']
# ['circulation  which', 'receives', 'right  atrium']
# ['where  it', 'pumped', 'carbon dioxide']
# ['Exercise', 'increases', 'resting heart rate']
# ['Cardiovascular  diseases', 'have', 'chest  pain']
# ['Structure Location', 'situated', 'human  heart']
# ['double-membraned  sac', 'surrounds', 'heart']
# ['left  lung', 'smaller', 'border  heart']
# ['adult  heart', 'has', 'mass']
# ['Well-trained  athletes', 'have', 'larger  hearts']
# ['Chambers', 'has', 'four  chambers']
# ['tissue  this', 'made', 'structure']
# ['fibrous  which', 'forms', 'atria']
# ['conduction system conduction collagen', 'provides', 'electricity']
# ['interventricular  septum', 'separates', 'ventricles']
# ['when  they', 'thicker', 'greater  pressure']
# ['four  which', 'has', 'chambers']
# ['three  which', 'has', 'three  cusps']
# ['mitral  valve', 'lies', 'atrium  ventricle']
# ['bicuspid valve bicuspid its', 'known', 'two  cusps']
# ['when  they', 'prevent', 'valves']
# ['This', 'creates', 'place chordae them']
# ['three  which', 'has', 'three  cusps']
# ['cusps  which', 'flows', 'valve']
# ['three  which', 'has', 'three  cusps']
# ['right  atrium', 'receives', 'blood']
# ['muscles  which', 'smooth', 'prominent  ridges']
# ['endocardium moderator band', 'addition', 'crucial  role']
# ['It', 'arises', 'interior  space']
# ['which  it', 'tapers', 'blood']
# ['arteries trunk that', 'branches', 'blood']
# ['left  heart', 'has', 'left  atrium']
# ['left  atrium', 'receives', 'oxygenated  blood']
# ['left  atrium', 'has', 'outpouching']
# ['left  ventricle', 'thicker', 'force  blood']
# ['ventricle  left', 'has', 'trabeculae  carneae']
# ['left  ventricle', 'pumps', 'blood']
# ['coronary heart artery', 'carry', 'valve  blood']
# ['It', 'made', 'epithelium heart chambers']
# ['endocardium', 'play', 'also  contraction']
# ['muscle cells', 'elegant', 'inner figure figure']
# ['swirling  pattern', 'allows', 'blood']
# ['muscle muscle which', 'are', 'ability']
# ['muscle cells', 'make', 'bulk']
# ['discs  which', 'connected', 'rapid  response']
# ['syncytium  that', 'allow', 'blood']
# ['pacemaker cells', 'make', 'cells conduction system']
# ['few  which', 'smaller', 'limited  contractibility']
# ['Cardiac muscle tissue', 'has', 'cell rate contraction']
# ['They', 'include', 'MYH6']
# ['that', 'sac', 'heart']
# ['serous  that', 'lined', 'pericardial  surface']
# ['pericardium', 'present', 'chest  heart']
# ['Coronary circulation Heart tissue', 'needs', 'metabolic  wastes']
# ['circulation  which', 'achieved', 'arteries']
# ['arteries  which', 'receives', 'blood']
# ['coronary  artery', 'splits', 'shortly  aorta']
# ['It', 'does', 'this']
# ['coronary  artery', 'supplies', 'posterior  sections']
# ['coronary  artery', 'supplies', 'also  blood']
# ['large  that', 'vein', 'atrium  most']
# ['It', 'receives', 'cardiac  bottom']
# ['cardiac  veins', 'drain', 'front']
# ['smaller  they', 'collect', 'smaller  vessels']
# ['third  which', 'travel', 'section']
# ['left  vessel', 'joins', 'artery  atrium']
# ['Nerve supply heart', 'receives', 'nerve signals']
# ['nerves', 'act', 'heart rate']
# ['Sympathetic  nerves', 'influence', 'also  force']
# ['vagus  nerve', 'acts', 'trunk act heart rate']
# ['nerves  that', 'form', 'network']
# ['wandering  that', 'nerve', 'parasympathetic  stimulation']
# ['Sympathetic  stimulation', 'causes', 'release']
# ['depolarization repolarization which', 'shortens', 'thus repolarization rate']
# ['It', 'opens', 'chemical ion influx']
# ['Development heart', 'organ', 'functional  blood']
# ['plate  which', 'derives', 'cardiogenic  region']
# ['here  that', 'form', 'primitive heart tube']
# ['week heart tube', 'lengthens', 'S-shape']
# ['Further  development', 'include', 'formation']
# ['atrium  blood', 'allowed', 'lungs']
# ['septum primum septum that', 'closes', 'cardiac circulation pattern']
# ['embryonic heart rate', 'accelerates', 'peak  rate']
# ['Physiology Blood flow', 'functions', 'continuous heart flow']
# ['systemic  circulation', 'transports', 'deoxygenated carbon blood']
# ['right  heart', 'collects deoxygenated', 'deoxygenated  blood']
# ['Blood', 'collects', 'right  atrium']
# ['inferior vena cava', 'drains', 'blood']
# ['lungs  it', 'divides', 'capillaries']
# ['which  ventricles', 'period', 'blood']
# ['atria', 'relaxed', 'blood']
# ['When  ventricles', 'contract', 'diastole atria blood']
# ['ventricles', 'completed most', 'ventricles atria pump']
# ['aortic aorta valves', 'open', 'further  pressure']
# ['Blood', 'ejected', 'heart  pressure']
# ['This', 'calculated', 'stroke volume']
# ['So  CO', '=', 'SV HR']
# ['cardiac  output', 'L/min', 'average stroke volume']
# ['stroke volume', 'measured', 'normally  echocardiogram']
# ['less  preload', 'is', 'ventricles']
# ['much  heart', 'influenced', 'blood']
# ['strength', 'controls', 'muscle contractions stroke volume']
# ['adrenaline  inotropes', 'decrease', 'contraction calcium channel blockers']
# ['that', 'created', 'heart heart muscle']
# ['which', 'part', 'signal']
# ['signal', 'travels', 'right bundle branches']
# ['tissue Purkinje which', 'carried', 'electric  charge']
# ['Cells', 'do', 'node action potential']
# ['they', 'have', 'negative  charge']
# ['rapid  influx', 'causes', 'sodium ions sodium charge']
# ['potassium', 'close', 'it']
# ['only  it', 'has', 'high  charge']
# ['potassium', 'close', 'cell']
# ['This', 'causes', 'resting  charge']
# ['process', 'close', '−60  mV']
# ['Calcium', 'plays', 'critical  role']
# ['when plateau they', 'means', 'positive  charge']
# ['Calcium ions', 'combine', 'protein troponin relaxation']
# ['Influences', 'influenced', 'resting heart rate']
# ['cardiovascular  centres', 'control', 'sympathetic  influences']
# ['reflexes carbon help', 'receive', 'blood flow']
# ['cardiac baroreceptor firing centers', 'decrease sympathetic', 'parasympathetic  stimulation']
# ['pressure  rate', 'increase sympathetic', 'parasympathetic baroreceptor firing stimulation']
# ['specialized  baroreceptors', 'stretches', 'walls']
# ['cardiac blood center', 'responds', 'parasympathetic heart rate']
# ['Low  oxygen', 'stimulate', 'high carbon firing']
# ['Exercise levels', 'affect', 'all heart rate']
# ['High  levels', 'increase', 'hormones heart rate']
# ['low blood oxygen', 'increase', 'low blood it']
# ['which', 'cause', 'diseases']
# ['medical  professionals', 'involved', 'diseases']
# ['coronary  severe', 'narrow', 'blood flow']
# ['then  patient', 'experience', 'symptoms']
# ['Severe  narrowings', 'cause chest', 'chest  pain']
# ['thin  covering', 'rupture', 'fatty  centre']
# ['case  clot', 'form', 'myocardial heart infarction']
# ['case  this', 'cause cardiac', 'cardiac  arrest']
# ['Obesity', 'increase', 'all blood atherosclerosis']
# ['which  heart', 'defined', 'enough  demands']
# ['Patients', 'experience', 'heart failure heart breathlessness']
# ['Heart failure', 'result', 'diseases end heart']
# ['common  causes', 'include various', 'various  cardiomyopathies']
# ['condition', 'affect', 'right  ventricle']
# ['Patients', 'risk', 'dangerous heart rhythm disturbances']
# ['Cardiomyopathies Cardiomyopathies', 'diseases', 'muscle']
# ['heart', 'cause', 'dilated  cardiomyopathy']
# ['blood', 'allow', 'direction  it']
# ['Diseased heart valves', 'have', 'valve  blood']
# ['Valvular heart disease', 'cause', 'abnormal  heart']
# ['Abnormal heart rhythms', 'asymptomatic', 'palpitations']
# ['types', 'increase', 'long term risk']
# ['re-entrant AV others', 'take many', 'heart  arise']
# ['which', 'become inflamed', 'heart']
# ['chest  that', 'causes chest', 'chest  pain']
# ['Pericardial  effusions', 'occur secondary', 'frequently kidney symptoms']
# ['which', 'compress', 'tamponade  breathlessness']
# ['Fluid', 'removed', 'diagnosis  syringe']
# ['heart that', 'include', 'heart  hole']
# ['main blood that', 'include', 'e.g.  coarctation']
# ['that', 'seen', 'one  part']
# ['oxygen  that', 'allow', 'blood']
# ['transposition', 'picked', 'arteries  breathlessness']
# ['minor  forms', 'remain undetected', 'only heart themselves']
# ['invasive  procedures', 'play', 'also  role']
# ['cardiac Examination examination', 'includes', 'chest']
# ['signs  that', 'involves', 'assessment']
# ['blood pressure', 'taken', 'invasive  measurement']
# ['healthy  hearts', 'sounds', 'audible heart sounds']
# ['two  valves', 'consists', 'slight  difference']
# ['also  these', 'present', 'rise']
# ['S3', 'indicates', 'usually  increase']
# ['combined  presence', 'give', 'quadruple  gallop']
# ['tests Blood tests', 'play', 'important  role']
# ['It', 'released', '4–6 hours']
# ['significant  rise', 'taken', 'often  one']
# ['frequently blood it', 'provides', 'creatine kinase creatine information']
# ['general health that', 'taken', 'general health factors']
# ['metabolic blood that', 'include', 'disturbances']
# ['Fasting  lipids', 'ordered', 'often cholesterol status']
# ['body surface it', 'possible', 'electrical  activity']
# ['ECG', 'test', 'bedside placement']
# ['ground).There', 'produces', '12  lead']
# ['that', 'create', 'current']
# ['negative  lead', 'depends', 'positive  deflection']
# ['ECG', 'tool', 'insufficient blood supply']
# ['suspected rhythm abnormality', 'worn', 'abnormality']
# ['Several imaging methods', 'used', 'anatomy']
# ['echocardiogram', 'ultrasound', 'heart  function']
# ['much  blood', 'include', 'valves  stenosis']
# ['Ejection fraction', 'obtained', 'then  volume']
# ['where  this', 'involves', 'injection']
# ['CT scans', 'help', 'imaging  size']
# ['major blood which', 'useful', 'heart']
# ['Treatment Diseases', 'treated', 'heart']
# ['when heart muscle artery', 'treated', 'myocardial  infarction']
# ['preventative calcium channel treatments', 'include', 'aspirin lifestyle smoking']
# ['narrowed heart arteries', 'treated', 'blood  obstruction']
# ['which  narrowings', 'performed', 'stent artery open']
# ['whereby blood vessel', 'performed', 'mammary  blood']
# ['that', 'require', 'abnormally  surgery']
# ['This', 'performed', 'damaged heart valve']
# ['circumstances tricuspid valves', 'repaired', 'surgically  need']
# ['percutaneously  that', 'treated', 'many  similarities']
# ['Transcatheter aortic valve replacement', 'used', 'high  risk']
# ['Cardiac  arrhythmias', 'treated', 'antiarrhythmic heart drugs']
# ['These', 'work', 'nervous sodium channel effect']
# ['stroke  risk', 'reduced', 'anticoagulants']
# ['treatment option', 'ablation', 'arrhythmia']
# ['tissue  that', 'passed', 'arrhythmia']
# ['abnormal  tissue', 'damaged', 'further heart rhythm disturbances']
# ['invasive catheter arrhythmias', 'treated', 'open  surgery']
# ['electric  shock', 'used', 'heart']
# ['Cardiac  devices', 'required', 'also  arrhythmias']
# ['skin  that', 'leads', 'slow heart rhythms']
# ['Implantable  defibrillators', 'used', 'rapid heart rhythms']
# ['dangerous heart racing', 'monitor', 'automatically  heart']
# ['Heart failure', 'medication', 'underlying  cause']
# ['that', 'include', 'resynchronisation therapy pumping efficiency']
# ['which', 'implanted', 'own pumping ability']
# ['blood  Hippocrates', 'considered', 'blood']
# ['they', 'noted', 'pump  dilation']
# ['He', 'discovered', 'also heart valves']
# ['Greek physician Galen', 'knew', 'brighter blood blood']
# ['body  it', 'concluded', 'heat']
# ['diastole  blood', 'pump', 'blood']
# ['academic  doctrines', 'continued', 'academic  community']
# ['authorities  he', 'questioned', 'some']
# ['Christianismi Restitutio Christianismi blood', 'wrote', 'Christianismi Restitutio Christianismi that']
# ['William Harvey physician William book', 'came', 'systemic  circulation']
# ['English  who', 'physiologist', 'also  heart']
# ['heart Sunao Tawara', 'recognized', 'Reizleitungssystem des Säugetierherzens']
# ['discovery', 'prompted', 'node Arthur Keith']
# ['electrocardiogram  inventor', 'form', 'Nobel Prize']
# ['This', 'marked', 'surgery  attention']
# ['American surgeon Norman Shumway', 'credited', 'efforts transplantation techniques']
# ['United States United it', 'surpassed infectious', 'infectious  disease']
# ['ongoing Framingham Heart Study', 'shed', 'light']
# ['heart failure heart disease', 'continues', 'year 30 diagnosis']
# ['heart', 'symbol', 'religions  temple']
# ['expressions  which', 'evidenced', 'ib']
# ['where nether it', 'conceived', 'evidence']
# ['Maat  which', 'weighed more', 'ideal  standard']
# ['it', 'devoured', 'just  afterlife']
# ['Chinese  character', 'derives', 'heart heart chambers']
# ['Chinese  word', 'takes', 'metaphorical  meanings']
# ['heart', 'associated', 'six  organs']
# ['Sanskrit  it', 'mean', 'anatomical  seat']
# ['classical  philosophers', 'considered', 'often  brain']
# ['physician Galen physician who', 'due', 'also  seat']
# ['heart', 'played', 'also  role']
# ['Jesus Christ Jesus which', 'consider', 'prominence']
# ['tradition', 'influenced', 'development']
# ['that', 'ancient', 'explicit']
# ['little Renaissance that', 'theme', 'little heart symbols']
# ['Many  recipes', 'combined', 'them']
# ['Australian  recipe', 'braised', 'stuffed beef heart']
# ['Other  animals', 'Vertebrates', 'size']
# ['which', 'continuous', 'beat']
# ['systems Adult systems amphibians', 'have', 'circulatory  system']
# ['lungs  which', 'allows', 'oxygenated  blood']
# ['fact  snakes', 'different', 'elongated  body']
# ['that', 'tend', 'higher blood pressure']
# ['rule  which', 'crocodiles', 'four-chambered  heart']
# ['spongy  nature', 'seem', 'ventricle  more']
# ['valve  that', 'replaced', 'two  bloodstreams']
# ['four-chambered  heart', 'thought', 'complete  separation']
# ['what', 'have', 'one  it']
# ['sometimes  what', 'has', 'entry compartments']
# ['primitive  heart', 'considered', 'four-chambered  heart']
# ['sinus which', 'venosus', 'deoxygenated  blood']
# ['main pumping action', 'flows', 'place']
# ['conus  which', 'arteriosus', 'several  blood']
# ['two  chambers', 'delivers', 'instead  S-shape']
# ['Invertebrates Arthropods', 'have', 'circulatory  system']
# ['blood', 'permeates', 'slowly  heart']
# ['heart', 'pumps', 'then  blood']
# ['muscular  that', 'tube', 'length']
# ['which', 'haemolymph', 'pigment copper-based pigment haemocyanin']
# ['circulatory  system', 'used', 'much  veins']
# ['animals  that', 'travels', 'two gill hearts']
# ['systemic  heart', 'have', 'two  atria']
# ['central  which', 'have', 'aorta  blood']
# ['This', 'suggests', 'presence']
# ['article', 'Notes', 'text']
# ['– NIH Atlas', 'discussion', 'human development Animal Heart']
# ['Arterioles', 'have muscular', 'muscular  walls']
# ['endothelium  which', 'promoted', 'biochemical  reaction']
# ['pressure Blood pressure', 'result', 'cardiac  output']
# ['decreased  velocity', 'increases', 'capillaries blood pressure']
# ['This', 'induces', 'gas']
# ['when  blood', 'occurs', 'venules']
# ['Arterioles', 'receive autonomic', 'order system diameter']
# ['Retinal  vessels', 'lack', 'sympathetic  innervation']
# ['number', 'influence', 'arteriole  tone']
# ['which', 'increase total', 'peripheral blood resistance']
# ['example blood which', 'targeted', 'arterioles calcium relaxation']
# ['This', 'decreases', 'systemic  pressure']
# ['which', 'arteriole', 'capillary  circulation']
# ['muscle cells heart muscle which', 'caused', 'cells']
# ['proteins  many', 'composed', 'harmful  mutations']
# ['right  cases', 'type', 'right  ventricle']
# ['associated  arrhythmias', 'characterized', 'free  wall']
# ['currently  ACM', 'thought', 'dysplasia']
# ['513 \u200a ACM', 'found', 'also  integrity']
# ['30–50  %', 'seen', 'familial  distribution']
# ['Signs', 'have', 'significant  abnormalities']
# ['abnormal heart which', 'rhythms', 'cardiomyopathy  form']
# ['50  %', 'test positive', 'ACM  positive']
# ['mutations', 'showed', 'intercalated point disc']
# ['mutations', 'shown', 'DES gene desmin DES ACM']
# ['Different DES mutations', 'cause', 'abnormal  aggregation']
# ['Apoptosis', 'appears', 'large cell role']
# ['recent  cohorts', 'thought', 'many  cases']
# ['disease process', 'starts', 'region  way']
# ['it', 'late', 'poor  prognosis']
# ['This', 'involves', 'partial  substitution']
# ['Fibro-fatty  infiltration', 'involves', 'fibro-fatty  replacement']
# ['regions', 'include', 'RV inflow tract']
# ['Recently  studies', 'identified strenuous', 'strenuous  exercise']
# ['conclusively  subpopulations', 'demonstrated', 'earlier  onset']

# %%
# for enitity_relations in ner:
#     print(enitity_relations)


#Add method to remove special characters

# %%
#Ner Models
print("jnlpba-labels",nlp_jnlpba.pipe_labels['ner'])
print("craft-labels",nlp_craft.pipe_labels['ner'])
print("bionlp-labels",nlp_bionlp.pipe_labels['ner'])
print("Bc5cdr-labels",nlp_bc5cdr.pipe_labels['ner'])
# Out:
# jnlpba-labels ['CELL_LINE', 'CELL_TYPE', 'DNA', 'PROTEIN', 'RNA']
# craft-labels ['CHEBI', 'CL', 'GGP', 'GO', 'SO', 'TAXON']
# bionlp-labels ['AMINO_ACID', 'ANATOMICAL_SYSTEM', 'CANCER', 'CELL', 'CELLULAR_COMPONENT', 'DEVELOPING_ANATOMICAL_STRUCTURE', 'GENE_OR_GENE_PRODUCT', 'IMMATERIAL_ANATOMICAL_ENTITY', 'MULTI_TISSUE_STRUCTURE', 'ORGAN', 'ORGANISM', 'ORGANISM_SUBDIVISION', 'ORGANISM_SUBSTANCE', 'PATHOLOGICAL_FORMATION', 'SIMPLE_CHEMICAL', 'TISSUE']
# Bc5cdr-labels ['CHEMICAL', 'DISEASE']

# %%
print("Bc5cdr-labels",nlp_bc5cdr.pipe_labels['ner'])
# Out:
# Bc5cdr-labels ['CHEMICAL', 'DISEASE']

# %%
#Entity-Ruler
ruler = nlp_bc5cdr.add_pipe("entity_ruler",after="ner")

# %%
print("Bc5cdr-labels",nlp_bc5cdr.pipe_labels['ner'])
# Out:
# Bc5cdr-labels ['CHEMICAL', 'DISEASE']

# %%
#Custom Entities and Labels
pattern = [
    #CVD
    {"label":"CVD","pattern":"cardiomyopathies"},
    {"label":"CVD","pattern":"angina"},
    {"label":"CVD","pattern":"arrhythmia"},
    {"label":"CVD","pattern":"dilated cardiomyopathy"},
    {"label":"CVD","pattern":"hypertrophic cardiomyopathy"},
    {"label":"CVD","pattern":"mitral regurgitation"},
    {"label":"CVD","pattern":"mitral valve prolapse"},
    {"label":"CVD","pattern":"pulmonary stenosis"},
    {"label":"CVD","pattern":"aortic stenosis"},
    {"label":"CVD","pattern":"atrial fibrillation"},
    {"label":"CVD","pattern":"peripheral artery disease"},
    {"label":"CVD","pattern":"aneurysm"},
    {"label":"CVD","pattern":"atherosclerosis"},
    {"label":"CVD","pattern":"raynaud’s disease"},
    {"label":"CVD","pattern":"peripheral venous disease"},
    {"label":"CVD","pattern":"ischemic stroke"},
    {"label":"CVD","pattern":"venous blood clots"},
    {"label":"CVD","pattern":"buerger’s disease"},
    
    #Drug
    {"label":"Drug","pattern":"statins"},
    {"label":"Drug","pattern":"aspirin"},
    {"label":"Drug","pattern":"clopidogrel"},
    {"label":"Drug","pattern":"warfarin"},
    {"label":"Drug","pattern":"beta-blockers"},
    {"label":"Drug","pattern":"ace inhibitors"},
    {"label":"Drug","pattern":"apixaban"},
    {"label":"Drug","pattern":"dabigatran"},
    {"label":"Drug","pattern":"edoxaban"},
    {"label":"Drug","pattern":"heparin"},
    {"label":"Drug","pattern":"rivaroxaban"},
    {"label":"Drug","pattern":"dipyridamole"},
    {"label":"Drug","pattern":"prasugrel"},
    {"label":"Drug","pattern":"ticagrelor"},
    
    #Symptoms
    {"label":"Symptoms","pattern":"chest pain"},
    {"label":"Symptoms","pattern":"chest tightness"},
    {"label":"Symptoms","pattern":"chest pressure"},
    {"label":"Symptoms","pattern":"chest discomfort"},
    {"label":"Symptoms","pattern":"shortness of breath"},
    {"label":"Symptoms","pattern":"numbness"},
    {"label":"Symptoms","pattern":"coldness"},
    {"label":"Symptoms","pattern":"neck pain"},
    {"label":"Symptoms","pattern":"jaw pain"},
    {"label":"Symptoms","pattern":"throat pain"},
    {"label":"Symptoms","pattern":"upper abdomen pain"},
    {"label":"Symptoms","pattern":"back pain"},
    
    #Parts of the human heart
    {"label":"Parts of the human heart","pattern":"superior vena cava"},
    {"label":"Parts of the human heart","pattern":"inferior vena cava"},
    {"label":"Parts of the human heart","pattern":"pulmonary vein"},
    {"label":"Parts of the human heart","pattern":"right atrium"},
    {"label":"Parts of the human heart","pattern":"pulmonary valve"},
    {"label":"Parts of the human heart","pattern":"tricuspid valve"},
    {"label":"Parts of the human heart","pattern":"right ventricle"},
    {"label":"Parts of the human heart","pattern":"aorta"},
    {"label":"Parts of the human heart","pattern":"pulmonary artery"},
    {"label":"Parts of the human heart","pattern":"left atrium"},
    {"label":"Parts of the human heart","pattern":"mitral valve"},
    {"label":"Parts of the human heart","pattern":"aortic valve"},
    {"label":"Parts of the human heart","pattern":"left ventricle"},
    
    #Causes
    {"label":"Causes","pattern":"family history"},
    {"label":"Causes","pattern":"smoking"},
    {"label":"Causes","pattern":"poor diet"},
    {"label":"Causes","pattern":"high blood pressure"},
    {"label":"Causes","pattern":"high blood cholesterol levels"},
    {"label":"Causes","pattern":"age"},
    {"label":"Causes","pattern":"sex"},
    {"label":"Causes","pattern":"stress"},
    {"label":"Causes","pattern":"obesity"},
    {"label":"Causes","pattern":"physical inactivity"},
    {"label":"Causes","pattern":"stress"},
    {"label":"Causes","pattern":"poor dental health"},
    
    #Complications
    {"label":"Complications","pattern":"heart failure"},
    {"label":"Complications","pattern":"heart attack"},
    {"label":"Complications","pattern":"stroke"},
    {"label":"Complications","pattern":"aneurysm"},
    {"label":"Complications","pattern":"peripheral artery disease"},
    {"label":"Complications","pattern":"sudden cardiac arrest"},

    #Prevention
    {"label":"Prevention","pattern":"healthy weight"},
    {"label":"Prevention","pattern":"manage stress"},
    {"label":"Prevention","pattern":"hygiene"},
    {"label":"Prevention","pattern":"exercise"},
    {"label":"Prevention","pattern":"diet"},
    ]

# %%
for i in range(len(pattern)):
    s = pattern[i]['pattern']
    s_cap = s.upper()
    s_fcap = s.capitalize()
    pattern.append({"label":pattern[i]['label'],"pattern":s_cap})
    pattern.append({"label":pattern[i]['label'],"pattern":s_fcap})

# %%
ruler.add_patterns(pattern)

doc_ner1 = nlp_bc5cdr(text)
doc_ner2 = nlp_jnlpba(text)
doc_ner3 = nlp_craft(text)
doc_ner4 = nlp_bionlp(text)

# %%
for ents in doc_ner1.ents:
    print(ents)
# Out:
# oxygen
# carbon dioxide
# right atrium
# oxygen
# right atrium
# inferior venae cavae
# right ventricle
# oxygen
# carbon dioxide
# left atrium
# left ventricle
# aorta
# circulation−where
# oxygen
# carbon dioxide
# heart beats
# Exercise
# Cardiovascular diseases
# death
# deaths
# coronary artery disease
# stroke
# smoking
# exercise
# cholesterol
# high blood pressure
# diabetes
# Cardiovascular diseases
# chest pain
# shortness of breath
# heart disease
# diseases of the heart
# aorta
# pulmonary trunk
# cardiac notch
# exercise
# heart muscle
# right atrium
# left atrium
# right atrium
# right ventricle
# left atrium
# left ventricle
# right atrium
# right ventricle
# tricuspid valve
# tricuspid valve
# mitral valve
# left atrium
# left ventricle
# pulmonary valve
# pulmonary artery
# aortic valve
# aorta
# aorta
# right atrium
# right ventricle
# tricuspid valve
# right atrium
# veins
# right atrium
# inferior vena cava
# right atrium
# depression
# right atrium
# depression
# right atrium
# right ventricle
# tricuspid valve
# right ventricle
# cardiac muscle
# cardiac muscle
# right ventricle
# right ventricle
# inferior papillary muscle
# right ventricle
# pulmonary trunk
# pulmonary valve
# pulmonary trunk
# left atrium
# left ventricle
# mitral valve
# left atrium
# left atrium
# right atrium
# left atrium
# left atrium
# left ventricle
# mitral valve
# left ventricle
# right ventricle
# left ventricle
# aortic valve
# aorta
# aortic valve
# heart muscle
# endothelins
# cardiac muscle—a
# involuntary striated muscle
# cardiac muscle
# cardiac muscle
# Cardiac muscle
# muscle contraction
# myosin
# tropomyosin
# LDB3
# lubricate
# lubricate
# infection
# oxygen
# heart muscle's relaxation
# aortic valve
# aorta
# left ventricle
# left ventricle
# right atrium
# right ventricle
# left ventricle
# right atrium
# cardiac vein
# left atrium
# left ventricle
# small cardiac veins
# right ventricle
# right atrium
# left ventricle
# pulmonary artery
# left atrium
# right atrium
# right ventricle
# aorta
# norepinephrine
# noradrenaline
# sodium
# calcium
# Norepinephrine
# right atrium
# left atrium
# depression
# right atrium
# 165–185
# carbon dioxide
# oxygen
# oxygen
# carbon dioxide
# veins
# left atrium
# superior vena cava
# right atrium
# inferior vena cava drains the blood
# superior vena cava
# inferior vena cava
# right atrium
# right atrium
# right atrium
# tricuspid valve
# right ventricle
# right ventricle
# tricuspid valve
# pulmonary valve
# pulmonary trunk
# carbon dioxide
# oxygen
# left atrium
# left ventricle
# mitral valve
# aorta
# aortic valve
# aorta
# oxygen
# carbon dioxide
# aorta
# pulmonary artery
# mitral and tricuspid valves
# mitral and tricuspid valves
# aorta
# right atrium
# left atrium
# aorta
# mitral and tricuspid valves
# stroke
# stroke
# stroke
# 4.0–8.0
# stroke
# sex
# stenosis
# heart muscle
# stroke
# adrenaline
# noradrenaline
# dopamine
# calcium
# right atrium
# superior vena cava
# right atrium
# left atrium
# right atrium
# right atrium
# left ventricle
# heart muscle
# right atrium
# sodium
# sodium
# calcium
# potassium
# potassium
# calcium
# calcium
# potassium
# potassium
# potassium
# sodium
# potassium
# Calcium
# Calcium
# cardiac muscle
# exercise
# oxygen
# carbon dioxide
# aorta
# carbon dioxide
# oxygen
# carbon dioxide
# Exercise
# age
# epinephrine
# norepinephrine
# calcium
# potassium
# sodium
# oxygen
# dehydration
# Diseases Cardiovascular diseases
# diseases of the heart
# death
# cardiovascular disease
# Heart disease
# death
# deaths
# diseases of the heart
# Ischaemic heart disease Coronary artery disease
# ischaemic heart disease
# atherosclerosis
# fatty deposits
# atherosclerotic
# stenosis
# narrowings
# chest pain
# angina
# breathlessness
# exercise
# atherosclerotic
# thrombus
# heart muscle
# myocardial infarction
# heart attack
# unstable angina
# cardiac arrest
# heart failure
# ischaemic heart disease
# hypertension
# heart failure
# ACE inhibitors and mineralocorticoid receptor antagonists).In
# heart failure
# heart failure
# Galen
# Galen believed the arterial blood
# left ventricle
# pulmonary artery
# left ventricle
# Galen
# Galen
# Galen's beliefs of the heart
# De humani corporis
# magnum
# attacks
# Otto
# 1865–1944
# Tawara's discovery of the atrioventricular
# heart disease
# infectious disease
# death
# deaths
# diet
# exercise
# aspirin
# ACE inhibitors
# chronic heart failure
# death
# xīn
# 神
# Hrd
# Galen
# heart-soul (tona-tiuh):
# pulsating"".In
# beef, pork,
# grilled or braised
# anticuchos de corazón, barbecued beef
# spice
# braised stuffed beef heart
# heart is stewed,
# braised
# right atrium
# pulmonary artery
# aorta
# conus arteriosus
# aorta
# aorta
# aorta
# aorta
# aorta
# aorta
# conus arteriosus
# right atrium
# oxygen
# oxygen
# Oxygen
# small muscular
# aorta
# Nicki R. Colledge
# 129–134
# cardiac muscle alpha
# muscle contraction
# alpha-actinin
# amino acids (Asp4Glu, Glu5Asp
# Leu301Met
# amino
# Myosin
# myosin
# amino acid
# Dilated Cardiomyopathy
# E101K
# Hypertrophic Cardiomyopathy
# Left Ventricular Noncompaction
# atrial septal defects
# COPaKB
# Hypertrophic Cardiomyopathy
# \displaystyle {\dot {u}}=0}    (
# de-inactivate
# potassium
# potassium
# K+
# potassium
# potassium
# tachycardia
# cardiac arrhythmias
# atrial fibrillation
# sodium
# sodium ions
# sodium
# potassium
# sodium
# potassium
# potassium
# potassium
# sodium
# potassium
# sodium
# sodium
# sodium
# potassium
# sodium
# potassium
# heart beats
# acetylcholine
# noradrenaline
# AV-nodal reentrant tachycardia
# AVNRT
# abnormal fast heart rhythm
# supraventricular tachycardia
# AV nodal reentrant tachycardia
# supraventricular tachycardia
# palpitations
# AVNRT
# right atrium
# Wolff-Parkinson-White syndrome
# WPW syndrome
# atrioventricular reciprocating tachycardia
# AVRT
# AVNRT
# right atrium
# WPW syndrome
# AVRT
# AVNRT
# palpitations
# palpitations
# tricuspid valve
# anxiety
# panic attacks
# dizziness
# coronary artery disease
# atherosclerosis
# chest pain
# angina
# pain
# pressure-like
# palpitations
# palpitations
# arrhythmia
# AVNRT
# 140
# right atrium
# tricuspid valve
# AVNRT
# AVNRT
# AVNRT
# AVNRT
# AVNRT
# AVNRT
# atypical AVNRT
# heart block
# palpitations
# palpitations
# AVNRT
# abnormal fast heart rhythms
# atrial fibrillation
# atrial flutter
# sinus tachycardia
# ventricular tachycardia
# tachyarrhythmias
# Wolff-Parkinson-White syndrome
# palpitations
# AVNRT
# potassium
# calcium
# magnesium
# AVNRT
# myocardial infarction
# heart attack
# AVNRT
# chest pain
# AVNRT
# tachycardia
# Arrhythmia
# supraventricular tachycardia
# AVNRT
# AVNRT
# AVNRT
# adenosine
# non-dihydropyridine calcium
# verapamil
# diltiazem
# adenosine
# flecainide
# amiodarone
# heart failure
# coma
# AVNRT
# shock
# Arrhythmia
# AVNRT
# arrhythmia
# calcium
# flecainide
# amiodarone
# digoxin
# EP
# AVNRT
# AVNRT
# adrenaline
# epinephrine
# cardiac arrests
# allergic reactions
# adrenaline
# Adrenaline
# adrenaline
# epinephrine
# epinephrine
# adrenaline
# adrenaline
# adrenaline
# adrenaline
# epinephrine
# adrenaline
# adrenaline
# Adrenaline
# adrenaline
# sensation-seeking behavior
# substance abuse
# sex
# adrenaline
# stress
# adrenaline
# stress
# adrenaline
# adrenaline
# adrenaline
# Adrenaline
# Epinephrine
# sodium ions
# sodium
# sodium
# sodium ions
# Potassium
# potassium
# sodium
# calcium
# calcium-based
# calcium
# sodium
# sodium
# calcium
# ions
# sodium
# calcium
# sodium
# sodium
# sodium ions
# sodium
# sodium
# potassium
# potassium
# sodium
# sodium
# potassium
# potassium
# potassium
# sodium
# sodium
# sodium
# sodium
# ions
# sodium
# potassium
# sodium ions
# potassium
# sodium
# potassium
# Calcium
# depression
# calcium
# sodium
# calcium
# sodium
# calcium
# sodium
# potassium
# sodium
# potassium
# sodium
# potassium
# sodium
# sodium
# peripheral nervous system)
# sodium
# sodium
# sodium
# cations
# sodium
# chloride ions
# potassium
# K+
# K+
# ions
# potassium
# potassium
# EK ≈ –75
# sodium
# potassium
# potassium
# sodium
# sodium
# potassium
# sodium
# sodium
# sodium
# sodium
# sodium
# sodium
# −30
# sodium
# sodium
# sodium
# sodium
# sodium
# sodium
# potassium
# potassium
# potassium
# sodium
# potassium
# potassium
# potassium
# calcium
# potassium
# potassium
# potassium
# sodium
# potassium
# sodium
# sodium
# potassium
# potassium
# sodium
# potassium
# potassium
# sodium
# sodium
# peripheral nervous system
# human nervous system
# diseases degrade myelin and impair saltatory conduction
# multiple sclerosis
# \displaystyle \tau {\frac {\partial V}{\partial t}}=\lambda ^{2}{\frac {\partial ^{2}V}{\partial x^{2}}}-V}   where V(x, t
# calcium
# calcium
# tetanus
# botulism
# acetylcholine
# acetylcholine
# acetylcholine
# sarin
# tabun
# diazinon
# potassium
# calcium
# sodium
# anomalies
# congenital mutation or injury—
# arrhythmias
# quinidine
# lidocaine
# verapamil
# sodium
# potassium
# calcium
# tropomyosin
# sodium
# calcium
# calcium
# chloride ions
# potassium
# calcium
# chloride ions
# diet
# Calcium
# calcium
# Calcium
# potassium
# salt
# KCl
# sodium
# potassium
# after-hyperpolarization
# calcium
# potassium
# potassium
# ATP
# hydrogen
# cross-purposed
# biofilm
# fine
# Ca2
# Sakmann
# Tetrodotoxin
# saxitoxin
# sodium
# dendrotoxin
# potassium
# permethrin
# sodium
# ions
# sodium
# sodium
# potassium
# Sakmann
# David E. Goldman to the eponymous
# sodium
# potassium
# X-ray crystallography
# neuronal and cardiac action potentials at SourceForge.net
# muscle contraction
# actins
# tropomyosin
# cancer
# nucleotide
# illnesses and diseases
# infection
# muscular diseases
# deafness
# myosin
# myosin
# ATP
# myosin
# myosin
# myosin
# ATP
# nucleotide
# ADP
# phosphate
# amino acid
# G-actin
# ADP
# G-actin
# rhodamine
# amino acid
# amino acid
# ATP
# ATP
# Myosin
# calcium
# stress
# MreB
# Ta0583
# G-actin
# adenosine
# ATP
# adenosine
# ADP
# Mg2
# ATP-G-Actin
# G-actin
# X-ray crystallography
# ATP
# Mg2
# ADP
# phosphate
# triphosphate
# G-actin
# ADP
# ATP
# ATP
# 41,785 Da
# structureElzinga
# amino acid
# aspartate
# amino
# phenylalanine
# cysteine
# Nτ-methylhistidine
# structuresThe
# β-α-β
# adenosine
# adenosine
# Mg2
# nucleotide
# calcium
# amino acids Asp11
# nucleotide
# divalent
# D-loop
# nucleotide
# °
# Å
# Å
# Å
# Å
# hydrophobic
# MreB.The
# ATP
# myosin
# tannic acid
# myosin
# myosin
# myosin
# myosin II
# G-actin
# ATP
# ATP
# tropomyosin
# tropomyosin
# actin-myosin
# muscular contraction
# tropomyosin
# troponins
# troponin
# chaperonins
# GroEL
# tubulin
# tubulin
# tubulin
# PFD4
# 170–198
# chaperonin
# ATP
# AMP-PNP
# chaperonin
# CAP
# ATP
# Pi
# ADP
# ATP
# glutamic acid
# ATP
# γ-phosphate
# nucleotide
# slowness
# amino acid
# MreB
# Arp2/3
# G-actin
# Arp2/3
# ATP
# ATP
# thymosin
# Thymosin
# ADP
# ATP
# anomaly
# agitation
# divalent
# ATP
# Cc
# ATP
# ATP
# ATP
# ADP
# ATP
# F-actin-ADP
# ADP
# ATP
# ATP
# G-actin
# ATP
# Pi
# ADP
# ATP
# ADP+Pi
# ADP
# ADP+Pi
# ATP
# ATP
# Cc
# nucleotides
# Thymosin
# G-actin-ATP
# thymosin β-4
# G-actin
# G-actin-ATP
# ADP
# ATP
# proline
# Arp2/3
# G-actin
# latrunculin
# cytochalasin D
# phalloidin): Latrunculin
# Cytochalasin
# Cytochalasin
# Phalloidin
# death
# myosin
# muscle contraction
# myosin V and VI
# ATP
# Myosin
# myosin
# myosin
# myosin VI
# inositol phosphate
# myosin
# cytochalasins
# myosin
# sodium
# Srv2/CAP
# α-tubulins
# β-tubulins
# profilins
# myosin
# gelsolin/severin
# calcium
# formins
# myosin
# KAM1/MUR3
# stress
# ATP
# ADP
# ATP
# phalloidin
# human melanoma
# alpha skeletal muscle
# myosin
# Pol II
# myosin
# muscle contraction
# myosin
# ATP
# ATP
# myosin
# stroke
# alpha-actinin
# myosin
# myosin
# muscle contraction
# tropomyosin
# 40-nanometre
# tropomyosin
# actin-myosin
# muscular contraction
# tropomyosin
# troponins
# troponin
# Tropomyosin
# troponin
# Ca2
# myosin
# myosin
# tropomyosin
# myosin
# ATP
# ATP
# myosin
# tropomyosin
# actin-myosin
# myosin
# Arp2/3
# formins
# programmed cell death
# stress
# cytocalasin
# Candida albicans
# spermatogenesis
# myosin
# myosin
# cardiac muscle
# infectious agents
# myopathy
# ACTA1 ACTA1
# heart muscle
# amino acids
# myopathy
# myopathy
# congenital myopathy
# CM
# congenital myopathy
# myopathies
# myopathy
# myopathy
# actinic nemaline myopathy
# myopathic facies
# muscular weakness
# respiratory difficulties
# age
# myopathy
# myopathy
# myopathy
# nucleotide
# Nemaline
# myopathy
# CFTDM
# muscular weakness
# type II muscular
# cisplatin
# MYH11
# hereditary thoracic aortic aneurisms
# stenosis
# aorta
# afflictions
# Moyamoya disease
# thoracic aortic aneurysm
# ischaemic heart disease
# liver cirrhosis
# heart muscle
# heart muscle
# structural disorders
# Type 1R dilated cardiomyopathy
# hypertrophic cardiomyopathy
# dilated cardiomyopathy
# amino acids belonging to the protein
# hypertrophic cardiomyopathies
# actin-myosin
# abnormal mechanical behaviour
# hypertrophy
# cardiac muscle
# stress
# idiopathic restrictive cardiomyopathy
# carcinomas
# juvenile dystonia
# infection
# nervous system malformations
# tumour
# tumours
# Hemangiopericytoma
# dystonia
# degenerative disease
# sensory hearing loss
# dystonia
# amino acid tryptophan
# arginine
# infections
# amyloidosis
# retinitis pigmentosa
# infection
# kidney diseases
# congenital hearing loss
# autosomal-dominant
# hearing loss
# sensorineural hearing loss
# DFNA
# hearing loss
# myopathies
# Listeria
# Rickettsia
# S.
# Listeria
# Arp2/3
# infection
# Arp2/3
# Pseudomonas aeruginosa
# biofilm
# biofilm
# cancer
# nucleotide
# nucleotide
# tubulin
# nucleotides
# crystalline
# G-actin
# tubulin
# AlfA
# amino acid
# MreB
# myosin
# Actin-myosin
# neoplasia
# vasculitis
# atrophy
# 3-methylhistidine
# F-myosin
# histidine
# Bank(EMDB
# ventricular contraction
# stroke
# stroke
# dilated left ventricle
# hypertrophy
# left ventricle
# oxygen
# left ventricle
# pulmonary artery
# right ventricle
# stress
# left ventricle
# {\textstyle \left({\frac {EDP\cdot EDR}{2h}}\right)}    where EDP
# left ventricle
# pulmonary artery
# left ventricle
# left ventricle
# left ventricle
# afterload Disease
# valve disease
# hypertension
# HTN
# aorta
# aortic valve
# left ventricle
# aorta
# Pulmonary hypertension
# stenosis
# left ventricle
# aortic valve
# aorta
# valve stenosis
# left ventricle
# aortic valve
# aorta
# aorta
# stenosis
# hypertrophy
# left ventricle
# aortic valve
# aorta
# Mitral regurgitation
# mitral valve
# aortic valve
# mitral valve
# left ventricle
# Cardiovascular Diseases
# doi:10.1016/0033-0620(76)90021-9
# stress
# pulmonary embolism
# P.
# P.
# doi:10.1161/CIRCULATIONAHA.106.668681
# P.
# K
# J. J.
# A. P.
# Nitroglycerin
# cognitive and social functions
# ""—
# substance abuse
# Vols
# 1898–1941
# 10th-53rd
# Death
# Duat
# Amiodarone
# cardiac dysrhythmias
# ventricular tachycardia
# ventricular fibrillation
# VF
# tachycardia
# atrial fibrillation
# supraventricular tachycardia
# cardiac arrest
# tremor
# nausea
# constipation
# amiodarone
# ventricular arrhythmias
# lung toxicity
# interstitial pneumonitis
# liver problems
# heart arrhythmias
# thyroid problems
# death
# Amiodarone
# chest pain
# arrhythmias
# Amiodarone
# arrhythmias
# arrhythmias
# supraventricular arrhythmias
# ventricular arrhythmias
# Cardiac arrest
# ventricular fibrillation
# pulseless
# ventricular tachycardia
# cardiac arrest
# amiodarone
# Amiodarone
# cardiac arrest
# Ventricular tachycardia Amiodarone
# ventricular tachycardia
# ventricular tachycardia
# amiodarone
# Amiodarone
# ventricular tachycardia
# amiodarone
# ventricular tachycardia
# monomorphic ventricular tachycardia
# ventricular tachycardia
# Atrial fibrillation
# atrial fibrillation
# amiodarone
# atrial fibrillation
# pulmonary toxicities
# amiodarone
# FDA
# atrial fibrillation
# amiodarone
# amiodarone
# atrial fibrillation
# amiodarone
# amiodarone
# breast milk
# amiodarone
# bradycardia
# atrioventricular block
# heart block
# depressed lung function
# amiodarone
# amiodarone
# benzyl alcohol
# benzyl alcohol
# syndrome"".Amiodarone
# cardiac arrhythmia
# digitalis toxicity
# Amiodarone
# amiodarone
# amiodarone
# amiodarone
# interstitial lung disease
# age
# pulmonary disease
# pulmonary fibrosis
# decreased lung function
# pulmonary toxicity
# amiodarone
# Thyroid Induced abnormalities in thyroid function
# Amiodarone
# thyroxine
# iodine
# amiodarone
# Amiodarone
# iodine
# cardiac hypothyroidism
# bradycardia
# arrhythmia
# Hypothyroidism
# amiodarone
# atrial fibrillation
# hypothyroidism
# amiodarone-treated
# sotalol
# Overt hypothyroidism
# amiodarone
# Hyperthyroidism
# Jod-Basedow
# hyperthyroidism
# Low thyroid
# hyperthyroidism
# amiodarone
# amiodarone
# iodine
# iodine
# amiodarone-induced hyperthyroidism
# keratopathy
# amiodarone
# Optic neuropathy
# nonarteritic
# ischemic optic neuropathy
# N-AION
# optic disc swelling
# visual field defects
# Loss of eyelashes
# amiodarone
# Liver Abnormal liver enzyme
# amiodarone
# jaundice
# hepatomegaly
# liver enlargement
# hepatitis
# amiodarone
# pseudo-alcoholic cirrhosis
# amiodarone
# blue-grey discoloration
# ultraviolet-A
# discoloration
# heart problems
# neurological problems
# amiodarone
# peripheral neuropathies
# Amiodarone
# epididymitis
# Amiodarone
# inflammation
# amiodarone
# gynecomastia
# amiodarone
# amiodarone
# cancer
# heart disease
# amiodarone
# digoxin
# amiodarone
# Amiodarone
# sotalol
# Amiodarone
# warfarin
# warfarin
# warfarin
# amiodarone
# warfarin
# amiodarone
# amiodarone
# amiodarone
# amiodarone
# amiodarone
# warfarin
# Amiodarone
# Ciclosporin
# Quinidine
# Simvastatin Theophylline
# ledipasvir/sofosbuvir
# sofosbuvir
# amiodarone
# cardiac arrest
# Amiodarone
# digoxin
# warfarin
# phenytoin
# amiodarone
# desethylamiodarone
# DEA
# amiodarone
# amiodarone
# rhabdomyolysis
# kidney failure
# death
# simvastatin
# amiodarone
# simvastatin
# simvastatin
# amiodarone
# desethylamiodarone
# DEA
# amiodarone
# DEA
# breast milk
# amiodarone
# DEA
# amiodarone
# Amiodarone
# calcium
# potassium
# Amiodarone
# potassium
# calcium
# (CACNA2D2).Amiodarone
# Amiodarone
# calcium
# sodium-
# amiodarone
# Long QT-3 syndrome
# ∆KPQ
# sodium
# sodium
# Amiodarone
# thyroxine
# amiodarone
# khellin
# Cairo
# Ammi visnaga
# khellin
# non-cardiac ailments
# Amiodarone
# khellin
# angina pectoris
# amiodarone
# sotalol
# amiodarone
# sotalol
# K+
# amiodarone
# supraventricular
# ventricular arrhythmias
# amiodarone
# arrhythmias
# amiodarone
# arrhythmias
# amiodarone
# amiodarone
# amiodarone
# amiodarone
# amiodarone
# patent ductus arteriosus
# obstructions
# calculus
# kidney stone
# gallstone
# unspecified obstruction
# bowel obstruction
# congenital anomalies
# Movement Joints
# synovial joints
# decreases (flexion) or increases (extension) the
# Abduction
# depression
# inferior (depression
# Pronation
# muscle contraction
# muscle coactivation
# synovial joints
# synovial joints
# serous
# serous
# Addison
# temples
# deceased souls
# cattle
# temples
# deaths
# non-royal
# Hapu
# Dedun
# Anat
# AD
# cohesive vision
# Khnum
# Elephantine
# Nile
# Nile
# Duat
# aggressive and impulsive
# Deities' mythic behavior
# birth to the sun god
# death
# changelessly
# temples
# myths
# Sex
# feminine aggression
# disapproval
# homosexual behavior
# Khnum
# Egyptian deities
# healer
# bas
# Nekhen
# Buhen
# Amun-Ra
# Ra-Horakhty
# foreign deities
# Khenti-Amentiu
# 1353–1336
# Atenism
# Amun-Ra
# Atenism
# silver
# Egyptians' visual representations
# anthropomorphic deities
# breasts
# emblems of deities
# deaths
# ḏsr—""sacred""—
# human souls
# death
# death
# Meskhenet
# Renenutet
# death
# ""—
# death
# human ailments
# cosmic disorder
# isfet
# guilt
# festivals
# Nile
# flood
# temples
# death
# temples
# theophoric
# Egyptian deities
# Oasis
# interpretatio
# Egyptian deities—
# Trismegistus
# Trismegistus
# Egyptian deities
# festivals
# Egyptian deities
# Lexikon der ägyptischen Götter
# VI
# temples
# death
# multiple deities
# Ra
# Amun-Ra
# Nu
# death
# human weakness
# temples
# death
# death
# death
# death
# death
# death
# akh
# heir
# death
# Nile
# human souls
# death
# serpentine
# Apep
# deceased souls
# non-royal
# spells
# temples
# festivals
# particular deities
# Egyptian deities
# barque's movements
# death
# temples
# temples
# mastabas
# mastabas
# Nekhen
# mastabas
# Ra
# Hermeticism
# Campaign
# Geraldine
# Bilolo
# Les cosmo-théologies philosophiques
# Essai de thématisation
# ———
# Les cosmo-théologies philosophiques
# l'Égypte
# ———
# ———
# Création dans la pensée memphite
# Geraldine
# Alpago
# death
# Cremonensis
# castigationibus
# complurium codicum arabicorum (Ibn Sina's Canon of
# Koine
# Classical-era
# Age
# Hatzopoulos
# γάλακτος
# PIE phonemes
# sex
# γένους
# PIE
# quis
# stress
# /oː/
# aorist
# PIE
# aorist
# aorist
# ī → ī o, ō → ō u, ū → ū ai → ēi ei → ēi or
# → h₃leh₃l →
# eilēpha
# lelēpha
# slambanō
# eilēpha
# Reduplication
# πεπόνθατε ὑπὸ τῶν ἐμῶν κατηγόρων
# οἶδα· ἐγὼ δ' οὖν καὶ
# ἐμαυτοῦ
# ἔπος εἰπεῖν οὐδὲν εἰρήκασιν
# IPA
# | ɔ̂ː ándres atʰɛːnaî̯i̯oi | pepóntʰate | hypo tɔ̂ːn emɔ̂ːŋ katɛːɡórɔːn | oːk oî̯da ‖ éɡɔː dûːŋ kai̯ au̯tos | hyp au̯tɔ̂ːn olíɡoː emau̯tûː | epelatʰómɛːn | hǔːtɔː pitʰanɔ̂ːs éleɡon ‖ kaí̯toi̯ alɛːtʰéz ɡe | hɔːs épos eːpêːn | oːden eːrɛ̌ːkaːsin
# Athēnaîoi
# pepónthate
# epelathómēn
# age
# Potter and the Philosopher's Stone
# Ὀνόματα Kεχιασμένα (Onomata Kechiasmena
# Hebdomada
# Hanhart
# Athenaze
# S. P.
# Chantraine
# Pierre
# Taillardat
# Anastasios-Phoibos
# W.
# 8–19
# A. W.
# Pierre
# Alfons
# P.
# Ἑλλάς
# c. AD 600
# Age
# age
# death
# death
# AD
# Lelantine
# poleis
# Chalcis
# Lelantine
# Chalcis
# Messenia
# helots
# labored
# Mamertines
# Peisistratos
# Cleomenes
# Isagoras
# Age
# Marathon
# Darius' son Xerxes
# defeat
# death
# Boeotia
# Boeotia
# Sphakteria
# Boeotia
# Delium
# Sphakteria
# deaths
# Aegospotami
# Mantinea
# Chaeronea
# poleis
# death
# Alexandria
# Alexandria
# poleis
# Galen
# Messenia
# Boeotia
# Chaonia
# Elimeia
# Lyncestae
# Orestae
# Mygdonia
# Almopia
# 7½-10
# Illyria
# Neapolis
# poleis
# poleis
# poleis
# poleis
# poleis
# poleis
# poleis
# hereditary
# poleis
# Eurysthenes
# Aristodemus
# Helots
# age
# paidagogos
# age
# labor
# silver
# age
# Plato's disciple Aristotle
# Antisthenes
# Citium
# Acharnians
# Alexandria
# Alexandria
# Actium
# calculus
# theurgy
# Horace
# artis
# Epistulae
# Age
# Age
# 1600–1100
# Midea
# Paeonia
# death
# Kyrenaika
# famine
# Bosporan
# Bosporan
# Βασίλειον
# Kimmerikou
# Phocis
# Kydonia
# Ἤπειρος
# 329–160
# fortified
# Leninabad
# Transoxiana
# Basileía tōn
# Babylonia
# /ænˈtɪɡoʊnɪd/
# Monophthalmus
# Πτολεμαϊκὴ βασιλεία, romanized
# death
# Basileía toû Póntou
# Hellenistic-era
# Bithynia
# death
# Lysimachus' lieutenants
# Sogdiana
# Age
# Age
# Hurwit
# 1100–480
# Latinize
# Pedagogium
# Dubois (Jacobus Sylvius) and Jean Fernel
# affectuum singularum corporis partium curatione
# leprosy
# Sex
# Galen
# sex
# Galen
# Galen's view
# Galen
# Galen
# Galen
# Galen
# Galen
# left ventricle
# right ventricle
# Galen
# Galen's assertions
# Galen
# felon
# corporis
# suorum
# corporis
# death
# 1588.Over
# Galen
# De humani corporis
# death
# death
# age
# death
# Galen
# vena azygos
# noose
# laterali secandam
# pain
# gout
# syphilis
# death
# Galen's theories
# Galen
# mitral valve
# azygos vein
# Catholic
# right atrium
# left atrium
# pulmonary vein
# Galen's theory
# teeth
# empyema
# syphilis
# chinaroot
# diet
# hands'—mainly
# UP
# CM
# W. F. Richardson and J. B.
# Bruxellensis
# Dе humani corporis
# Jacqueline
# De humani corporis
# Angina
# angina pectoris
# chest pain
# heart muscle
# Angina
# obstruction
# spasm
# heart muscle
# anemia
# abnormal heart rhythms
# heart failure
# coronary artery obstruction
# atherosclerosis
# coronary artery disease
# pectus
# pain
# oxygen
# heart muscle
# pain
# myocardial infarction
# heart attack
# heart attack
# pain
# angina
# death
# age
# angina
# 92%.Worsening angina
# angina
# angina
# unstable angina
# heart attack
# myocardial infarction
# angina
# acute aortic insufficiency
# heart failure
# pulmonary edema
# chronic insufficiency
# hypertrophy
# left ventricle
# aortic valve
# calcification
# stenosis
# hypertrophy
# left ventricle
# ventricular hypertrophy
# heart failure
# Dysfunctional aortic valves often
# heart failure
# fatigue
# shortness of breath
# aorta
# rheumatic fever
# infection
# infective endocarditis
# degeneration of the aortic valve
# Marfan's syndrome
# Aortic stenosis
# rheumatic fever
# degenerative calcification
# congenital heart defect
# aortic valve
# Turner syndrome
# Aortic valve
# Aortic valve
# aortic valve
# aortic valve
# aortic regurgitation
# aneurysm
# congenital aortic stenosis
# Aortic valve
# aortic valve
# aortic valve
# aortic valve
# valve dysfunction
# aortic valve
# aorta
# embolism
# stroke
# calcification
# aortic valve
# aortic valve
# aortic valve
# pulmonary valve
# pulmonary valve
# valvular prothesis
# pulmonary valve
# aortic valve
# Endocarditis Endocarditis
# infection of the heart
# aortic valve
# aortic valve
# stenosis
# insufficiency
# valve dysfunction
# stenosis
# insufficiency
# aortic valve
# calcification
# bicuspid, unicuspid)
# aortic valve
# aortic valve
# left ventricle
# aorta
# 20:07
# Aortic valve
# aortic valve
# aortic valve
# aortic valve
# stenosis
# aortic stenosis
# stenosis
# aortic valve
# aortic valve
# aortic valve
# aortic valve
# aortic valve
# aortic valve
# LV stroke
# aortic valve
# LV stroke
# Stroke
# Diameter2
# \displaystyle {\text{Aortic
# subvalvular stenosis
# Gorlin
# Gorlin
# Gorlin
# aortic valve
# aortic valve
# aortic valve
# \displaystyle {\text{Valve
# cm}}^{2}{\text{)}}={\frac {{\text{Cardiac Output }}({\frac {\text{ml}}{\text{min}}})}{{\text{Heart rate }}({\frac {\text{beats}}{\text{min}}})\cdot {\text{Systolic ejection
# Gorlin
# dobutamine
# Gorlin
# (bpm)}}\cdot {\text{systolic ejection
# \displaystyle {\text{Aortic
# Gorlin
# \displaystyle {\text{Valve Area
# cm}}^{2}{\text{)}}={\text{(0.83}}^{2}+{\frac {\frac {{\text{Q (}}{\frac {ml}{min}})}{\text{60}}}{{\text{0.35 }}\cdot {\sqrt {\text{mean Gradient (dynes/cm2)}}}}}{\text{)}}^{\text{0.5}}-{\text{0.87}}}     == References
# Aortic stenosis
# left ventricle
# aorta
# aortic valve
# exercise
# heart failure
# loss of consciousness
# chest pain
# Loss of consciousness
# heart failure
# shortness of breath
# exercise
# aortic sclerosis
# bicuspid aortic valve
# rheumatic fever
# aortic valve
# rheumatic heart disease
# coronary artery disease
# smoking
# high blood pressure
# cholesterol
# diabetes
# aortic valve
# left ventricle
# aorta
# stenosis
# aortic valve
# heart failure
# ACE inhibitors
# nitroglycerin
# Nitroprusside
# phenylephrine
# heart failure
# stenosis
# valvular heart disease
# age
# death
# stenosis
# Rivière
# stenosis
# stenosis
# stenosis
# aortic stenosis
# stenosis
# stenosis
# loss of consciousness
# chest pain
# shortness of breath
# heart failure
# shortness of breath
# shortness of breath
# Angina
# Angina
# heart failure
# death
# angina
# aortic valve
# Angina
# ventricular hypertrophy
# left ventricle
# oxygen
# ischemia
# exercise
# aortic valve
# aortic valve
# aortic valve
# aortic valve
# Heart failure Acute decompensated heart failure
# high blood pressure
# nitroprusside
# Phenylephrine
# stenosis
# aortic valve
# age
# age
# age
# valve stenosis
# coronary artery disease
# hypertension
# age
# hyperlipidemia
# diabetes mellitus
# smoking
# metabolic syndrome
# end-stage kidney disease
# stenosis
# Rivière
# bisphosphonates
# stenosis
# stenosis
# ACC/AATS/AHA/ASE/EACTS/HVS/SCA/SCAI/SCCT/SCMR/STS
# doi:10.1016/j.jacc.2017.09.018
# Archosauria
# Archosauria
# Archosauria
# Archosauria
# proterosuchids
# Archosauria
# Archosauria
# crocodilian-line
# Teleocrater
# oxygen
# uric acid
# uric acid
# aglandular (glandless)
# urea
# Pseudosuchia
# suture
# age
# Teleocrater
# Archosauria
# Archosauria
# proterochampsids
# Archosauria
# proterosuchids
# Archosauria
# Archosauria
# Archosauria
# Archosauria
# Archosauria
# Ornithosuchids
# Archosauria
# Ornithosuchia
# Ornithosuchia
# proterosuchids
# Archosauria
# Archosauria
# Ornithosuchia
# Ornithosuchia
# Archosauria
# Ornithosuchia
# cladogram
# branch-based
# cladogram
# Archosauria
# Archosauria
# Archosauria
# cladogram
# Hip joints
# hip joints
# Diet
# teleosaurs
# fluke
# oxygen
# oxygen
# palate
# right ventricle
# pulmonary artery
# terrestrial predators
# gas
# Archosauria
# gas
# oxygen
# sex
# sex
# R. L. (1988)
# W.
# Archosauria
# oxygen
# carbon dioxide
# right atrium
# oxygen
# right atrium
# inferior venae cavae
# right ventricle
# oxygen
# carbon dioxide
# left atrium
# left ventricle
# aorta
# circulation−where
# oxygen
# carbon dioxide
# heart beats
# Exercise
# Cardiovascular diseases
# death
# deaths
# coronary artery disease
# stroke
# smoking
# exercise
# cholesterol
# high blood pressure
# diabetes
# Cardiovascular diseases
# chest pain
# shortness of breath
# heart disease
# diseases of the heart
# aorta
# pulmonary trunk
# cardiac notch
# exercise
# heart muscle
# right atrium
# left atrium
# right atrium
# right ventricle
# left atrium
# left ventricle
# right atrium
# right ventricle
# tricuspid valve
# tricuspid valve
# mitral valve
# left atrium
# left ventricle
# pulmonary valve
# pulmonary artery
# aortic valve
# aorta
# aorta
# right atrium
# right ventricle
# tricuspid valve
# right atrium
# veins
# right atrium
# inferior vena cava
# right atrium
# depression
# right atrium
# depression
# right atrium
# right ventricle
# tricuspid valve
# right ventricle
# cardiac muscle
# cardiac muscle
# right ventricle
# right ventricle
# inferior papillary muscle
# right ventricle
# pulmonary trunk
# pulmonary valve
# pulmonary trunk
# left atrium
# left ventricle
# mitral valve
# left atrium
# left atrium
# right atrium
# left atrium
# left atrium
# left ventricle
# mitral valve
# left ventricle
# right ventricle
# left ventricle
# aortic valve
# aorta
# aortic valve
# heart muscle
# endothelins
# cardiac muscle—a
# involuntary striated muscle
# cardiac muscle
# cardiac muscle
# Cardiac muscle
# muscle contraction
# myosin
# tropomyosin
# LDB3
# lubricate
# lubricate
# infection
# oxygen
# heart muscle's relaxation
# aortic valve
# aorta
# left ventricle
# left ventricle
# right atrium
# right ventricle
# left ventricle
# right atrium
# cardiac vein
# left atrium
# left ventricle
# small cardiac veins
# right ventricle
# right atrium
# left ventricle
# pulmonary artery
# left atrium
# right atrium
# right ventricle
# aorta
# norepinephrine
# noradrenaline
# sodium
# calcium
# Norepinephrine
# right atrium
# left atrium
# depression
# right atrium
# 165–185
# carbon dioxide
# oxygen
# oxygen
# carbon dioxide
# veins
# left atrium
# superior vena cava
# right atrium
# inferior vena cava drains the blood
# superior vena cava
# inferior vena cava
# right atrium
# right atrium
# right atrium
# tricuspid valve
# right ventricle
# right ventricle
# tricuspid valve
# pulmonary valve
# pulmonary trunk
# carbon dioxide
# oxygen
# left atrium
# left ventricle
# mitral valve
# aorta
# aortic valve
# aorta
# oxygen
# carbon dioxide
# aorta
# pulmonary artery
# mitral and tricuspid valves
# mitral and tricuspid valves
# aorta
# right atrium
# left atrium
# aorta
# mitral and tricuspid valves
# stroke
# stroke
# stroke
# 4.0–8.0
# stroke
# sex
# stenosis
# heart muscle
# stroke
# adrenaline
# noradrenaline
# dopamine
# calcium
# right atrium
# superior vena cava
# right atrium
# left atrium
# right atrium
# right atrium
# left ventricle
# heart muscle
# right atrium
# sodium
# sodium
# calcium
# potassium
# potassium
# calcium
# calcium
# potassium
# potassium
# potassium
# sodium
# potassium
# Calcium
# Calcium
# cardiac muscle
# exercise
# oxygen
# carbon dioxide
# aorta
# carbon dioxide
# oxygen
# carbon dioxide
# Exercise
# age
# epinephrine
# norepinephrine
# calcium
# potassium
# sodium
# oxygen
# dehydration
# Diseases Cardiovascular diseases
# diseases of the heart
# death
# cardiovascular disease
# Heart disease
# death
# deaths
# diseases of the heart
# Ischaemic heart disease Coronary artery disease
# ischaemic heart disease
# atherosclerosis
# fatty deposits
# atherosclerotic
# stenosis
# narrowings
# chest pain
# angina
# breathlessness
# exercise
# atherosclerotic
# thrombus
# heart muscle
# myocardial infarction
# heart attack
# unstable angina
# cardiac arrest
# Obesity
# high blood pressure
# diabetes
# smoking
# cholesterol
# atherosclerosis
# coronary artery disease
# Heart failure Heart failure
# heart failure
# breathlessness
# ankle swelling
# peripheral oedema
# Heart failure
# diseases affecting the heart
# ischaemic heart disease
# valvular heart disease
# high blood pressure
# cardiomyopathies
# Heart failure
# weakness of the heart muscle
# systolic heart failure
# heart muscle
# heart failure
# left ventricle
# predominantly breathlessness
# right ventricle
# heart failure
# arrhythmias
# Cardiomyopathies Cardiomyopathies
# abnormal thickening of the heart muscle
# hypertrophic cardiomyopathy
# dilated cardiomyopathy
# heart muscle
# cardiomyopathy
# arrhythmogenic cardiomyopathy
# dilated cardiomyopathy
# alcohol
# cardiomyopathies
# hypertrophic cardiomopathy
# cardiac death
# cardiomyopathies
# heart failure
# Valvular heart disease
# Diseased
# valvular regurgitation
# Valvular heart disease
# breathlessness
# chest pain
# valvular heart disease
# age
# infection of the heart valves
# endocarditis
# heart disease
# valvular heart disease
# stenosis
# throat infection
# Cardiac arrhythmias
# arrhythmias
# palpitations
# breathlessness
# arrhythmia
# atrial fibrillation
# stroke
# arrhythmias
# bradycardia
# bradyarrhythmia
# arrhythmias
# tachycardia
# tachyarrhythmia
# arrhythmias
# atrial flutter
# re-entrant tachycardia
# ventricular tachycardia
# tachyarrhythmias
# ventricular tachycardia
# atrial tachycardia
# Wolff-Parkinson-White syndrome
# ventricular fibrillation
# Pericardial disease
# pericarditis
# chest pain
# viral infection
# glandular fever
# pericardial effusion
# Pericardial effusions
# pericarditis
# kidney failure
# tumours
# cardiac tamponade
# breathlessness
# tamponade
# pericardiocentesis
# Congenital heart disease
# congenital heart defects
# patent foramen ovale
# life-threatening abnormalities
# hypoplastic left heart syndrome
# ventricular septal defect
# congenital aortic stenosis
# coarctation of the aorta
# congenital heart defects
# oxygen
# cyanotic congenital heart defects
# congenital heart defects
# breathlessness
# congenital heart disease
# atrial septal defect
# Heart disease
# valvular or cardiac problems
# quadruple
# Heart murmurs
# congenital heart disease
# ventricular septal defects
# pericarditis
# rub
# Troponin
# troponin
# heart failure
# left ventricle
# cardiac disease
# creatine
# heart disease
# anaemia
# cholesterol
# diabetes
# ground).There
# rhythm disturbances
# rhythm abnormality
# valve disease
# stenosis
# blood (regurgitation
# stroke
# stress
# exercise
# dobutamine
# pulmonary oedema
# aorta
# Diseases affecting the heart
# Ischaemic heart disease Narrowings of the coronary arteries (ischaemic heart disease
# chest pain
# artery (angina pectoris
# heart muscle damage
# myocardial infarction
# myocardial infarction
# angina
# nitroglycerin
# calcium
# antiplatelets
# aspirin
# statins
# smoking
# weight loss
# high blood pressure
# diabetes
# narrowings
# narrowings
# narrowings
# aorta
# Valvular heart disease Diseased heart valves
# aortic valve
# Cardiac arrhythmias
# arrhythmias
# calcium
# sodium
# amiodarone
# digoxin
# atropine
# arrhythmias
# atrial fibrillation
# stroke
# warfarin
# arrhythmia
# arrhythmia
# arrhythmias
# arrhythmias
# atrial fibrillation
# shock
# arrhythmias
# shock
# heart failure
# cardiomyopathies
# arrhythmia
# Heart failure
# heart failure
# ischaemic heart disease
# hypertension
# heart failure
# ACE inhibitors and mineralocorticoid receptor antagonists).In
# heart failure
# heart failure
# Galen
# Galen believed the arterial blood
# left ventricle
# pulmonary artery
# left ventricle
# Galen
# Galen
# Galen's beliefs of the heart
# De humani corporis
# magnum
# attacks
# Otto
# 1865–1944
# Tawara's discovery of the atrioventricular
# heart disease
# infectious disease
# death
# deaths
# diet
# exercise
# aspirin
# ACE inhibitors
# chronic heart failure
# death
# xīn
# 神
# Hrd
# Galen
# heart-soul (tona-tiuh):
# pulsating"".In
# beef, pork,
# grilled or braised
# anticuchos de corazón, barbecued beef
# spice
# braised stuffed beef heart
# heart is stewed,
# braised
# right atrium
# pulmonary artery
# aorta
# conus arteriosus
# aorta
# aorta
# aorta
# aorta
# aorta
# aorta
# conus arteriosus
# right atrium
# oxygen
# oxygen
# Oxygen
# small muscular
# aorta
# Nicki R. Colledge
# 129–134
# nitric oxide
# polyphenols
# nitric oxide
# L-arginine
# luminal
# hypertensive
# arteriolosclerosis
# luminal
# stroke
# gas
# carbon dioxide
# oxygen
# norepinephrine
# epinephrine
# cardiac muscle
# oxygen
# carbon dioxide
# oxygen
# angiotensin II
# bradykinin
# prostacyclin
# age
# stenosis
# hypertension
# Arteriosclerosis
# hypertension
# atherosclerosis
# Arteritis
# muscular contraction
# dihydropyridines
# nifedipine
# nicardipine
# calcium
# Arrhythmogenic cardiomyopathy
# ACM
# arrhythmogenic right ventricular dysplasia
# ARVD
# arrhythmogenic right ventricular cardiomyopathy
# ARVC
# heart disease
# ACM
# heart muscle
# right ventricle
# left ventricular disease
# arrhythmias
# right ventricle
# ARVD
# ACM
# dysplasia of the ventricular wall
# ACM
# left ventricle
# name ARVC
# ACM
# keratoderma
# Naxos disease
# stress
# ventricular arrhythmias
# arrhythmogenic cardiomyopathy
# arrhythmias
# arrhythmogenic cardiomyopathy
# palpitations
# Sudden death
# ACM
# ACM
# right ventricle
# fatigue
# ankle swelling
# shortness of breath
# ACM
# ACM
# ACM
# ACM
# DES
# ACM
# DES
# abnormal aggregation
# ACM
# ACM
# programmed cell death
# right ventricle
# ventricular disease
# biventricular disease
# aneurysmal dilatation
# Aneurysmal dilatation
# dysplasia
# left ventricle
# left ventricle
# ACM
# Fatty infiltration
# fibro-fatty infiltration
# Fatty infiltration
# fatty infiltration
# right ventricle
# fatty
# left ventricle
# fatty infiltration
# death
# fatty infiltration
# Fibro-fatty infiltration
# fibro-fatty infiltration
# myocarditis
# Myocardial atrophy
# aneurysm
# Exercise
# exercise
# Ventricular arrhythmias Ventricular arrhythmias
# ACM
# right ventricle
# arrhythmia
# premature ventricular complexes (PVCs
# ventricular tachycardia
# ventricular fibrillation
# VF
# ventricular arrhythmias
# Ventricular arrhythmias

# %%
html=displacy.render(doc_ner1,style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">&quot;The heart is a muscular organ in most animals, which pumps blood through the blood vessels of the circulatory system. The pumped blood carries
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     oxygen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
#  and nutrients to the body, while carrying metabolic waste such as
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     carbon dioxide
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
#  to the lungs. In humans, the heart is approximately the size of a closed fist and is located between the lungs, in the middle compartment of the chest.In humans, other mammals, and birds, the heart is divided into four chambers: upper left and right atria and lower left and right ventricles. Commonly the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     right atrium
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Parts of the human heart</span>
# </mark>
#  and ventricle are referred together as the right heart and their left counterparts as the left heart. Fish, in contrast, have two chambers, an atrium and a ventricle, while reptiles have three chambers. In a healthy heart blood flows one way through the heart due to heart valves, which prevent backflow. The heart is enclosed in a protective sac, the pericardium, which also contains a small amount of fluid. The wall of the heart is made up of three layers: epicardium, myocardium, and endocardium.The heart pumps blood with a rhythm determined by a group of pacemaker cells in the sinoatrial node. These generate a current that causes contraction of the heart, traveling through the atrioventricular node and along the conduction system of the heart. The heart receives blood low in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     oxygen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
#  from the systemic circulation, which enters the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     right atrium
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Parts of the human heart</span>
# </mark>
#  from the superior and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     inferior venae cavae
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  and passes to the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     right ventricle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Parts of the human heart</span>
# </mark>
# . From here it is pumped into the pulmonary circulation, through the lungs where it receives
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     oxygen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
#  and gives off
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     carbon dioxide
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
# . Oxygenated blood then returns to the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     left atrium
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Parts of the human heart</span>
# </mark>
# , passes through the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     left ventricle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Parts of the human heart</span>
# </mark>
#  and is pumped out through the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     aorta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Parts of the human heart</span>
# </mark>
#  to the systemic
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     circulation−where
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
#  the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     oxygen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
#  is used and metabolized to
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     carbon dioxide
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
# . The
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     heart beats
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  at a resting rate close to 72 beats per minute.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Exercise
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Prevention</span>
# </mark>
#  temporarily increases the rate, but lowers resting heart rate in the long term, and is good for heart health.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cardiovascular diseases
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  (CVD) are the most common cause of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     death
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  globally as of 2008, accounting for 30% of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin

# %%
html=displacy.render(doc_ner2,style="ent")

# %%
html=displacy.render(doc_ner3,style="ent")

# %%
html=displacy.render(doc_ner4,style="ent")

# %%
#Label's and Entities added to source , target and relations list

docs=[doc_ner1,doc_ner2,doc_ner3,doc_ner4]
for doc in docs:
    for ents in doc.ents:
        sources.append(ents)
        targets.append(ents.label_)
        relations.append('NER')

# %%
doc_stanza = nlp_stanza(text)

# %%
#print both here

# %%
texts =[[]]
ners =[[]]
i=0
for sent in doc_stanza.ents:
    text=[]
    ner=[]
    for token in sent.tokens:
        text.append(token.text)
        ner.append(token.ner)
    texts.append(text)
    ners.append(ner)

# %%
pattern = [['B-PROBLEM', 'I-PROBLEM', 'E-PROBLEM'],['B-TREATMENT', 'I-TREATMENT', 'E-TREATMENT'],['B-TEST', 'I-TEST', 'E-TEST']]
sources1 =[]
relations1 = []
targets1 =[]
for val in ners:
    if val in pattern:
        if texts[ners.index(val)][0] not in sources1:
            sources1.append(texts[ners.index(val)][0])
            relations1.append(texts[ners.index(val)][1])
            targets1.append(texts[ners.index(val)][2])

# %%
for i in range(len(sources1)):
    sources.append(sources1[i])
    targets.append(targets1[i])
    relations.append(relations1[i])

# %%
df=pd.DataFrame({'source-node':sources,'target-node':targets,'relation':relations})

# %%
df['relation'].value_counts()[:50]
# Out:
# NER               28659
# include             400
# such_as             337
# abbreviated-as      166
# other               108
# have                 92
# has                  69
# used                 54
# had                  41
# found                36
# is                   32
# contains             24
# cause                23
# believed             23
# performed            22
# developed            22
# increases            19
# form                 19
# shown                19
# causes               19
# includes             18
# involves             18
# included             17
# treated              17
# increase             17
# considered           16
# means                16
# result               14
# decreases            14
# published            13
# began                13
# appears              13
# See                  13
# are                  13
# allow                13
# called               13
# made                 13
# provides             12
# use                  12
# discovered           12
# receives             12
# took                 12
# continued            12
# require              12
# said                 12
# make                 12
# occurs               12
# required             12
# suggested            11
# taken                11
# Name: relation, dtype: int64

# %%
df.head()
# Out:
#   source-node     target-node relation
# 0       waste  carbon dioxide  such_as
# 1        They            MYH6  include
# 2        They           ACTC1  include
# 3        They           TNNI3  include
# 4        They            CDH2  include

# %%
Knowledge_graph=nx.from_pandas_edgelist(df, 'source-node', 'target-node', edge_attr=True, create_using=nx.MultiDiGraph())
for n in Knowledge_graph.nodes():
    Knowledge_graph.nodes[n]['color'] = 'red' if n in df['source-node'] else 'skyblue'

plt.figure(figsize=(20,20))
colors = [node[1]['color'] for node in Knowledge_graph.nodes(data=True)]
pos = nx.spring_layout(Knowledge_graph)
nx.draw(Knowledge_graph, with_labels=True, node_color=colors, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()
