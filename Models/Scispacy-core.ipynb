# %%
import spacy
import scispacy
from scispacy.abbreviation import AbbreviationDetector
from scispacy.linking import EntityLinker
from scispacy.hyponym_detector import HyponymDetector
import pandas as pd
from spacy import displacy
import deplacy

# %%
with open ("/Users/abhinavshinow/Documents/GitHub/Bert_Based_NER/Data_Collection/heart-data.txt","r") as f:
    text=f.read().replace("\n\n"," ").replace("\n"," ")
text=text[:10000]

# %%
nlp=spacy.load("en_core_sci_sm")
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/spacy/util.py:762: UserWarning: [W095] Model 'en_core_sci_sm' (0.4.0) was trained with spaCy v3.0 and may not be 100% compatible with the current version (3.1.4). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
nlp.add_pipe("hyponym_detector", last=True, config={"extended": False})

# %%
doc=nlp(text)

# %%
for token in doc:
    print(token.text,token.dep_)
# Out:
# " punct
# Cardiovascular amod
# disease nsubj
# ( punct
# CVD appos
# ) punct
# is cop
# a det
# class ROOT
# of case
# diseases nmod
# that nsubj
# involve acl:relcl
# the det
# heart compound
# or cc
# blood conj
# vessels dobj
# . punct
# CVD nsubj
# includes ROOT
# coronary amod
# artery compound
# diseases dobj
# ( punct
# CAD appos
# ) punct
# such case
# as mwe
# angina nmod
# and cc
# myocardial conj
# infarction conj
# ( punct
# commonly advmod
# known dep
# as case
# a det
# heart compound
# attack nmod
# ) punct
# . punct
# Other amod
# CVDs nsubj
# include ROOT
# stroke dobj
# , punct
# heart compound
# failure conj
# , punct
# hypertensive amod
# heart compound
# disease conj
# , punct
# rheumatic amod
# heart compound
# disease conj
# , punct
# cardiomyopathy conj
# , punct
# abnormal amod
# heart compound
# rhythms conj
# , punct
# congenital amod
# heart compound
# disease conj
# , punct
# valvular amod
# heart compound
# disease conj
# , punct
# carditis conj
# , punct
# aortic amod
# aneurysms conj
# , punct
# peripheral amod
# artery compound
# disease conj
# , punct
# thromboembolic compound
# disease conj
# , punct
# and cc
# venous amod
# thrombosis conj
# . punct
# The det
# underlying amod
# mechanisms nsubj
# vary ROOT
# depending case
# on case
# the det
# disease nmod
# . punct
# Coronary amod
# artery compound
# disease nsubj
# , punct
# stroke conj
# , punct
# and cc
# peripheral amod
# artery compound
# disease conj
# involve ROOT
# atherosclerosis dobj
# . punct
# This nsubjpass
# may aux
# be auxpass
# caused ROOT
# by case
# high amod
# blood compound
# pressure nmod
# , punct
# smoking conj
# , punct
# diabetes compound
# mellitus conj
# , punct
# lack conj
# of case
# exercise nmod
# , punct
# obesity conj
# , punct
# high amod
# blood compound
# cholesterol conj
# , punct
# poor amod
# diet conj
# , punct
# excessive amod
# alcohol compound
# consumption conj
# , punct
#   conj
# and cc
# poor conj
# sleep conj
# , punct
# among case
# others nmod
# . punct
# High amod
# blood compound
# pressure nsubjpass
# is auxpass
# estimated ROOT
# to mark
# account xcomp
# for case
# approximately advmod
# 13 nummod
# % nmod
# of case
# CVD compound
# deaths nmod
# , punct
# while mark
# tobacco compound
# accounts nsubj
# for case
# 9 nummod
# % nmod
# , punct
# diabetes advcl
# 6 nummod
# % dobj
# , punct
# lack appos
# of case
# exercise nmod
# 6 nummod
# % dobj
# and cc
# obesity conj
# 5 nummod
# % dobj
# . punct
# Rheumatic amod
# heart compound
# disease nsubj
# may aux
# follow ROOT
# untreated amod
# strep compound
# throat dobj
# . punct
# It nsubjpass
# is auxpass
# estimated ROOT
# that mark
# up advmod
# to dep
# 90 nummod
# % nsubj
# of case
# CVD nmod
# may aux
# be cop
# preventable ccomp
# . punct
# Prevention nsubj
# of case
# CVD nmod
# involves ROOT
# improving xcomp
# risk compound
# factors dobj
# through dobj
# : punct
# healthy amod
# eating advcl
# , punct
# exercise conj
# , punct
# avoidance conj
# of case
# tobacco compound
# smoke nmod
# and cc
# limiting amod
# alcohol compound
# intake conj
# . punct
# Treating csubj
# risk compound
# factors dobj
# , punct
# such case
# as mwe
# high amod
# blood compound
# pressure nmod
# , punct
# blood compound
# lipids conj
# and cc
# diabetes conj
# is cop
# also advmod
# beneficial ROOT
# . punct
# Treating csubj
# people dobj
# who nsubj
# have aux
# strep advmod
# throat ROOT
# with case
# antibiotics nmod
# can aux
# decrease conj
# the det
# risk dobj
# of case
# rheumatic amod
# heart compound
# disease nmod
# . punct
# The det
# use nsubj
# of case
# aspirin nmod
# in case
# people nmod
# , punct
# who nsubj
# are cop
# otherwise advmod
# healthy acl:relcl
# , punct
# is cop
# of case
# unclear amod
# benefit ROOT
# . punct
# Cardiovascular amod
# diseases nsubj
# are cop
# the det
# leading amod
# cause ROOT
# of case
# death nmod
# worldwide advmod
# except case
# Africa nmod
# . punct
# Together advmod
# CVD nsubj
# resulted ROOT
# in case
# 17.9 compound
# million nummod
# deaths nmod
# ( punct
# 32.1 nummod
# % appos
# ) punct
# in case
# 2015 nmod
# , punct
# up advmod
# from case
# 12.3 compound
# million nmod
# ( punct
# 25.8 nummod
# % nmod:npmod
# ) punct
# in case
# 1990 nmod
# . punct
# Deaths nsubj
# , punct
# at case
# a det
# given amod
# age nmod
# , punct
# from case
# CVD nmod
# are cop
# more advmod
# common ROOT
# and cc
# have aux
# been aux
# increasing conj
# in case
# much nmod
# of case
# the det
# developing amod
# world nmod
# , punct
# while mark
# rates nsubj
# have aux
# declined advcl
# in case
# most nmod
# of case
# the det
# developed amod
# world nmod
# since case
# the det
# 1970s nmod
# . punct
# Coronary amod
# artery compound
# disease ROOT
# and cc
# stroke conj
# account dobj
# for case
# 80 nummod
# % nmod
# of case
# CVD compound
# deaths nmod
# in case
# males nmod
# and cc
# 75 nummod
# % conj
# of case
# CVD compound
# deaths nmod
# in case
# females nmod
# . punct
# Most amod
# cardiovascular amod
# disease nsubj
# affects ROOT
# older amod
# adults dobj
# . punct
# In case
# the det
# United compound
# States nmod
# 11 nummod
# % nsubj
# of case
# people nmod
# between case
# 20 nmod
# and cc
# 40 conj
# have ROOT
# CVD dobj
# , punct
# while mark
# 37 nummod
# % nsubj
# between case
# 40 nmod
# and cc
# 60 conj
# , punct
# 71 nummod
# % conj
# of case
# people nmod
# between case
# 60 nmod
# and cc
# 80 conj
# , punct
# and cc
# 85 nummod
# % conj
# of case
# people nmod
# over quantmod
# 80 nmod
# have advcl
# CVD dobj
# . punct
# The det
# average amod
# age nsubj
# of case
# death nmod
# from case
# coronary amod
# artery compound
# disease nmod
# in case
# the det
# developed amod
# world nmod
# is cop
# around advmod
# 80 ROOT
# while mark
# it nsubj
# is cop
# around advmod
# 68 advcl
# in case
# the det
# developing amod
# world nmod
# . punct
# Diagnosis nsubj
# of case
# disease nmod
# typically advmod
# occurs ROOT
# seven quantmod
# to quantmod
# ten nummod
# years nmod:npmod
# earlier advmod
# in case
# men nmod
# as mark
# compared advcl
# to case
# women nmod
# . punct
# : punct
#   dep
# 48 nummod
# Types dobj
# There expl
# are acl:relcl
# many amod
# cardiovascular amod
# diseases attr
# involving acl
# the det
# blood compound
# vessels dobj
# . punct
# They nsubjpass
# are auxpass
# known ROOT
# as case
# vascular amod
# diseases nmod
# . punct
# Coronary amod
# artery compound
# disease compound
# ( punct
# also advmod
# known acl
# as case
# coronary amod
# heart compound
# disease nmod
# and cc
# ischemic amod
# heart compound
# disease conj
# ) punct
# Peripheral amod
# arterial amod
# disease compound
# – compound
# disease nsubj
# of case
# blood compound
# vessels nmod
# that nsubj
# supply acl:relcl
# blood dobj
# to case
# the det
# arms nmod
# and cc
# legs conj
# Cerebrovascular compound
# disease compound
# – compound
# disease conj
# of case
# blood compound
# vessels nmod
# that nsubj
# supply acl:relcl
# blood dobj
# to case
# the det
# brain nmod
# ( punct
# includes dep
# stroke dobj
# ) punct
# Renal amod
# artery compound
# stenosis compound
# Aortic amod
# aneurysmThere dobj
# are cop
# also advmod
# many amod
# cardiovascular amod
# diseases ROOT
# that nsubj
# involve acl:relcl
# the det
# heart dobj
# . punct
# Cardiomyopathy amod
# – compound
# diseases nsubj
# of case
# cardiac amod
# muscle compound
# Hypertensive compound
# heart compound
# disease compound
# – compound
# diseases nmod
# of case
# the det
# heart nmod
# secondary amod
# to case
# high amod
# blood compound
# pressure nmod
# or cc
# hypertension compound
# Heart compound
# failure conj
# - punct
# a det
# clinical amod
# syndrome conj
# caused acl
# by case
# the det
# inability nmod
# of case
# the det
# heart nmod
# to mark
# supply acl
# sufficient amod
# blood dobj
# to case
# the det
# tissues nmod
# to mark
# meet acl:relcl
# their nmod:poss
# metabolic amod
# requirements dobj
# Pulmonary amod
# heart compound
# disease compound
# – dobj
# a det
# failure dobj
# at case
# the det
# right amod
# side nmod
# of case
# the det
# heart nmod
# with case
# respiratory amod
# system nmod
# involvement ROOT
# Cardiac amod
# dysrhythmias compound
# – compound
# abnormalities dobj
# of case
# heart compound
# rhythm compound
# Inflammatory amod
# heart compound
# disease compound
# Endocarditis compound
# – compound
# inflammation nmod
# of case
# the det
# inner amod
# layer nmod
# of case
# the det
# heart nmod
# , punct
# the det
# endocardium appos
# . punct
# The det
# structures nsubj
# most advmod
# commonly advmod
# involved acl
# are cop
# the det
# heart compound
# valves ROOT
# . punct
# Inflammatory amod
# cardiomegaly compound
# Myocarditis compound
# – compound
# inflammation nsubj
# of case
# the det
# myocardium nmod
# , punct
# the det
# muscular amod
# part appos
# of case
# the det
# heart nmod
# , punct
# caused ROOT
# most advmod
# often advmod
# by case
# viral amod
# infection nmod
# and cc
# less advmod
# often conj
# by case
# bacterial amod
# infections nmod
# , punct
# certain amod
# medications conj
# , punct
# toxins conj
# , punct
# and cc
# autoimmune amod
# disorders conj
# . punct
# It nsubjpass
# is auxpass
# characterized ROOT
# in case
# part nmod
# by case
# infiltration nmod
# of case
# the det
# heart nmod
# by case
# lymphocyte nmod
# and cc
# monocyte conj
# types dep
# of case
# white amod
# blood compound
# cells nmod
# . punct
# Eosinophilic amod
# myocarditis compound
# - punct
# inflammation ROOT
# of case
# the det
# myocardium nmod
# caused acl
# by case
# pathologically advmod
# activated amod
# eosinophilic amod
# white amod
# blood compound
# cells nmod
# . punct
# This det
# disorder nsubj
# differs ROOT
# from case
# myocarditis nmod
# in case
# its nmod:poss
# causes nmod
# and cc
# treatments conj
# . punct
# Valvular amod
# heart compound
# disease compound
# Congenital amod
# heart compound
# disease compound
# – compound
# heart compound
# structure compound
# malformations nsubj
# existing acl
# at case
# birth compound
# Rheumatic amod
# heart compound
# disease compound
# – compound
# heart compound
# muscles nmod
# and cc
# valves conj
# damage ROOT
# due advmod
# to pcomp
# rheumatic amod
# fever dobj
# caused acl
# by case
#   nummod
# Streptococcus compound
# pyogenes nmod
# a det
# group compound
# A compound
# streptococcal amod
# infection dobj
# . punct
# Risk compound
# factors nsubj
# There expl
# are ROOT
# many amod
# risk compound
# factors attr
# for case
# heart compound
# diseases nmod
# : punct
# age dep
# , punct
# sex conj
# , punct
# tobacco compound
# use conj
# , punct
# physical amod
# inactivity conj
# , punct
# excessive amod
# alcohol compound
# consumption conj
# , punct
# unhealthy amod
# diet conj
# , punct
# obesity conj
# , punct
# genetic amod
# predisposition conj
# and cc
# family compound
# history conj
# of case
# cardiovascular amod
# disease nmod
# , punct
# raised conj
# blood compound
# pressure dobj
# ( punct
# hypertension appos
# ) punct
# , punct
# raised conj
# blood compound
# sugar dobj
# ( punct
# diabetes compound
# mellitus appos
# ) punct
# , punct
# raised conj
# blood compound
# cholesterol dobj
# ( punct
# hyperlipidemia appos
# ) punct
# , punct
# undiagnosed conj
# celiac amod
# disease dobj
# , punct
# psychosocial amod
# factors conj
# , punct
# poverty conj
# and cc
# low amod
# educational amod
# status conj
# , punct
# air compound
# pollution conj
# and cc
# poor amod
# sleep conj
# . punct
# While mark
# the det
# individual amod
# contribution nsubj
# of case
# each det
# risk compound
# factor nmod
# varies advcl
# between case
# different amod
# communities nmod
# or cc
# ethnic amod
# groups conj
# the det
# overall amod
# contribution dobj
# of case
# these det
# risk compound
# factors nmod
# is cop
# very advmod
# consistent ROOT
# . punct
# Some nsubj
# of case
# these det
# risk compound
# factors nmod
# , punct
# such case
# as mwe
# age nmod
# , punct
# sex conj
# or cc
# family conj
# history/genetic amod
# predisposition conj
# , punct
# are cop
# immutable ROOT
# ; punct
# however advmod
# , punct
# many amod
# important amod
# cardiovascular amod
# risk compound
# factors nsubj
# are cop
# modifiable parataxis
# by case
# lifestyle compound
# change nmod
# , punct
# social amod
# change conj
# , punct
# drug compound
# treatment conj
# ( punct
# for case
# example compound
# prevention nmod
# of case
# hypertension nmod
# , punct
# hyperlipidemia conj
# , punct
# and cc
# diabetes conj
# ) punct
# . punct
# People nsubj
# with case
# obesity nmod
# are cop
# at case
# increased amod
# risk ROOT
# of case
# atherosclerosis nmod
# of case
# the det
# coronary amod
# arteries nmod
# . punct
# Genetics compound
# Genetic amod
# factors nsubj
# influence ROOT
# the det
# development dobj
# of case
# cardiovascular amod
# disease nmod
# in case
# men nmod
# who nsubj
# are cop
# less amod
# than quantmod
# 55 nummod
# years nmod:npmod
# old acl:relcl
# and cc
# in case
# women conj
# who nsubj
# are cop
# less amod
# than quantmod
# 65 nummod
# years nmod:npmod
# old acl:relcl
# . punct
# Cardiovascular amod
# disease nsubj
# in case
# a det
# person nmod:poss
# 's case
# parents nmod
# increases ROOT
# their nmod:poss
# risk dobj
# by case
# 3 nummod
# fold nmod
# . punct
# Multiple amod
# single amod
# nucleotide compound
# polymorphisms nsubjpass
# ( punct
# SNP appos
# ) punct
# have aux
# been auxpass
# found ROOT
# to mark
# be auxpass
# associated xcomp
# with case
# cardiovascular amod
# disease nmod
# in case
# genetic amod
# association compound
# studies nmod
# , punct
# but cc
# usually advmod
# , punct
# their nmod:poss
# individual amod
# influence nsubj
# is cop
# small conj
# , punct
# and cc
# genetic conj
# contributions nmod
# to case
# cardiovascular amod
# disease nmod
# are auxpass
# poorly advmod
# understood conj
# . punct
# Age compound
# Age nsubj
# is cop
# the det
# most advmod
# important amod
# risk compound
# factor ROOT
# in mark
# developing advcl
# cardiovascular amod
# or cc
# heart conj
# diseases dobj
# , punct
# with case
# approximately advmod
# a det
# tripling nmod
# of case
# risk nmod
# with case
# each det
# decade nmod
# of case
# life nmod
# . punct
#   nummod
# Coronary amod
# fatty amod
# streaks nsubj
# can aux
# begin ROOT
# to mark
# form xcomp
# in case
# adolescence nmod
# . punct
# It nsubjpass
# is auxpass
# estimated ROOT
# that mark
# 82 nummod
# percent nsubj
# of case
# people nmod
# who nsubj
# die acl:relcl
# of case
# coronary amod
# heart compound
# disease nmod
# are cop
# 65 ccomp
# and cc
# older conj
# . punct
# Simultaneously advmod
# , punct
# the det
# risk nsubjpass
# of case
# stroke compound
# doubles nmod
# every det
# decade nmod:tmod
# after mark
# age compound
# 55.Multiple compound
# explanations nsubjpass
# are auxpass
# proposed ROOT
# to mark
# explain xcomp
# why advmod
# age nsubj
# increases ccomp
# the det
# risk dobj
# of case
# cardiovascular/heart amod
# diseases nmod
# . punct
# One nsubj
# of case
# them nmod
# relates ROOT
# to case
# serum compound
# cholesterol compound
# level nmod
# . punct
# In case
# most amod
# populations nmod
# , punct
# the det
# serum compound
# total amod
# cholesterol compound
# level nsubj
# increases ROOT
# as case
# age compound
# increases nmod
# . punct
# In case
# men nmod
# , punct
# this det
# increase compound
# levels ROOT
# off case
# around case
# age nmod
# 45 nummod
# to dep
# 50 conj
# years nmod
# . punct
# In case
# women nmod
# , punct
# the det
# increase nsubj
# continues ROOT
# sharply advmod
# until case
# age nmod
# 60 quantmod
# to quantmod
# 65 nummod
# years nmod
# . punct
# Aging nsubjpass
# is auxpass
# also advmod
# associated ROOT
# with case
# changes nmod
# in case
# the det
# mechanical amod
# and cc
# structural conj
# properties nmod
# of case
# the det
# vascular amod
# wall nmod
# , punct
# which nsubj
# leads acl:relcl
# to case
# the det
# loss nmod
# of case
# arterial amod
# elasticity nmod
# and cc
# reduced amod
# arterial amod
# compliance conj
# and cc
# may aux
# subsequently advmod
# lead conj
# to case
# coronary amod
# artery compound
# disease nmod
# . punct
# Sex compound
# Men nsubj
# are cop
# at case
# greater amod
# risk ROOT
# of case
# heart compound
# disease nmod
# than case
# pre-menopausal amod
# women nmod
# . punct
# Once case
# past amod
# menopause nmod
# , punct
# it nsubjpass
# has aux
# been auxpass
# argued ROOT
# that mark
# a det
# woman nmod:poss
# 's case
# risk nsubj
# is cop
# similar ccomp
# to case
# a det
# man nmod:poss
# 's case
# although case
# more advmod
# recent amod
# data nmod
# from case
# the dep
# WHO nmod
# and cc
# UN compound
# disputes conj
# this dobj
# . punct
# If mark
# a det
# female nsubj
# has advcl
# diabetes dobj
# , punct
# she nsubj
# is cop
# more advmod
# likely ROOT
# to mark
# develop xcomp
# heart compound
# disease dobj
# than case
# a det
# male nmod
# with case
# diabetes nmod
# . punct
# Coronary amod
# heart compound
# diseases nsubj
# are cop
# 2 compound
# to dep
# 5 nmod:npmod
# times quantmod
# more advmod
# common ROOT
# among case
# middle-aged amod
# men nmod
# than case
# women nmod
# . punct
#   nsubj
# In case
# a det
# study nmod
# done acl
# by case
# the det
# World compound
# Health compound
# Organization nmod
# , punct
# sex nsubj
# contributes ROOT
# to case
# approximately advmod
# 40 nummod
# % nmod
# of case
# the det
# variation nmod
# in case
# sex compound
# ratios nmod
# of case
# coronary amod
# heart compound
# disease compound
# mortality nmod
# . punct
# Another det
# study nsubj
# reports ROOT
# similar amod
# results dobj
# finding acl
# that mark
# sex compound
# differences nsubj
# explains ccomp
# nearly advmod
# half nummod
# the det
# risk dobj
# associated acl
# with case
# cardiovascular amod
# diseases nmod
# One nummod
# of case
# the det
# proposed amod
# explanations nmod
# for case
# sex compound
# differences nmod
# in case
# cardiovascular amod
# diseases nmod
# is cop
# hormonal amod
# difference ccomp
# . punct
#   ROOT
# Among case
# women nmod
# , punct
# estrogen nsubj
# is cop
# the det
# predominant amod
# sex compound
# hormone appos
# . punct
# Estrogen nsubj
# may aux
# have ROOT
# protective amod
# effects dobj
# on case
# glucose compound
# metabolism nmod
# and cc
# hemostatic amod
# system conj
# , punct
# and cc
# may aux
# have conj
# direct amod
# effect dobj
# in case
# improving amod
# endothelial amod
# cell compound
# function nmod
# . punct
#   nummod
# The det
# production ROOT
# of case
# estrogen compound
# decreases nmod
# after case
# menopause nmod
# , punct
# and cc
# this nsubj
# may aux
# change conj
# the det
# female amod
# lipid compound
# metabolism dobj
# toward case
# a det
# more advmod
# atherogenic amod
# form nmod
# by mark
# decreasing advcl
# the det
# HDL compound
# cholesterol compound
# level dobj
# while mark
# increasing amod
# LDL nmod
# and cc
# total amod
# cholesterol compound
# levels conj
# . punct
# Among case
# men nmod
# and cc
# women conj
# , punct
# there expl
# are ROOT
# differences attr
# in case
# body compound
# weight nmod
# , punct
# height conj
# , punct
# body compound
# fat compound
# distribution conj
# , punct
# heart compound
# rate conj
# , punct
# stroke dep
# volume dobj
# , punct
# and cc
# arterial amod
# compliance conj
# . punct
# In case
# the det
# very advmod
# elderly amod
# , punct
# age-related dep
# large amod
# artery compound
# pulsatility nmod
# and cc
# stiffness conj
# is auxpass
# more advmod
# pronounced ROOT
# among case
# women nmod
# than case
# men nmod
# . punct
# This nsubjpass
# may aux
# be auxpass
# caused ROOT
# by case
# the det
# women nmod:poss
# 's case
# smaller amod
# body compound
# size nmod
# and cc
# arterial amod
# dimensions conj
# which nsubj
# are cop
# independent acl:relcl
# of case
# menopause nmod
# . punct
# Tobacco compound
# Cigarettes nsubj
# are cop
# the det
# major amod
# form ROOT
# of case
# smoked amod
# tobacco nmod
# . punct
# Risks nsubj
# to case
# health nmod
# from case
# tobacco compound
# use nmod
# result ROOT
# not neg
# only cc:preconj
# from case
# direct amod
# consumption dobj
# of case
# tobacco nmod
# , punct
# but cc
# also advmod
# from case
# exposure conj
# to case
# second-hand amod
# smoke nmod
# . punct
# Approximately advmod
# 10 nummod
# % nsubjpass
# of case
# cardiovascular amod
# disease nmod
# is auxpass
# attributed ROOT
# to case
# smoking nmod
# ; punct
# however advmod
# , punct
# people nsubj
# who nsubj
# quit acl:relcl
# smoking dobj
# by case
# age nmod
# 30 nummod
# have parataxis
# almost advmod
# as case
# low amod
# a det
# risk nmod
# of case
# death nmod
# as case
# never neg
# smokers nmod
# . punct
# Physical amod
# inactivity compound
# Insufficient amod
# physical amod
# activity nsubj
# ( punct
# defined dep
# as advmod
# less amod
# than quantmod
# 5 nummod
# x cc
# 30 conj
# minutes nmod
# of case
# moderate amod
# activity nmod
# per case
# week nmod
# , punct
# or cc
# less amod
# than dep
# 3 nummod
# x cc
# 20 conj
# minutes nmod
# of case
# vigorous amod
# activity nmod
# per case
# week nmod
# ) punct
# is cop
# currently advmod
# the det
# fourth amod
# leading amod
# risk compound
# factor ROOT
# for case
# mortality nmod
# worldwide advmod
# . punct
#   advcl
# In case
# 2008 nmod
# , punct
# 31.3 nummod
# % nsubj
# of case
# adults nmod
# aged amod
# 15 dobj
# or cc
# older conj
# ( punct
# 28.2 nummod
# % compound
# men dep
# and cc
# 34.4 compound
# % compound
# women conj
# ) punct
# were cop
# insufficiently advmod
# physically advmod
# active ROOT
# . punct
# The det
# risk nsubjpass
# of case
# ischemic amod
# heart compound
# disease nmod
# and cc
# diabetes compound
# mellitus conj
# is auxpass
# reduced ROOT
# by case
# almost advmod
# a det
# third nmod
# in case
# adults nmod
# who nsubj
# participate acl:relcl
# in case
# 150 nummod
# minutes nmod
# of case
# moderate amod
# physical amod
# activity nmod
# each det
# week nmod:tmod
# ( punct
# or cc
# equivalent conj
# ) punct
# . punct
# In case
# addition nmod
# , punct
# physical amod
# activity compound
# assists ROOT
# weight compound
# loss dep
# and cc
# improves conj
# blood compound
# glucose compound
# control conj
# , punct
# blood compound
# pressure conj
# , punct
# lipid compound
# profile conj
# and cc
# insulin compound
# sensitivity conj
# . punct
# These det
# effects nsubj
# may aux
# , punct
# at advmod
# least mwe
# in case
# part nmod
# , punct
# explain ROOT
# its nmod:poss
# cardiovascular amod
# benefits dobj
# . punct
# Diet amod
# High amod
# dietary amod
# intakes nsubjpass
# of case
# saturated amod
# fat nmod
# , punct
# trans-fats conj
# and cc
# salt conj
# , punct
# and cc
# low amod
# intake conj
# of case
# fruits nmod
# , punct
# vegetables conj
# and cc
# fish conj
# are auxpass
# linked ROOT
# to case
# cardiovascular amod
# risk nmod
# , punct
# although mark
# whether mark
# all predet
# these det
# associations nsubj
# indicate advcl
# causes nsubjpass
# is auxpass
# disputed ccomp
# . punct
# The det
# World compound
# Health compound
# Organization nsubj
# attributes ROOT
# approximately advmod
# 1.7 compound
# million nummod
# deaths nmod:npmod
# worldwide advmod
# to case
# low amod
# fruit nmod
# and cc
# vegetable amod
# consumption conj
# . punct
#   nummod
# Frequent amod
# consumption ROOT
# of case
# high-energy amod
# foods nmod
# , punct
# such case
# as mwe
# processed amod
# foods nmod
# that nsubj
# are cop
# high acl:relcl
# in case
# fats nmod
# and cc
# sugar conj

# %%
patterns=list(doc._.hearst_patterns)

# %%
#Entity-Linker
nlp.add_pipe("scispacy_linker", config={"resolve_abbreviations": True, "name": "umls"})
doc=nlp(text)
# Out:
# https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/data/linkers/2020-10-09/umls/tfidf_vectors_sparse.npz not found in cache, downloading to /var/folders/6t/fjr9gh2x3kzfp_x8d04mv8gm0000gn/T/tmpy42b5kyg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-5030d2384d0b> in <module>
#       1 #Entity-Linker
# ----> 2 nlp.add_pipe("scispacy_linker")
#       3 doc=nlp(text)
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/spacy/language.py in add_pipe(self, factory_name, name, before, after, first, last, source, config, raw_config, validate)
#     785                     lang_code=self.lang,
#     786                 )
# --> 787             pipe_component = self.create_pipe(
#     788                 factory_name,
#     789                 name=name,
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/spacy/language.py in create_pipe(self, factory_name, name, config, raw_config, validate)
#     668         # We're calling the internal _fill here to avoid constructing the
#     669         # registered functions twice
# --> 670         resolved = registry.resolve(cfg, validate=validate)
#     671         filled = registry.fill({"cfg": cfg[factory_name]}, validate=validate)["cfg"]
#     672         filled = Config(filled)
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/thinc/config.py in resolve(cls, config, schema, overrides, validate)
#     727         validate: bool = True,
#     728     ) -> Dict[str, Any]:
# --> 729         resolved, _ = cls._make(
#     730             config, schema=schema, overrides=overrides, validate=validate, resolve=True
#     731         )
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/thinc/config.py in _make(cls, config, schema, overrides, resolve, validate)
#     776         if not is_interpolated:
#     777             config = Config(orig_config).interpolate()
# --> 778         filled, _, resolved = cls._fill(
#     779             config, schema, validate=validate, overrides=overrides, resolve=resolve
#     780         )
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/thinc/config.py in _fill(cls, config, schema, validate, resolve, parent, overrides)
#     848                     # We don't want to try/except this and raise our own error
#     849                     # here, because we want the traceback if the function fails.
# --> 850                     getter_result = getter(*args, **kwargs)
#     851                 else:
#     852                     # We're not resolving and calling the function, so replace
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/scispacy/linking.py in __init__(self, nlp, name, candidate_generator, resolve_abbreviations, k, threshold, no_definition_threshold, filter_for_definitions, max_entities_per_mention, linker_name)
#      82         Span.set_extension("kb_ents", default=[], force=True)
#      83
# ---> 84         self.candidate_generator = candidate_generator or CandidateGenerator(
#      85             name=linker_name
#      86         )
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/scispacy/candidate_generation.py in __init__(self, ann_index, tfidf_vectorizer, ann_concept_aliases_list, kb, verbose, ef_search, name)
#     220         linker_paths = DEFAULT_PATHS.get(name, UmlsLinkerPaths)
#     221
# --> 222         self.ann_index = ann_index or load_approximate_nearest_neighbours_index(
#     223             linker_paths=linker_paths, ef_search=ef_search
#     224         )
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/scispacy/candidate_generation.py in load_approximate_nearest_neighbours_index(linker_paths, ef_search)
#     131     """
#     132     concept_alias_tfidfs = scipy.sparse.load_npz(
# --> 133         cached_path(linker_paths.tfidf_vectors)
#     134     ).astype(numpy.float32)
#     135     ann_index = nmslib.init(
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/scispacy/file_cache.py in cached_path(url_or_filename, cache_dir)
#      34     if parsed.scheme in ("http", "https"):
#      35         # URL, so get it from the cache (downloading if necessary)
# ---> 36         return get_from_cache(url_or_filename, cache_dir)
#      37     elif os.path.exists(url_or_filename):
#      38         # File, and it exists.
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/scispacy/file_cache.py in get_from_cache(url, cache_dir)
#     131
#     132             # GET file object
# --> 133             http_get(url, temp_file)
#     134
#     135             # we are copying the file before closing it, so flush to avoid truncation
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/scispacy/file_cache.py in http_get(url, temp_file)
#      95 def http_get(url: str, temp_file: IO) -> None:
#      96     req = requests.get(url, stream=True)
# ---> 97     for chunk in req.iter_content(chunk_size=1024):
#      98         if chunk:  # filter out keep-alive new chunks
#      99             temp_file.write(chunk)
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/requests/models.py in generate()
#     756             if hasattr(self.raw, 'stream'):
#     757                 try:
# --> 758                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     759                         yield chunk
#     760                 except ProtocolError as e:
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     574         else:
#     575             while not is_fp_closed(self._fp):
# --> 576                 data = self.read(amt=amt, decode_content=decode_content)
#     577
#     578                 if data:
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     517             else:
#     518                 cache_content = False
# --> 519                 data = self._fp.read(amt) if not fp_closed else b""
#     520                 if (
#     521                     amt != 0 and not data
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/http/client.py in read(self, amt)
#     460             # Amount is given, implement using readinto
#     461             b = bytearray(amt)
# --> 462             n = self.readinto(b)
#     463             return memoryview(b)[:n].tobytes()
#     464         else:
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/http/client.py in readinto(self, b)
#     504         # connection, and the user is reading more bytes than will be provided
#     505         # (for example, reading in 1k chunks)
# --> 506         n = self.fp.readinto(b)
#     507         if not n and b:
#     508             # Ideally, we would raise IncompleteRead if the content-length
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
