# %%
import spacy
import scispacy
from scispacy.abbreviation import AbbreviationDetector
from scispacy.linking import EntityLinker
from scispacy.hyponym_detector import HyponymDetector
import pandas as pd
from spacy import displacy
import deplacy

# %%
with open ("/Users/abhinavshinow/Documents/GitHub/Bert_Based_NER/Data_Collection/heart-data.txt","r") as f:
    text=f.read().replace("\n\n"," ").replace("\n"," ")
text=text[:10000]

# %%
nlp=spacy.load("en_core_sci_sm")
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/spacy/util.py:762: UserWarning: [W095] Model 'en_core_sci_sm' (0.4.0) was trained with spaCy v3.0 and may not be 100% compatible with the current version (3.1.4). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
doc=nlp(text)

# %%
nlp.add_pipe("scispacy_linker")
nlp.add_pipe("abbreviation_detector")
nlp.add_pipe("hyponym_detector", last=True, config={"extended": False})
# Out:
# https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/data/linkers/2020-10-09/umls/tfidf_vectors_sparse.npz not found in cache, downloading to /var/folders/6t/fjr9gh2x3kzfp_x8d04mv8gm0000gn/T/tmpghxydfuv

# %%
for token in doc:
    print(token.text,token.dep_)
# Out:
# " punct
# Cardiovascular amod
# disease nsubj
# ( punct
# CVD appos
# ) punct
# is cop
# a det
# class ROOT
# of case
# diseases nmod
# that nsubj
# involve acl:relcl
# the det
# heart compound
# or cc
# blood conj
# vessels dobj
# . punct
# CVD nsubj
# includes ROOT
# coronary amod
# artery compound
# diseases dobj
# ( punct
# CAD appos
# ) punct
# such case
# as mwe
# angina nmod
# and cc
# myocardial conj
# infarction conj
# ( punct
# commonly advmod
# known dep
# as case
# a det
# heart compound
# attack nmod
# ) punct
# . punct
# Other amod
# CVDs nsubj
# include ROOT
# stroke dobj
# , punct
# heart compound
# failure conj
# , punct
# hypertensive amod
# heart compound
# disease conj
# , punct
# rheumatic amod
# heart compound
# disease conj
# , punct
# cardiomyopathy conj
# , punct
# abnormal amod
# heart compound
# rhythms conj
# , punct
# congenital amod
# heart compound
# disease conj
# , punct
# valvular amod
# heart compound
# disease conj
# , punct
# carditis conj
# , punct
# aortic amod
# aneurysms conj
# , punct
# peripheral amod
# artery compound
# disease conj
# , punct
# thromboembolic compound
# disease conj
# , punct
# and cc
# venous amod
# thrombosis conj
# . punct
# The det
# underlying amod
# mechanisms nsubj
# vary ROOT
# depending case
# on case
# the det
# disease nmod
# . punct
# Coronary amod
# artery compound
# disease nsubj
# , punct
# stroke conj
# , punct
# and cc
# peripheral amod
# artery compound
# disease conj
# involve ROOT
# atherosclerosis dobj
# . punct
# This nsubjpass
# may aux
# be auxpass
# caused ROOT
# by case
# high amod
# blood compound
# pressure nmod
# , punct
# smoking conj
# , punct
# diabetes compound
# mellitus conj
# , punct
# lack conj
# of case
# exercise nmod
# , punct
# obesity conj
# , punct
# high amod
# blood compound
# cholesterol conj
# , punct
# poor amod
# diet conj
# , punct
# excessive amod
# alcohol compound
# consumption conj
# , punct
#   conj
# and cc
# poor conj
# sleep conj
# , punct
# among case
# others nmod
# . punct
# High amod
# blood compound
# pressure nsubjpass
# is auxpass
# estimated ROOT
# to mark
# account xcomp
# for case
# approximately advmod
# 13 nummod
# % nmod
# of case
# CVD compound
# deaths nmod
# , punct
# while mark
# tobacco compound
# accounts nsubj
# for case
# 9 nummod
# % nmod
# , punct
# diabetes advcl
# 6 nummod
# % dobj
# , punct
# lack appos
# of case
# exercise nmod
# 6 nummod
# % dobj
# and cc
# obesity conj
# 5 nummod
# % dobj
# . punct
# Rheumatic amod
# heart compound
# disease nsubj
# may aux
# follow ROOT
# untreated amod
# strep compound
# throat dobj
# . punct
# It nsubjpass
# is auxpass
# estimated ROOT
# that mark
# up advmod
# to dep
# 90 nummod
# % nsubj
# of case
# CVD nmod
# may aux
# be cop
# preventable ccomp
# . punct
# Prevention nsubj
# of case
# CVD nmod
# involves ROOT
# improving xcomp
# risk compound
# factors dobj
# through dobj
# : punct
# healthy amod
# eating advcl
# , punct
# exercise conj
# , punct
# avoidance conj
# of case
# tobacco compound
# smoke nmod
# and cc
# limiting amod
# alcohol compound
# intake conj
# . punct
# Treating csubj
# risk compound
# factors dobj
# , punct
# such case
# as mwe
# high amod
# blood compound
# pressure nmod
# , punct
# blood compound
# lipids conj
# and cc
# diabetes conj
# is cop
# also advmod
# beneficial ROOT
# . punct
# Treating csubj
# people dobj
# who nsubj
# have aux
# strep advmod
# throat ROOT
# with case
# antibiotics nmod
# can aux
# decrease conj
# the det
# risk dobj
# of case
# rheumatic amod
# heart compound
# disease nmod
# . punct
# The det
# use nsubj
# of case
# aspirin nmod
# in case
# people nmod
# , punct
# who nsubj
# are cop
# otherwise advmod
# healthy acl:relcl
# , punct
# is cop
# of case
# unclear amod
# benefit ROOT
# . punct
# Cardiovascular amod
# diseases nsubj
# are cop
# the det
# leading amod
# cause ROOT
# of case
# death nmod
# worldwide advmod
# except case
# Africa nmod
# . punct
# Together advmod
# CVD nsubj
# resulted ROOT
# in case
# 17.9 compound
# million nummod
# deaths nmod
# ( punct
# 32.1 nummod
# % appos
# ) punct
# in case
# 2015 nmod
# , punct
# up advmod
# from case
# 12.3 compound
# million nmod
# ( punct
# 25.8 nummod
# % nmod:npmod
# ) punct
# in case
# 1990 nmod
# . punct
# Deaths nsubj
# , punct
# at case
# a det
# given amod
# age nmod
# , punct
# from case
# CVD nmod
# are cop
# more advmod
# common ROOT
# and cc
# have aux
# been aux
# increasing conj
# in case
# much nmod
# of case
# the det
# developing amod
# world nmod
# , punct
# while mark
# rates nsubj
# have aux
# declined advcl
# in case
# most nmod
# of case
# the det
# developed amod
# world nmod
# since case
# the det
# 1970s nmod
# . punct
# Coronary amod
# artery compound
# disease ROOT
# and cc
# stroke conj
# account dobj
# for case
# 80 nummod
# % nmod
# of case
# CVD compound
# deaths nmod
# in case
# males nmod
# and cc
# 75 nummod
# % conj
# of case
# CVD compound
# deaths nmod
# in case
# females nmod
# . punct
# Most amod
# cardiovascular amod
# disease nsubj
# affects ROOT
# older amod
# adults dobj
# . punct
# In case
# the det
# United compound
# States nmod
# 11 nummod
# % nsubj
# of case
# people nmod
# between case
# 20 nmod
# and cc
# 40 conj
# have ROOT
# CVD dobj
# , punct
# while mark
# 37 nummod
# % nsubj
# between case
# 40 nmod
# and cc
# 60 conj
# , punct
# 71 nummod
# % conj
# of case
# people nmod
# between case
# 60 nmod
# and cc
# 80 conj
# , punct
# and cc
# 85 nummod
# % conj
# of case
# people nmod
# over quantmod
# 80 nmod
# have advcl
# CVD dobj
# . punct
# The det
# average amod
# age nsubj
# of case
# death nmod
# from case
# coronary amod
# artery compound
# disease nmod
# in case
# the det
# developed amod
# world nmod
# is cop
# around advmod
# 80 ROOT
# while mark
# it nsubj
# is cop
# around advmod
# 68 advcl
# in case
# the det
# developing amod
# world nmod
# . punct
# Diagnosis nsubj
# of case
# disease nmod
# typically advmod
# occurs ROOT
# seven quantmod
# to quantmod
# ten nummod
# years nmod:npmod
# earlier advmod
# in case
# men nmod
# as mark
# compared advcl
# to case
# women nmod
# . punct
# : punct
#   dep
# 48 nummod
# Types dobj
# There expl
# are acl:relcl
# many amod
# cardiovascular amod
# diseases attr
# involving acl
# the det
# blood compound
# vessels dobj
# . punct
# They nsubjpass
# are auxpass
# known ROOT
# as case
# vascular amod
# diseases nmod
# . punct
# Coronary amod
# artery compound
# disease compound
# ( punct
# also advmod
# known acl
# as case
# coronary amod
# heart compound
# disease nmod
# and cc
# ischemic amod
# heart compound
# disease conj
# ) punct
# Peripheral amod
# arterial amod
# disease compound
# – compound
# disease nsubj
# of case
# blood compound
# vessels nmod
# that nsubj
# supply acl:relcl
# blood dobj
# to case
# the det
# arms nmod
# and cc
# legs conj
# Cerebrovascular compound
# disease compound
# – compound
# disease conj
# of case
# blood compound
# vessels nmod
# that nsubj
# supply acl:relcl
# blood dobj
# to case
# the det
# brain nmod
# ( punct
# includes dep
# stroke dobj
# ) punct
# Renal amod
# artery compound
# stenosis compound
# Aortic amod
# aneurysmThere dobj
# are cop
# also advmod
# many amod
# cardiovascular amod
# diseases ROOT
# that nsubj
# involve acl:relcl
# the det
# heart dobj
# . punct
# Cardiomyopathy amod
# – compound
# diseases nsubj
# of case
# cardiac amod
# muscle compound
# Hypertensive compound
# heart compound
# disease compound
# – compound
# diseases nmod
# of case
# the det
# heart nmod
# secondary amod
# to case
# high amod
# blood compound
# pressure nmod
# or cc
# hypertension compound
# Heart compound
# failure conj
# - punct
# a det
# clinical amod
# syndrome conj
# caused acl
# by case
# the det
# inability nmod
# of case
# the det
# heart nmod
# to mark
# supply acl
# sufficient amod
# blood dobj
# to case
# the det
# tissues nmod
# to mark
# meet acl:relcl
# their nmod:poss
# metabolic amod
# requirements dobj
# Pulmonary amod
# heart compound
# disease compound
# – dobj
# a det
# failure dobj
# at case
# the det
# right amod
# side nmod
# of case
# the det
# heart nmod
# with case
# respiratory amod
# system nmod
# involvement ROOT
# Cardiac amod
# dysrhythmias compound
# – compound
# abnormalities dobj
# of case
# heart compound
# rhythm compound
# Inflammatory amod
# heart compound
# disease compound
# Endocarditis compound
# – compound
# inflammation nmod
# of case
# the det
# inner amod
# layer nmod
# of case
# the det
# heart nmod
# , punct
# the det
# endocardium appos
# . punct
# The det
# structures nsubj
# most advmod
# commonly advmod
# involved acl
# are cop
# the det
# heart compound
# valves ROOT
# . punct
# Inflammatory amod
# cardiomegaly compound
# Myocarditis compound
# – compound
# inflammation nsubj
# of case
# the det
# myocardium nmod
# , punct
# the det
# muscular amod
# part appos
# of case
# the det
# heart nmod
# , punct
# caused ROOT
# most advmod
# often advmod
# by case
# viral amod
# infection nmod
# and cc
# less advmod
# often conj
# by case
# bacterial amod
# infections nmod
# , punct
# certain amod
# medications conj
# , punct
# toxins conj
# , punct
# and cc
# autoimmune amod
# disorders conj
# . punct
# It nsubjpass
# is auxpass
# characterized ROOT
# in case
# part nmod
# by case
# infiltration nmod
# of case
# the det
# heart nmod
# by case
# lymphocyte nmod
# and cc
# monocyte conj
# types dep
# of case
# white amod
# blood compound
# cells nmod
# . punct
# Eosinophilic amod
# myocarditis compound
# - punct
# inflammation ROOT
# of case
# the det
# myocardium nmod
# caused acl
# by case
# pathologically advmod
# activated amod
# eosinophilic amod
# white amod
# blood compound
# cells nmod
# . punct
# This det
# disorder nsubj
# differs ROOT
# from case
# myocarditis nmod
# in case
# its nmod:poss
# causes nmod
# and cc
# treatments conj
# . punct
# Valvular amod
# heart compound
# disease compound
# Congenital amod
# heart compound
# disease compound
# – compound
# heart compound
# structure compound
# malformations nsubj
# existing acl
# at case
# birth compound
# Rheumatic amod
# heart compound
# disease compound
# – compound
# heart compound
# muscles nmod
# and cc
# valves conj
# damage ROOT
# due advmod
# to pcomp
# rheumatic amod
# fever dobj
# caused acl
# by case
#   nummod
# Streptococcus compound
# pyogenes nmod
# a det
# group compound
# A compound
# streptococcal amod
# infection dobj
# . punct
# Risk compound
# factors nsubj
# There expl
# are ROOT
# many amod
# risk compound
# factors attr
# for case
# heart compound
# diseases nmod
# : punct
# age dep
# , punct
# sex conj
# , punct
# tobacco compound
# use conj
# , punct
# physical amod
# inactivity conj
# , punct
# excessive amod
# alcohol compound
# consumption conj
# , punct
# unhealthy amod
# diet conj
# , punct
# obesity conj
# , punct
# genetic amod
# predisposition conj
# and cc
# family compound
# history conj
# of case
# cardiovascular amod
# disease nmod
# , punct
# raised conj
# blood compound
# pressure dobj
# ( punct
# hypertension appos
# ) punct
# , punct
# raised conj
# blood compound
# sugar dobj
# ( punct
# diabetes compound
# mellitus appos
# ) punct
# , punct
# raised conj
# blood compound
# cholesterol dobj
# ( punct
# hyperlipidemia appos
# ) punct
# , punct
# undiagnosed conj
# celiac amod
# disease dobj
# , punct
# psychosocial amod
# factors conj
# , punct
# poverty conj
# and cc
# low amod
# educational amod
# status conj
# , punct
# air compound
# pollution conj
# and cc
# poor amod
# sleep conj
# . punct
# While mark
# the det
# individual amod
# contribution nsubj
# of case
# each det
# risk compound
# factor nmod
# varies advcl
# between case
# different amod
# communities nmod
# or cc
# ethnic amod
# groups conj
# the det
# overall amod
# contribution dobj
# of case
# these det
# risk compound
# factors nmod
# is cop
# very advmod
# consistent ROOT
# . punct
# Some nsubj
# of case
# these det
# risk compound
# factors nmod
# , punct
# such case
# as mwe
# age nmod
# , punct
# sex conj
# or cc
# family conj
# history/genetic amod
# predisposition conj
# , punct
# are cop
# immutable ROOT
# ; punct
# however advmod
# , punct
# many amod
# important amod
# cardiovascular amod
# risk compound
# factors nsubj
# are cop
# modifiable parataxis
# by case
# lifestyle compound
# change nmod
# , punct
# social amod
# change conj
# , punct
# drug compound
# treatment conj
# ( punct
# for case
# example compound
# prevention nmod
# of case
# hypertension nmod
# , punct
# hyperlipidemia conj
# , punct
# and cc
# diabetes conj
# ) punct
# . punct
# People nsubj
# with case
# obesity nmod
# are cop
# at case
# increased amod
# risk ROOT
# of case
# atherosclerosis nmod
# of case
# the det
# coronary amod
# arteries nmod
# . punct
# Genetics compound
# Genetic amod
# factors nsubj
# influence ROOT
# the det
# development dobj
# of case
# cardiovascular amod
# disease nmod
# in case
# men nmod
# who nsubj
# are cop
# less amod
# than quantmod
# 55 nummod
# years nmod:npmod
# old acl:relcl
# and cc
# in case
# women conj
# who nsubj
# are cop
# less amod
# than quantmod
# 65 nummod
# years nmod:npmod
# old acl:relcl
# . punct
# Cardiovascular amod
# disease nsubj
# in case
# a det
# person nmod:poss
# 's case
# parents nmod
# increases ROOT
# their nmod:poss
# risk dobj
# by case
# 3 nummod
# fold nmod
# . punct
# Multiple amod
# single amod
# nucleotide compound
# polymorphisms nsubjpass
# ( punct
# SNP appos
# ) punct
# have aux
# been auxpass
# found ROOT
# to mark
# be auxpass
# associated xcomp
# with case
# cardiovascular amod
# disease nmod
# in case
# genetic amod
# association compound
# studies nmod
# , punct
# but cc
# usually advmod
# , punct
# their nmod:poss
# individual amod
# influence nsubj
# is cop
# small conj
# , punct
# and cc
# genetic conj
# contributions nmod
# to case
# cardiovascular amod
# disease nmod
# are auxpass
# poorly advmod
# understood conj
# . punct
# Age compound
# Age nsubj
# is cop
# the det
# most advmod
# important amod
# risk compound
# factor ROOT
# in mark
# developing advcl
# cardiovascular amod
# or cc
# heart conj
# diseases dobj
# , punct
# with case
# approximately advmod
# a det
# tripling nmod
# of case
# risk nmod
# with case
# each det
# decade nmod
# of case
# life nmod
# . punct
#   nummod
# Coronary amod
# fatty amod
# streaks nsubj
# can aux
# begin ROOT
# to mark
# form xcomp
# in case
# adolescence nmod
# . punct
# It nsubjpass
# is auxpass
# estimated ROOT
# that mark
# 82 nummod
# percent nsubj
# of case
# people nmod
# who nsubj
# die acl:relcl
# of case
# coronary amod
# heart compound
# disease nmod
# are cop
# 65 ccomp
# and cc
# older conj
# . punct
# Simultaneously advmod
# , punct
# the det
# risk nsubjpass
# of case
# stroke compound
# doubles nmod
# every det
# decade nmod:tmod
# after mark
# age compound
# 55.Multiple compound
# explanations nsubjpass
# are auxpass
# proposed ROOT
# to mark
# explain xcomp
# why advmod
# age nsubj
# increases ccomp
# the det
# risk dobj
# of case
# cardiovascular/heart amod
# diseases nmod
# . punct
# One nsubj
# of case
# them nmod
# relates ROOT
# to case
# serum compound
# cholesterol compound
# level nmod
# . punct
# In case
# most amod
# populations nmod
# , punct
# the det
# serum compound
# total amod
# cholesterol compound
# level nsubj
# increases ROOT
# as case
# age compound
# increases nmod
# . punct
# In case
# men nmod
# , punct
# this det
# increase compound
# levels ROOT
# off case
# around case
# age nmod
# 45 nummod
# to dep
# 50 conj
# years nmod
# . punct
# In case
# women nmod
# , punct
# the det
# increase nsubj
# continues ROOT
# sharply advmod
# until case
# age nmod
# 60 quantmod
# to quantmod
# 65 nummod
# years nmod
# . punct
# Aging nsubjpass
# is auxpass
# also advmod
# associated ROOT
# with case
# changes nmod
# in case
# the det
# mechanical amod
# and cc
# structural conj
# properties nmod
# of case
# the det
# vascular amod
# wall nmod
# , punct
# which nsubj
# leads acl:relcl
# to case
# the det
# loss nmod
# of case
# arterial amod
# elasticity nmod
# and cc
# reduced amod
# arterial amod
# compliance conj
# and cc
# may aux
# subsequently advmod
# lead conj
# to case
# coronary amod
# artery compound
# disease nmod
# . punct
# Sex compound
# Men nsubj
# are cop
# at case
# greater amod
# risk ROOT
# of case
# heart compound
# disease nmod
# than case
# pre-menopausal amod
# women nmod
# . punct
# Once case
# past amod
# menopause nmod
# , punct
# it nsubjpass
# has aux
# been auxpass
# argued ROOT
# that mark
# a det
# woman nmod:poss
# 's case
# risk nsubj
# is cop
# similar ccomp
# to case
# a det
# man nmod:poss
# 's case
# although case
# more advmod
# recent amod
# data nmod
# from case
# the dep
# WHO nmod
# and cc
# UN compound
# disputes conj
# this dobj
# . punct
# If mark
# a det
# female nsubj
# has advcl
# diabetes dobj
# , punct
# she nsubj
# is cop
# more advmod
# likely ROOT
# to mark
# develop xcomp
# heart compound
# disease dobj
# than case
# a det
# male nmod
# with case
# diabetes nmod
# . punct
# Coronary amod
# heart compound
# diseases nsubj
# are cop
# 2 compound
# to dep
# 5 nmod:npmod
# times quantmod
# more advmod
# common ROOT
# among case
# middle-aged amod
# men nmod
# than case
# women nmod
# . punct
#   nsubj
# In case
# a det
# study nmod
# done acl
# by case
# the det
# World compound
# Health compound
# Organization nmod
# , punct
# sex nsubj
# contributes ROOT
# to case
# approximately advmod
# 40 nummod
# % nmod
# of case
# the det
# variation nmod
# in case
# sex compound
# ratios nmod
# of case
# coronary amod
# heart compound
# disease compound
# mortality nmod
# . punct
# Another det
# study nsubj
# reports ROOT
# similar amod
# results dobj
# finding acl
# that mark
# sex compound
# differences nsubj
# explains ccomp
# nearly advmod
# half nummod
# the det
# risk dobj
# associated acl
# with case
# cardiovascular amod
# diseases nmod
# One nummod
# of case
# the det
# proposed amod
# explanations nmod
# for case
# sex compound
# differences nmod
# in case
# cardiovascular amod
# diseases nmod
# is cop
# hormonal amod
# difference ccomp
# . punct
#   ROOT
# Among case
# women nmod
# , punct
# estrogen nsubj
# is cop
# the det
# predominant amod
# sex compound
# hormone appos
# . punct
# Estrogen nsubj
# may aux
# have ROOT
# protective amod
# effects dobj
# on case
# glucose compound
# metabolism nmod
# and cc
# hemostatic amod
# system conj
# , punct
# and cc
# may aux
# have conj
# direct amod
# effect dobj
# in case
# improving amod
# endothelial amod
# cell compound
# function nmod
# . punct
#   nummod
# The det
# production ROOT
# of case
# estrogen compound
# decreases nmod
# after case
# menopause nmod
# , punct
# and cc
# this nsubj
# may aux
# change conj
# the det
# female amod
# lipid compound
# metabolism dobj
# toward case
# a det
# more advmod
# atherogenic amod
# form nmod
# by mark
# decreasing advcl
# the det
# HDL compound
# cholesterol compound
# level dobj
# while mark
# increasing amod
# LDL nmod
# and cc
# total amod
# cholesterol compound
# levels conj
# . punct
# Among case
# men nmod
# and cc
# women conj
# , punct
# there expl
# are ROOT
# differences attr
# in case
# body compound
# weight nmod
# , punct
# height conj
# , punct
# body compound
# fat compound
# distribution conj
# , punct
# heart compound
# rate conj
# , punct
# stroke dep
# volume dobj
# , punct
# and cc
# arterial amod
# compliance conj
# . punct
# In case
# the det
# very advmod
# elderly amod
# , punct
# age-related dep
# large amod
# artery compound
# pulsatility nmod
# and cc
# stiffness conj
# is auxpass
# more advmod
# pronounced ROOT
# among case
# women nmod
# than case
# men nmod
# . punct
# This nsubjpass
# may aux
# be auxpass
# caused ROOT
# by case
# the det
# women nmod:poss
# 's case
# smaller amod
# body compound
# size nmod
# and cc
# arterial amod
# dimensions conj
# which nsubj
# are cop
# independent acl:relcl
# of case
# menopause nmod
# . punct
# Tobacco compound
# Cigarettes nsubj
# are cop
# the det
# major amod
# form ROOT
# of case
# smoked amod
# tobacco nmod
# . punct
# Risks nsubj
# to case
# health nmod
# from case
# tobacco compound
# use nmod
# result ROOT
# not neg
# only cc:preconj
# from case
# direct amod
# consumption dobj
# of case
# tobacco nmod
# , punct
# but cc
# also advmod
# from case
# exposure conj
# to case
# second-hand amod
# smoke nmod
# . punct
# Approximately advmod
# 10 nummod
# % nsubjpass
# of case
# cardiovascular amod
# disease nmod
# is auxpass
# attributed ROOT
# to case
# smoking nmod
# ; punct
# however advmod
# , punct
# people nsubj
# who nsubj
# quit acl:relcl
# smoking dobj
# by case
# age nmod
# 30 nummod
# have parataxis
# almost advmod
# as case
# low amod
# a det
# risk nmod
# of case
# death nmod
# as case
# never neg
# smokers nmod
# . punct
# Physical amod
# inactivity compound
# Insufficient amod
# physical amod
# activity nsubj
# ( punct
# defined dep
# as advmod
# less amod
# than quantmod
# 5 nummod
# x cc
# 30 conj
# minutes nmod
# of case
# moderate amod
# activity nmod
# per case
# week nmod
# , punct
# or cc
# less amod
# than dep
# 3 nummod
# x cc
# 20 conj
# minutes nmod
# of case
# vigorous amod
# activity nmod
# per case
# week nmod
# ) punct
# is cop
# currently advmod
# the det
# fourth amod
# leading amod
# risk compound
# factor ROOT
# for case
# mortality nmod
# worldwide advmod
# . punct
#   advcl
# In case
# 2008 nmod
# , punct
# 31.3 nummod
# % nsubj
# of case
# adults nmod
# aged amod
# 15 dobj
# or cc
# older conj
# ( punct
# 28.2 nummod
# % compound
# men dep
# and cc
# 34.4 compound
# % compound
# women conj
# ) punct
# were cop
# insufficiently advmod
# physically advmod
# active ROOT
# . punct
# The det
# risk nsubjpass
# of case
# ischemic amod
# heart compound
# disease nmod
# and cc
# diabetes compound
# mellitus conj
# is auxpass
# reduced ROOT
# by case
# almost advmod
# a det
# third nmod
# in case
# adults nmod
# who nsubj
# participate acl:relcl
# in case
# 150 nummod
# minutes nmod
# of case
# moderate amod
# physical amod
# activity nmod
# each det
# week nmod:tmod
# ( punct
# or cc
# equivalent conj
# ) punct
# . punct
# In case
# addition nmod
# , punct
# physical amod
# activity compound
# assists ROOT
# weight compound
# loss dep
# and cc
# improves conj
# blood compound
# glucose compound
# control conj
# , punct
# blood compound
# pressure conj
# , punct
# lipid compound
# profile conj
# and cc
# insulin compound
# sensitivity conj
# . punct
# These det
# effects nsubj
# may aux
# , punct
# at advmod
# least mwe
# in case
# part nmod
# , punct
# explain ROOT
# its nmod:poss
# cardiovascular amod
# benefits dobj
# . punct
# Diet amod
# High amod
# dietary amod
# intakes nsubjpass
# of case
# saturated amod
# fat nmod
# , punct
# trans-fats conj
# and cc
# salt conj
# , punct
# and cc
# low amod
# intake conj
# of case
# fruits nmod
# , punct
# vegetables conj
# and cc
# fish conj
# are auxpass
# linked ROOT
# to case
# cardiovascular amod
# risk nmod
# , punct
# although mark
# whether mark
# all predet
# these det
# associations nsubj
# indicate advcl
# causes nsubjpass
# is auxpass
# disputed ccomp
# . punct
# The det
# World compound
# Health compound
# Organization nsubj
# attributes ROOT
# approximately advmod
# 1.7 compound
# million nummod
# deaths nmod:npmod
# worldwide advmod
# to case
# low amod
# fruit nmod
# and cc
# vegetable amod
# consumption conj
# . punct
#   nummod
# Frequent amod
# consumption nsubj
# of case
# high-energy amod
# foods nmod
# , punct
# such case
# as mwe
# processed amod
# foods nmod
# that nsubj
# are cop
# high acl:relcl
# in case
# fats nmod
# and cc
# sugars conj
# , punct
# promotes ROOT
# obesity dobj
# and cc
# may aux
# increase conj
# cardiovascular amod
# risk dobj
# . punct
#   nummod
# The det
# amount nsubj
# of case
# dietary amod
# salt nmod
# consumed acl
# may aux
# also advmod
# be cop
# an det
# important amod
# determinant ROOT
# of case
# blood compound
# pressure compound
# levels nmod
# and cc
# overall amod
# cardiovascular amod
# risk conj
# . punct
#   dep
# There expl
# is ROOT
# moderate amod
# quality compound
# evidence attr
# that mark
# reducing csubj
# saturated amod
# fat amod
# intake dobj
# for case
# at advmod
# least nmod:npmod
# two nummod
# years nmod
# reduces acl:relcl
# the det
# risk dobj
# of case
# cardiovascular amod
# disease nmod
# . punct
# High amod
# trans-fat compound
# intake nsubj
# has ROOT
# adverse amod
# effects dobj
# on case
# blood compound
# lipids nmod
# and cc
# circulating amod
# inflammatory amod
# markers conj
# , punct
# and cc
# elimination nsubjpass
# of case
# trans-fat nmod
# from case
# diets nmod
# has aux
# been auxpass
# widely advmod
# advocated conj
# . punct
# In case
# 2018 nmod
# the det
# World compound
# Health compound
# Organization nsubj
# estimated ROOT
# that mark
# trans amod
# fats nsubj
# were cop
# the det
# cause ccomp
# of case
# more amod
# than quantmod
# half quantmod
# a quantmod
# million nummod
# deaths nmod
# per case
# year nmod
# . punct
# There expl
# is ROOT
# evidence nsubj
# that mark
# higher amod
# consumption nsubjpass
# of case
# sugar nmod
# is auxpass
# associated ccomp
# with case
# higher amod
# blood compound
# pressure nmod
# and cc
# unfavorable amod
# blood compound
# lipids conj
# , punct
# and cc
# sugar compound
# intake nsubj
# also advmod
# increases conj
# the det
# risk dobj
# of case
# diabetes compound
# mellitus nmod
# . punct
# High amod
# consumption nsubjpass
# of case
# processed amod
# meats nmod
# is auxpass
# associated ROOT
# with case
# an det
# increased amod
# risk nmod
# of case
# cardiovascular amod
# disease nmod
# , punct
# possibly advmod
# in case
# part nmod
# due case
# to pcomp
# increased amod
# dietary amod
# salt compound
# intake nmod
# . punct
# Alcohol dep
# The det
# relationship nsubj
# between case
# alcohol compound
# consumption nmod
# and cc
# cardiovascular amod
# disease conj
# is cop
# complex ROOT
# , punct
# and cc
# may aux
# depend conj
# on case
# the det
# amount nmod
# of case
# alcohol nmod
# consumed acl
# . punct
# There expl
# is ROOT
# a det
# direct amod
# relationship nsubj
# between case
# high amod
# levels nmod
# of case
# drinking compound
# alcohol nmod
# and cc
# cardiovascular amod
# disease conj
# . punct
#   nummod
# Drinking nsubjpass
# at case
# low amod
# levels nmod
# without case
# episodes nmod
# of case
# heavy amod
# drinking nmod
# may aux
# be auxpass
# associated ROOT
# with case
# a det
# reduced amod
# risk nmod
# of case
# cardiovascular amod
# disease nmod
# , punct
# but cc
# there expl
# is conj
# evidence attr
# that mark
# associations nsubj
# between case
# moderate amod
# alcohol compound
# consumption nmod
# and cc
# protection conj
# from case
# stroke nmod
# are cop
# non-causal acl
# . punct
# At case
# the det
# population compound
# level nmod
# , punct
# the det
# health compound
# risks nsubj
# of case
# drinking compound
# alcohol nmod
# exceed ROOT
# any det
# potential amod
# benefits dobj
# . punct
# Celiac amod
# disease compound
# Untreated amod
# celiac amod
# disease nsubj
# can aux
# cause ROOT
# the det
# development dobj
# of case
# many amod
# types nmod
# of case
# cardiovascular amod
# diseases nmod
# , punct
# most nsubj
# of case
# which nmod
# improve acl:relcl
# or cc
# resolve conj
# with case
# a det
# gluten-free amod
# diet nmod
# and cc
# intestinal amod
# healing conj
# . punct
# However advmod
# , punct
# delays nsubj
# in case
# recognition nmod
# and cc
# diagnosis conj
# of case
# celiac amod
# disease nmod
# can aux
# cause ROOT
# irreversible amod
# heart compound
# damage dobj
# . punct
# Sleep nsubj
# Not neg
# getting ROOT
# good amod
# sleep dobj
# , punct
# in case
# amount nmod
# or cc
# quality conj
# , punct
# is auxpass
# documented conj
# as mark
# increasing amod
# cardiovascular amod
# risk dobj
# in case
# both det
# adults nmod
# and cc
# teens conj
# . punct
# Recommendations nsubj
# suggest ROOT
# that mark
# Infants nsubj
# typically advmod
# need ccomp
# 12 nummod
# or cc
# more conj
# hours dobj
# of case
# sleep nmod
# per case
# day nmod
# , punct
# adolescent xcomp
# at case
# least advmod
# eight nummod
# or cc
# nine conj
# hours nmod:npmod
# , punct
# and cc
# adults conj
# seven dep
# or cc
# eight conj
# . punct
# About advmod
# one-third nsubj
# of case
# adult amod
# Americans nmod
# get ROOT
# less dobj
# than case
# the det
# recommended amod
# seven nummod
# hours nmod
# of case
# sleep nmod
# per case
# night nmod
# , punct
# and cc
# in case
# a det
# study nmod
# of case
# teenagers nmod
# , punct
# just advmod
# 2.2 nummod
# percent nsubj
# of case
# those nmod
# studied acl
# got conj
# enough amod
# sleep dobj
# , punct
# many nsubj
# of case
# whom nmod
# did aux
# not neg
# get acl:relcl
# good amod
# quality compound
# sleep dobj
# . punct
#   nummod
# Studies nsubj
# have aux
# shown ROOT
# that mark
# short amod
# sleepers nsubj
# getting acl
# less amod
# than quantmod
# seven nummod
# hours compound
# sleep dobj
# per case
# night nmod
# have ccomp
# a det
# 10 nummod
# percent dobj
# to case
# 30 nummod
# percent nmod:npmod
# higher amod
# risk nmod
# of case
# cardiovascular amod
# disease nmod
# . punct
# Sleep compound
# disorders nsubjpass
# such case
# as mwe
# sleep nmod:npmod
# disordered amod
# breathing nmod
# and cc
# insomnia conj
# , punct
# are auxpass
# also advmod
# associated ROOT
# with case
# a det
# higher amod
# cardiometabolic amod
# risk nmod
# . punct
# An det
# estimated amod
# 50 quantmod
# to quantmod
# 70 compound
# million nummod
# Americans nsubj
# suffer ROOT
# from case
# insomnia nmod
# , punct
# sleep compound
# apnea conj
# or cc
# other amod
#   nummod
# chronic amod
# sleep compound
# disorders conj
# . punct
# In case
# addition nmod
# , punct
# sleep compound
# research nsubj
# displays ROOT
# differences dobj
# in case
# race nmod
# and cc
# class conj
# . punct
# Short amod
# sleep nsubj
# and cc
# poor amod
# sleep conj
# tend ROOT
# to mark
# be auxpass
# more advmod
# frequently advmod
# reported xcomp
# in case
# ethnic amod
# minorities nmod
# than case
# in case
#   nummod
# whites advcl
# . punct
# African-Americans amod
# report ROOT
# experiencing acl
# short amod
# durations dobj
# of case
# sleep nmod
# five nummod
# times nmod:npmod
# more advmod
# often advmod
# than case
# whites nmod
# , punct
# possibly advmod
# as case
# a det
# result nmod
# of case
# social amod
# and cc
# environmental conj
# factors nmod
# . punct
#   nummod
# Black amod
# children nsubj
# and cc
# children conj
# in case
# disadvantaged amod
# neighborhoods nmod
# have ccomp
# much advmod
# higher amod
# rates dobj
# of case
# sleep compound
# apnea nmod
# than case
# white amod
# children nmod
# , punct
# Socioeconomic compound
# disadvantage compound
# Cardiovascular compound
# disease nsubj
# affects ROOT
# low- amod
# and cc
# middle-income conj
# countries dobj
# even advmod
# more advmod
# than case
# high-income amod
# countries nmod
# . punct
# There expl
# is ROOT
# relatively advmod
# little amod
# information nsubj
# regarding case
# social amod
# patterns nmod
# of case
# cardiovascular amod
# disease nmod
# within case
# low- amod
# and cc
# middle-income conj
# countries nmod
# , punct
# but cc
# within case
# high-income amod
# countries nmod
# low amod
# income nsubjpass
# and cc
# low amod
# educational amod
# status conj
# are auxpass
# consistently advmod
# associated conj
# with case
# greater amod
# risk nmod
# of case
# cardiovascular amod
# disease nmod
# . punct
# Policies nsubjpass
# that nsubj
# have aux
# resulted acl:relcl
# in case
# increased amod
# socio-economic amod
# inequalities nmod
# have aux
# been auxpass
# associated ROOT
# with case
# greater amod
# subsequent dep
# socio-economic amod
# differences nmod
# in case
# cardiovascular amod
# disease nmod
# implying acl
# a det
# cause dobj
# and cc
# effect conj
# relationship conj
# . punct
# Psychosocial amod
# factors nsubj
# , punct
# environmental amod
# exposures conj
# , punct
# health compound
# behaviours conj
# , punct
# and cc
# health-care amod
# access conj
# and cc
# quality conj
# contribute ROOT
# to case
# socio-economic amod
# differentials nmod
# in case
# cardiovascular amod
# disease nmod
# . punct
# The det
# Commission nsubj
# on case
# Social compound
# Determinants nmod
# of case
# Health nmod
# recommended ROOT
# that mark
# more advmod
# equal amod
# distributions nsubjpass
# of case
# power nmod
# , punct
# wealth conj
# , punct
# education conj
# , punct
# housing conj
# , punct
# environmental amod
# factors conj
# , punct
# nutrition conj
# , punct
# and cc
# health compound
# care conj
# were auxpass
# needed ccomp
# to mark
# address xcomp
# inequalities dobj
# in case
# cardiovascular amod
# disease nmod
# and cc
# non-communicable amod
# diseases conj
# . punct
# Air compound
# pollution compound
# Particulate compound
# matter nsubjpass
# has aux
# been auxpass
# studied ROOT
# for case
# its nmod:poss
# short- amod
# and cc
# long-term conj
# exposure compound
# effects nmod
# on case
# cardiovascular amod
# disease nmod
# . punct
# Currently advmod
# , punct
# airborne amod
# particles nsubj
# under case
# 2.5 nummod
# micrometers nmod
# in case
# diameter nmod
# ( punct
# PM2.5 appos
# ) punct
# are cop
# the det
# major amod
# focus ROOT
# , punct
# in case
# which nmod
# gradients nsubjpass
# are auxpass
# used acl:relcl
# to mark
# determine xcomp
# CVD compound
# risk dobj
# . punct
# Overall advmod
# , punct
# long-term amod
# PM compound
# exposure nsubj
# increased ROOT
# rate dobj
# of case
# atherosclerosis nmod
# and cc
# inflammation conj
# . punct
# In case
# regards nmod
# to case
# short-term amod
# exposure nmod
# ( punct
# 2 nummod
# hours appos
# ) punct
# , punct
# every det
# 25 nummod
# μg/m3 nsubj
# of case
# PM2.5 nmod
# resulted ROOT
# in case
# a det
# 48 compound
# % compound
# increase nmod
# of case
# CVD compound
# mortality compound
# risk nmod
# . punct
# In case
# addition nmod
# , punct
# after case
# only advmod
# 5 nummod
# days nmod
# of case
# exposure nmod
# , punct
# a det
# rise nsubj
# in case
# systolic nmod
# ( punct
# 2.8 nummod
# mmHg appos
# ) punct
# and cc
# diastolic conj
# ( punct
# 2.7 nummod
# mmHg appos
# ) punct
# blood compound
# pressure nsubj
# occurred ROOT
# for case
# every det
# 10.5 nummod
# μg/m3 nmod
# of case
# PM2.5 nmod
# . punct
#   nummod
# Other amod
# research nsubj
# has aux
# implicated ROOT
# PM2.5 dobj
# in case
# irregular amod
# heart compound
# rhythm nmod
# , punct
# reduced amod
# heart compound
# rate compound
# variability dobj
# ( punct
# decreased amod
# vagal amod
# tone appos
# ) punct
# , punct
# and cc
# most advmod
# notably advmod
# heart compound
# failure conj
# . punct
#   nummod
# PM2.5 nsubjpass
# is auxpass
# also advmod
# linked ROOT
# to mark
# carotid xcomp
# artery compound
# thickening dobj
# and cc
# increased amod
# risk conj
# of case
# acute amod
# myocardial amod
# infarction nmod
# . punct
# Cardiovascular amod
# risk compound
# assessment compound
# Existing amod
# cardiovascular amod
# disease nsubj
# or cc
# a det
# previous amod
# cardiovascular amod
# event conj
# , punct
# such case
# as mwe
# a det
# heart compound
# attack nmod
# or cc
# stroke conj
# , punct
# is cop
# the det
# strongest amod
# predictor ROOT
# of case
# a det
# future amod
# cardiovascular amod
# event nmod
# . punct
# Age nsubj
# , punct
# sex conj
# , punct
# smoking conj
# , punct
# blood compound
# pressure conj
# , punct
# blood compound
# lipids conj
# and cc
# diabetes conj
# are cop
# important amod
# predictors ROOT
# of case
# future amod
# cardiovascular amod
# disease nmod
# in case
# people nmod
# who nsubjpass
# are auxpass
# not neg
# known acl:relcl
# to mark
# have xcomp
# cardiovascular amod
# disease dobj
# . punct
# These det
# measures nsubjpass
# , punct
# and cc
# sometimes advmod
# others conj
# , punct
# may aux
# be auxpass
# combined ROOT
# into case
# composite amod
# risk compound
# scores nmod
# to mark
# estimate xcomp
# an det
# individual nmod:poss
# 's case
# future amod
# risk dobj
# of case
# cardiovascular amod
# disease nmod
# . punct
# Numerous amod
# risk compound
# scores nsubj
# exist ROOT
# although mark
# their nmod:poss
# respective amod
# merits nsubjpass
# are auxpass
# debated advcl
# . punct
# Other amod
# diagnostic amod
# tests nsubj
# and cc
# biomarkers conj
# remain ROOT
# under case
# evaluation nmod
# but cc
# currently advmod
# these det
# lack compound
# clear-cut amod
# evidence conj
# to mark
# support acl
# their nmod:poss
# routine amod
# use dobj
# . punct
# They nsubj
# include ROOT
# family compound
# history dobj
# , punct
# coronary amod
# artery compound
# calcification compound
# score conj
# , punct
# high amod
# sensitivity compound
# C-reactive amod
# protein conj
# ( punct
# hs-CRP appos
# ) punct
# , punct
# ankle compound
# – compound
# brachial amod
# pressure compound
# index conj
# , punct
#   nummod
# lipoprotein compound
# subclasses conj
# and cc
# particle compound
# concentration conj
# , punct
# lipoprotein(a appos
# ) punct
# , punct
# apolipoproteins conj
# A-I dobj
# and cc
# B conj
# , punct
# fibrinogen conj
# , punct
# white amod
# blood compound
# cell compound
# count conj
# , punct
# homocysteine conj
# , punct
# N-terminal amod
# pro amod
# B-type amod
# natriuretic amod
# peptide appos
#   nummod
# ( punct
# NT-proBNP appos
# ) punct
# , punct
# and cc
# markers conj
# of case
# kidney compound
# function nmod
# . punct
# High amod
# blood compound
# phosphorus nsubjpass
# is auxpass
# also advmod
# linked ROOT
# to case
# an det
# increased amod
# risk nmod
# . punct
# Depression nsubj
# and cc
# traumatic amod
# stress conj
# There expl
# is ROOT
# evidence nsubj
# that mark
# mental amod
# health compound
# problems nsubjpass
# , punct
# in case
# particular amod
# depression nmod
# and cc
# traumatic amod
# stress conj
# , punct
# is auxpass
# linked ccomp
# to case
# cardiovascular amod
# diseases nmod
# . punct
# Whereas mark
# mental amod
# health compound
# problems nsubjpass
# are auxpass
# known advcl
# to mark
# be auxpass
# associated xcomp
# with case
# risk compound
# factors nmod
# for case
# cardiovascular amod
# diseases nmod
# such case
# as mwe
# smoking nmod
# , punct
# poor amod
# diet conj
# , punct
# and cc
# a det
# sedentary amod
# lifestyle conj
# , punct
# these det
# factors nsubj
# alone advmod
# do aux
# not neg
# explain ROOT
# the det
# increased amod
# risk dobj
# of case
# cardiovascular amod
# diseases nmod
# seen acl
# in case
# depression nmod
# , punct
# stress conj
# , punct
# and cc
# anxiety conj
# . punct
# Moreover advmod
# , punct
# posttraumatic amod
# stress compound
# disorder nsubjpass
# is auxpass
# independently advmod
# associated ROOT
# with case
# increased amod
# risk nmod
# for case
# incident amod
# coronary amod
# heart compound
# disease nmod
# , punct
# even advmod
# after mark
# adjusting advcl
# for case
# depression nmod
# and cc
# other amod
# covariates conj
# . punct
# Occupational amod
# exposure compound
# Little nsubjpass
# is auxpass
# known ROOT
# about case
# the det
# relationship nmod
# between case
# work nmod
# and cc
# cardiovascular amod
# disease conj
# , punct
# but cc
# links nsubjpass
# have aux
# been auxpass
# established conj
# between case
# certain amod
# toxins nmod
# , punct
# extreme amod
# heat conj
# and cc
# cold conj
# , punct
# exposure conj
# to case
# tobacco compound
# smoke nmod
# , punct
# and cc
# mental amod
# health compound
# concerns conj
# such case
# as mwe
# stress nmod
# and cc
# depression conj
# . punct
# Non-chemical amod
# risk compound
# factors nsubj
# A det
# 2015 nummod
# SBU-report dobj
# looking acl
# at case
# non-chemical amod
# factors nmod
# found ROOT
# an det
# association dobj
# for case
# those nmod
# : punct
# with case
# mentally advmod
# stressful amod
# work nmod
# with case
# a det
# lack nmod
# of case
# control nmod
# over case
# their nmod:poss
# working compound
# situation compound
# — nmod
# with case
# an det
# effort-reward amod
# imbalance nmod
# who nsubj
# experience acl:relcl
# low amod
# social amod
# support dobj
# at case
# work nmod
# ; punct
# who nsubj
# experience acl:relcl
# injustice dobj
# or cc
# experience conj
# insufficient amod
# opportunities dobj
# for case
# personal amod
# development nmod
# ; punct
# or cc
# those conj
# who nsubj
# experience acl:relcl
# job compound
# insecurity dobj
# those dobj
# who nsubj
# work acl:relcl
# night compound
# schedules dobj
# ; punct
# or cc
# have conj
# long amod
# working compound
# weeks dobj
# those dobj
# who nsubjpass
# are auxpass
# exposed acl:relcl
# to case
# noiseSpecifically advmod
# the det
# risk nmod
# of case
# stroke nmod
# was auxpass
# also advmod
# increased ccomp
# by case
# exposure nmod
# to case
# ionizing amod
# radiation nmod
# . punct
# Hypertension nsubj
# develops ROOT
# more advmod
# often advmod
# in case
# those nmod
# who nsubj
# experience acl:relcl
# job compound
# strain dobj
# and cc
# who nsubj
# have conj
# shift-work dobj
# . punct
# Differences nsubj
# between case
# women nmod
# and cc
# men conj
# in case
# risk nmod
# are cop
# small ROOT
# , punct
# however advmod
# men nsubj
# risk conj
# suffering dobj
# and cc
# dying conj
# of case
# heart compound
# attacks nmod
# or cc
# stroke conj
# twice advmod
# as advmod
# often advmod
# as case
# women nmod
# during case
# working amod
# life nmod
# . punct
# Chemical compound
# risk compound
# factors nsubj
# A det
# 2017 nummod
# SBU compound
# report nsubj
# found ROOT
# evidence dobj
# that mark
# workplace amod
# exposure nsubjpass
# to mark
# silica acl
# dust dobj
# , punct
# engine compound
# exhaust conj
# or cc
# welding compound
# fumes conj
# is auxpass
# associated ccomp
# with case
# heart compound
# disease nmod
# . punct
# Associations nsubj
# also advmod
# exist ROOT
# for case
# exposure nmod
# to case
# arsenic amod
# , punct
# benzopyrenes nmod
# , punct
# lead conj
# , punct
# dynamite conj
# , punct
# carbon compound
# disulphide conj
# , punct
# carbon compound
# monoxide conj
# , punct
# metalworking amod
# fluids conj
# and cc
# occupational amod
# exposure conj
# to case
# tobacco compound
# smoke nmod
# . punct
# Working ROOT
#   dobj
# with case
#   nmod
# the det
#   nummod
# electrolytic amod
# production dobj
# of case
#   nummod
# aluminium nmod
#   dep
# or cc
#   conj
# the det
#   compound
# production nmod
#   nummod
# of case
#   nummod
# paper nmod
#   nummod
# when advmod
#   nummod
# the det
#   nummod
# sulphate nsubjpass
# pulping acl
#   nummod
# process dobj
#   appos
# is cop
#   nmod:npmod
# used advcl
#   dobj
# is cop
#   appos
# associated acl
# with case
# heart compound
# disease nmod
# . punct
# An det
# association nsubjpass
# was auxpass
# also advmod
# found ROOT
#   dobj
# between case
#   nummod
# heart compound
#   compound
# disease nmod
#   dep
# and cc
#   conj
# exposure nmod
#   acl
# to case
#   nummod
# compounds nmod
#   appos
# which det
#   nsubj
# are cop
#   nummod
# no det
#   compound
# longer amod
#   nsubj
# permitted conj
#   dobj
# in case
# certain amod
#   nummod
# work compound
#   nummod
# environments nmod
# , punct
#   nummod
# such amod
#   dep
# as case
#   nummod
# phenoxy compound
# acids nmod
# containing acl
# TCDD(dioxin dobj
# ) punct
# or cc
# asbestos conj
# . punct
# Workplace compound
# exposure nsubjpass
# to mark
# silica acl
# dust dobj
# or cc
# asbestos conj
# is auxpass
# also advmod
# associated ROOT
# with case
# pulmonary amod
# heart compound
# disease nmod
# . punct
# There expl
# is ROOT
# evidence nsubj
# that nsubj
# workplace acl:relcl
#   nummod
# exposure dobj
# to mark
# lead xcomp
# , punct
# carbon compound
# disulphide conj
# , punct
# phenoxyacids nsubj
# containing acl
#   nummod
# TCDD dobj
# , punct
# as cc
# well advmod
# as mwe
# working acl
# in case
# an det
# environment nmod
# where advmod
# aluminum nsubjpass
# is aux
# being auxpass
# electrolytically advmod
# produced acl:relcl
# , punct
# is auxpass
# associated conj
# with case
# stroke nmod
# . punct
# Somatic amod
# mutations nsubj
# As prep
# of case
# 2017 nmod
# , punct
# evidence nsubj
# suggests ROOT
# that mark
# certain amod
# leukemia-associated amod
# mutations nsubj
# in case
# blood compound
# cells nmod
# may aux
# also advmod
# lead ccomp
# to case
# increased amod
# risk nmod
# of case
# cardiovascular amod
# disease nmod
# . punct
# Several amod
# large-scale amod
# research compound
# projects nsubj
# looking acl
# at case
# human amod
# genetic amod
# data nmod
# have aux
# found ROOT
# a det
# robust amod
# link dobj
# between case
# the det
# presence nmod
# of case
# these det
# mutations nmod
# , punct
# a det
# condition nmod:npmod
# known acl
# as case
# clonal amod
# hematopoiesis nmod
# , punct
# and cc
# cardiovascular amod
# disease-related amod
# incidents conj
# and cc
# mortality conj
# . punct
# Radiation compound
# therapy compound
# Radiation compound
# treatments nsubj
# for case
# cancer nmod
# can aux
# increase ROOT
# the det
# risk dobj
# of case
# heart compound
# disease nmod
# and cc
# death conj
# , punct
# as mark
# observed advcl
# in case
# breast compound
# cancer compound
# therapy nmod
# . punct
#   nummod
# Therapeutic amod
# radiation nsubj
# increases ROOT
# the det
# risk dobj
# of case
# a det
# subsequent amod
# heart compound
# attack nmod
# or cc
# stroke conj
# by case
# 1.5 compound
# to dep
# 4 nummod
# times quantmod
# the det
# normal amod
# rate nmod
# . punct
# The det
# increase nsubj
# is cop
# dose-dependent ROOT
# , punct
# depending case
# on case
# the det
# dose compound
# strength advcl
# , punct
# volume conj
# , punct
# and cc
# location conj
# . punct
# Side-effects nsubjpass
# from case
# radiation compound
# therapy nmod
# for case
# cardiovascular amod
# diseases nmod
# have aux
# been auxpass
# termed ROOT
# radiation-induced amod
# heart compound
# disease xcomp
# or cc
# radiation-induced amod
# vascular amod
# disease conj
# . punct
# Symptoms nsubj
# are cop
# dose-dependent ROOT
# and cc
# include conj
# cardiomyopathy dobj
# , punct
# myocardial amod
# fibrosis conj
# , punct
# valvular amod
# heart compound
# disease conj
# , punct
# coronary amod
# artery compound
# disease conj
# , punct
# heart compound
# arrhythmia conj
# and cc
# peripheral amod
# artery compound
# disease conj
# . punct
# Radiation-induced amod
# fibrosis nsubj
# , punct
# vascular amod
# cell compound
# damage conj
# and cc
# oxidative amod
# stress conj
# can aux
# lead ROOT
# to case
# these nmod
# and cc
# other amod
# late amod
# side-effect amod
# symptoms conj
# . punct
# Pathophysiology compound
# Population-based amod
# studies nsubj
# show ROOT
# that mark
# atherosclerosis nsubj
# , punct
# the det
# major amod
# precursor appos
# of case
# cardiovascular amod
# disease nmod
# , punct
# begins ccomp
# in case
# childhood nmod
# . punct
# The det
# Pathobiological amod
# Determinants compound
# of case
# Atherosclerosis nmod
# in case
# Youth nmod
# ( punct
# PDAY appos
# ) punct
# study nsubj
# demonstrated ROOT
# that mark
# intimal amod
# lesions nsubj
# appear ccomp
# in case
# all predet
# the det
# aortas nmod
# and cc
# more amod
# than quantmod
# half conj
# of case
# the det
# right amod
# coronary amod
# arteries nmod
# of case
# youths nmod
# aged amod
# 7–9 amod
# years nmod
# . punct
# This nsubj
# is cop
# extremely advmod
# important ROOT
# considering xcomp
# that mark
# 1 nummod
# in quantmod
# 3 nummod
# people nsubj
# die ccomp
# from case
# complications nmod
# attributable amod
# to case
# atherosclerosis nmod
# . punct
# In mark
# order mwe
# to mark
# stem ROOT
# the det
# tide dobj
# , punct
# education conj
# and cc
# awareness conj
# that mark
# cardiovascular amod
# disease nsubj
# poses ccomp
# the det
# greatest amod
# threat dobj
# , punct
# and cc
# measures conj
# to mark
# prevent xcomp
# or cc
# reverse conj
# this det
# disease nsubjpass
# must aux
# be auxpass
# taken ccomp
# . punct
# Obesity compound
# and cc
# diabetes conj
# mellitus nsubjpass
# are auxpass
# often advmod
# linked ROOT
# to case
# cardiovascular amod
# disease nmod
# , punct
# as mark
# are cop
# a det
# history advcl
# of case
# chronic amod
# kidney compound
# disease nmod
# and cc
# hypercholesterolaemia conj
# . punct
#   nsubj
# In case
# fact nmod
# , punct
# cardiovascular amod
# disease nsubj
# is cop
# the det
# most amod
# life-threatening ROOT
# of case
# the det
# diabetic amod
# complications nmod
# and cc
# diabetics conj
# are cop
# two- dep
# to mark
# four-fold advmod
# more advmod
# likely amod
# to mark
# die xcomp
# of case
# cardiovascular-related amod
# causes nmod
# than case
# nondiabetics nmod
# . punct
# Screening compound
# Screening compound
# ECGs nsubjpass
# ( punct
# either cc:preconj
# at case
# rest dep
# or cc
# with case
# exercise conj
# ) punct
# are auxpass
# not neg
# recommended ROOT
# in case
# those nmod
# without case
# symptoms nmod
# who nsubj
# are cop
# at case
# low amod
# risk acl:relcl
# . punct
# This nsubj
# includes ROOT
# those dobj
# who nsubj
# are cop
# young acl:relcl
# without case
# risk compound
# factors nmod
# . punct
# In case
# those dep
# at case
# higher amod
# risk ROOT
# the det
# evidence dobj
# for case
# screening nmod
# with case
# ECGs nmod
# is cop
# inconclusive conj
# . punct
# Additionally advmod
# echocardiography nsubjpass
# , punct
# myocardial amod
# perfusion compound
# imaging conj
# , punct
# and cc
# cardiac amod
# stress compound
# testing nsubjpass
# is auxpass
# not neg
# recommended ROOT
# in case
# those nmod
# at case
# low amod
# risk nmod
# who nsubj
# do aux
# not neg
# have acl:relcl
# symptoms dobj
# . punct
# Some det
# biomarkers nsubj
# may aux
# add ROOT
# to case
# conventional amod
# cardiovascular amod
# risk compound
# factors nmod
# in mark
# predicting advcl
# the det
# risk dobj
# of case
# future amod
# cardiovascular amod
# disease nmod
# ; punct
# however advmod
# , punct
# the det
# value nsubj
# of case
# some det
# biomarkers nmod
# is cop
# questionable conj
# . punct
# Ankle-brachial amod
# index nsubj
# ( punct
# ABI appos
# ) punct
# , punct
# high-sensitivity amod
# C-reactive amod
# protein conj
# ( punct
# hsCRP appos
# ) punct
# , punct
# and cc
# coronary amod
# artery compound
# calcium conj
# , punct
# are cop
# also advmod
# of case
# unclear amod
# benefit nmod
# in case
# those nmod
# without case
# symptoms nmod
# as case
# of case
# 2018.The compound
# NIH nsubj
# recommends ROOT
# lipid compound
# testing dobj
# in case
# children nmod
# beginning acl
# at case
# the det
# age nmod
# of case
# 2 nmod
# if mark
# there expl
# is advcl
# a det
# family compound
# history attr
# of case
# heart compound
# disease nmod
# or cc
# lipid compound
# problems conj
# . punct
# It nsubjpass
# is auxpass
# hoped ROOT
# that mark
# early amod
# testing nsubj
# will aux
# improve ccomp
# lifestyle compound
# factors dobj
# in case
# those nmod
# at case
# risk nmod
# such case
# as mwe
# diet nmod
# and cc
# exercise conj
# . punct
# Screening nsubjpass
# and cc
# selection conj
# for case
# primary amod
# prevention compound
# interventions nmod
# has aux
# traditionally advmod
# been auxpass
# done ROOT
# through case
# absolute amod
# risk nmod
# using acl
# a det
# variety dobj
# of case
# scores nmod
# ( punct
# ex dep
# . punct
# Framingham compound
# or cc
# Reynolds conj
# risk compound
# scores ROOT
# ) punct
# . punct
# This det
# stratification nsubj
# has aux
# separated ROOT
# people dobj
# who nsubj
# receive acl:relcl
# the det
# lifestyle compound
# interventions dobj
# ( punct
# generally advmod
# lower dep
# and cc
# intermediate conj
# risk dep
# ) punct
# from case
# the det
# medication nmod
# ( punct
# higher amod
# risk appos
# ) punct
# . punct
# The det
# number nsubj
# and cc
# variety conj
# of case
# risk compound
# scores nmod
# available amod
# for case
# use nmod
# has aux
# multiplied ROOT
# , punct
# but cc
# their nmod:poss
# efficacy nsubj
# according case
# to mwe
# a det
# 2016 nummod
# review nmod
# was cop
# unclear conj
# due case
# to pcomp
# lack nmod
# of case
# external amod
# validation nmod
# or cc
# impact compound
# analysis conj
# . punct
# Risk compound
# stratification compound
# models nsubj
# often advmod
# lack ROOT
# sensitivity dobj
# for case
# population compound
# groups nmod
# and cc
# do aux
# not neg
# account conj
# for case
# the det
# large amod
# number nmod
# of case
# negative amod
# events nmod
# among case
# the det
# intermediate amod
# and cc
# low conj
# risk compound
# groups nmod
# . punct
# As case
# a det
# result nmod
# , punct
# future amod
# preventative amod
# screening nsubj
# appears ROOT
# to mark
# shift xcomp
# toward mark
# applying advcl
# prevention dobj
# according case
# to mwe
# randomized amod
# trial compound
# results nmod
# of case
# each det
# intervention nmod
# rather advmod
# than case
# large-scale amod
# risk compound
# assessment nmod
# . punct
# Prevention nsubj
# Up advmod
# to dep
# 90 nummod
# % conj
# of case
# cardiovascular amod
# disease nmod
# may aux
# be cop
# preventable ROOT
# if mark
# established amod
# risk compound
# factors nsubjpass
# are auxpass
# avoided advcl
# . punct
# Currently advmod
# practiced amod
# measures nsubj
# to mark
# prevent acl
# cardiovascular amod
# disease dobj
# include ccomp
# : punct
# Reduction dobj
# in case
# consumption nmod
# of case
# saturated amod
# fat nmod
# : punct
# there expl
# is ROOT
# moderate amod
# quality compound
# evidence attr
# that nsubj
# reducing acl:relcl
# the det
# proportion dobj
# of case
# saturated amod
# fat nmod
# in case
# the det
# diet nmod
# , punct
# and cc
# replacing conj
# it dobj
# with case
# unsaturated amod
# fats nmod
# or cc
# carbohydrates conj
# over case
# a det
# period nmod
# of case
# at advmod
# least nmod:npmod
# two nummod
# years nmod
# , punct
# leads conj
# to case
# a det
# reduction nmod
# in case
# the det
# risk nmod
# of case
# cardiovascular amod
# disease nmod
# . punct
# Stopping ROOT
# smoking dobj
# and cc
# avoidance conj
# of case
# second-hand amod
# smoke nmod
# . punct
# Stopping compound
# smoking nsubj
# reduces ROOT
# risk dobj
# by case
# about advmod
# 35 nummod
# % nmod
# . punct
# Maintain ROOT
# a det
# healthy amod
# diet dobj
# , punct
# such case
# as mwe
# the det
# Mediterranean amod
# diet nmod
# . punct
# Dietary amod
# interventions nsubj
# are cop
# effective ROOT
# in mark
# reducing advcl
# cardiovascular amod
# risk compound
# factors dobj
# over case
# a det
# year nmod
# , punct
# but cc
# the det
# longer amod
# term amod
# effects nsubj
# of case
# such amod
# interventions nmod
# and cc
# their nmod:poss
# impact conj
# on case
# cardiovascular amod
# disease compound
# events nmod
# is cop
# uncertain conj
# . punct
# At case
# least nmod:npmod
# 150 nummod
# minutes ROOT
# ( punct
# 2 nummod
# hours appos
# and cc
# 30 nummod
# minutes conj
# ) punct
# of case
# moderate amod
# exercise nmod
# per case
# week nmod
# . punct
# Limit compound
# alcohol compound
# consumption ROOT
# to case
# the det
# recommended amod
# daily amod
# limits nmod
# ; punct
# People nsubj
# who nsubj
# moderately advmod
# consume acl:relcl
# alcoholic amod
# drinks dobj
# have dep
# a det
# 25–30 compound
# % nmod:npmod
# lower amod
# risk dobj
# of case
# cardiovascular amod
# disease nmod
# . punct
# However advmod
# , punct
# people nsubj
# who nsubjpass
# are auxpass
# genetically advmod
# predisposed acl:relcl
# to mark
# consume xcomp
# less amod
# alcohol dobj
# have ROOT
# lower amod
# rates dobj
# of case
# cardiovascular amod
# disease nmod
# ...
# ; punct
# this nsubj
# can aux
# cause parataxis
# a det
# range dobj
# of case
# complications nmod
# . punct
# It nsubj
# is cop
# essential ROOT
# to mark
# make xcomp
# the det
# critical amod
# part dobj
# of case
# the det
# operation nmod
# fast ccomp
# , punct
# so advmod
# the det
# incision nsubjpass
# is auxpass
# typically advmod
# made parataxis
# large amod
# enough dobj
# to mark
# facilitate xcomp
# the det
# fastest amod
# repair dobj
# . punct
# Recovery nsubj
# after case
# open amod
# AAA compound
# surgery nmod
# takes ROOT
# significant amod
# time dobj
# . punct
# The det
# minimums nsubj
# are cop
# a det
# few amod
# days ROOT
# in case
# intensive amod
# care nmod
# , punct
# a det
# week compound
# total acl:relcl
# in case
# the det
# hospital nmod
# and cc
# a quantmod
# few amod
# months conj
# before case
# full amod
# recovery nmod
# . punct
# Endovascular nsubj
# repair nsubj
# Endovascular compound
# repair dobj
# first advmod
# became ROOT
# practical acomp
# in case
# the det
# 1990s nmod
# and cc
# although mark
# it nsubj
# is cop
# now advmod
# an det
# established amod
# alternative conj
# to mark
# open xcomp
# repair dobj
# , punct
# its nmod:poss
# role nsubj
# is cop
# yet advmod
# to mark
# be auxpass
# clearly advmod
# defined conj
# . punct
# It nsubjpass
# is auxpass
# generally advmod
# indicated ROOT
# in case
# older amod
# , punct
# high-risk dep
# patients nmod
# or cc
# patients conj
# unfit amod
# for case
# open amod
# repair nmod
# . punct
# However advmod
# , punct
# endovascular amod
# repair nsubj
# is cop
# feasible ROOT
# for case
# only advmod
# a det
# proportion nmod
# of case
# AAAs nmod
# , punct
# depending dep
# on case
# the det
# morphology nmod
# of case
# the det
# aneurysm nmod
# . punct
# The det
# main amod
# advantages nsubj
# over case
# open amod
# repair nmod
# are ROOT
# that mark
# there expl
# is ccomp
# less advmod
# peri-operative amod
# mortality attr
# , punct
# less amod
# time attr
# in case
# intensive amod
# care nmod
# , punct
# less amod
# time attr
# in case
# hospital nmod
# overall advmod
# and cc
# earlier conj
# return attr
# to case
# normal amod
# activity nmod
# . punct
# Disadvantages nsubj
# of case
# endovascular amod
# repair nmod
# include ROOT
# a det
# requirement dobj
# for case
# more advmod
# frequent amod
# ongoing amod
# hospital compound
# reviews nmod
# , punct
# and cc
# a det
# higher amod
# chance conj
# of case
# further amod
# procedures nmod
# being auxpass
# required acl
# . punct
# According case
# to mwe
# the det
# latest amod
# studies nmod
# , punct
# the det
# EVAR compound
# procedure nsubj
# does aux
# not neg
# offer ROOT
# any det
# benefit dobj
# for case
# overall amod
# survival nmod
# or cc
# health-related amod
# quality conj
# of case
# life nmod
# compared prep
# to case
# open amod
# surgery nmod
# , punct
# although mark
# aneurysm-related amod
# mortality nsubj
# is cop
# lower advcl
# . punct
# In case
# patients nmod
# unfit amod
# for case
# open amod
# repair nmod
# , punct
# EVAR nsubjpass
# plus cc
# conservative amod
# management conj
# was auxpass
# associated ROOT
# with case
# no det
# benefit nmod
# , punct
# more amod
# complications conj
# , punct
# subsequent amod
# procedures conj
# and cc
# higher amod
# costs conj
# compared acl
# to case
# conservative amod
# management nmod
# alone advmod
# . punct
# Endovascular amod
# treatment nsubj
# for case
# paraanastomotic amod
# aneurysms nmod
# after case
# aortobiiliac compound
# reconstruction nmod
# is cop
# also advmod
# a det
# possibility ROOT
# . punct
# A det
# 2017 nummod
# Cochrane compound
# review nsubj
# found ROOT
# tentative amod
# evidence dobj
# of case
# no det
# difference nmod
# in case
# outcomes nmod
# between case
# endovascular amod
# and cc
# open conj
# repair nmod
# of case
# ruptured amod
# AAA nmod
# in case
# the det
# first amod
# month nmod
# . punct
# Rupture ROOT
# In case
# those nmod
# with case
# aortic amod
# rupture nmod
# of case
# the det
# AAA nmod
# , punct
# treatment nsubj
# is cop
# immediate amod
# surgical amod
# repair conj
# . punct
# There expl
# appears ROOT
# to mark
# be cop
# benefits xcomp
# to mark
# allowing acl
# permissive amod
# hypotension dobj
# and cc
# limiting conj
# the det
# use dobj
# of case
# intravenous amod
# fluids nmod
# during case
# transport nmod
# to case
# the det
# operating compound
# room nmod
# . punct
# Prognosis nsubjpass
# Although mark
# the det
# current amod
# standard nsubjpass
# of mark
# determining advcl
# rupture compound
# risk dobj
# is auxpass
# based advcl
# on case
# maximum compound
# diameter nmod
# , punct
# it nsubjpass
# is auxpass
# known ROOT
# that mark
# smaller amod
# AAAs nsubj
# that nsubj
# fall acl:relcl
# below case
# this det
# threshold nmod
# ( punct
# diameter<5.5 compound
# cm appos
# ) punct
# may aux
# also advmod
# rupture ccomp
# , punct
# and cc
# larger amod
# AAAs nsubj
# ( punct
# diameter>5.5 compound
# cm appos
# ) punct
# may aux
# remain conj
# stable acomp
# . punct
# In case
# one nummod
# report nmod
# , punct
# it nsubjpass
# was auxpass
# shown ROOT
# that mark
# 10–24 compound
# % nsubj
# of case
# ruptured amod
# AAAs nmod
# were cop
# less amod
# than quantmod
# 5 nummod
# cm dep
# in case
# diameter nmod
# . punct
# It nsubjpass
# has aux
# also advmod
# been auxpass
# reported ROOT
# that mark
# of case
# 473 nummod
# non-repaired amod
# AAAs nmod
# examined acl
# from case
# autopsy amod
# reports nmod
# , punct
# there expl
# were ccomp
# 118 nummod
# cases nsubj
# of case
# rupture nmod
# , punct
# 13 nummod
# % attr
# of case
# which nmod
# were cop
# less amod
# than quantmod
# 5 nummod
# cm nmod
# in case
# diameter nmod
# . punct
# This det
# study nsubj
# also advmod
# showed ROOT
# that mark
# 60 nummod
# % nsubj
# of case
# the det
# AAAs nmod
# greater amod
# than advmod
# 5 nummod
# cm nmod
# ( punct
# including case
# 54 nummod
# % nmod
# of case
# those det
# AAAs nmod
# between case
# 7.1 nmod
# and cc
# 10 conj
# cm dep
# ) punct
# never neg
# experienced ccomp
# rupture dobj
# . punct
# Vorp nsubj
# et compound
# al. dep
# later advmod
# deduced acl
# from case
# the det
# findings nmod
# of case
# Darling nmod
# et dobj
# al. dep
# that mark
# if mark
# the det
# maximum compound
# diameter compound
# criterion nsubjpass
# were auxpass
# followed advcl
# for case
# the det
# 473 nummod
# subjects nmod
# , punct
# only advmod
# 7 nummod
# % nsubj
# ( punct
# 34/473 appos
# ) punct
# of case
# cases nmod
# would aux
# have aux
# succumbed ROOT
# to mark
# rupture xcomp
# prior advmod
# to case
# surgical amod
# intervention nmod
# as case
# the det
# diameter nsubj
# was cop
# less amod
# than quantmod
# 5 nummod
# cm nmod
# , punct
# with case
# 25 nummod
# % nmod
# ( punct
# 116/473 appos
# ) punct
# of case
# cases nmod
# possibly advmod
# undergoing advcl
# unnecessary amod
# surgery dobj
# since mark
# these det
# AAAs nsubj
# may aux
# never neg
# have aux
# ruptured advcl
# . punct
# Alternative amod
# methods nsubjpass
# of case
# rupture compound
# assessment nmod
# have aux
# been auxpass
# recently advmod
# reported ROOT
# . punct
# The det
# majority nsubj
# of case
# these det
# approaches nmod
# involve ROOT
# the det
# numerical amod
# analysis dobj
# of case
# AAAs nmod
# using acl
# the det
# common amod
# engineering compound
# technique dobj
# of case
# the det
# finite amod
# element compound
# method nmod
# ( punct
# FEM appos
# ) punct
# to mark
# determine advcl
# the det
# wall compound
# stress compound
# distributions dobj
# . punct
# Recent amod
# reports nsubj
# have aux
# shown ROOT
# that mark
# these det
# stress compound
# distributions nsubjpass
# have aux
# been auxpass
# shown ccomp
# to mark
# correlate xcomp
# to case
# the det
# overall amod
# geometry nmod
# of case
# the det
# AAA nmod
# rather advmod
# than case
# solely advmod
# to case
# the det
# maximum compound
# diameter nmod
# . punct
# It nsubjpass
# is auxpass
# also advmod
# known ROOT
# that mark
# wall compound
# stress nsubj
# alone advmod
# does aux
# not neg
# completely advmod
# govern amod
# failure nsubj
# as case
# an det
# AAA nmod
# will aux
# usually advmod
# rupture ccomp
# when advmod
# the det
# wall compound
# stress nsubj
# exceeds advcl
# the det
# wall compound
# strength dobj
# . punct
# In case
# light nmod
# of case
# this nmod
# , punct
# rupture compound
# assessment nsubj
# may aux
# be cop
# more advmod
# accurate ROOT
# if mark
# both cc:preconj
# the det
# patient-specific amod
# wall compound
# stress nsubjpass
# is auxpass
# coupled advcl
# together advmod
# with case
# patient-specific amod
# wall compound
# strength nmod
# . punct
# A det
# non-invasive amod
# method nsubjpass
# of mark
# determining acl
# patient-dependent amod
# wall compound
# strength dobj
# was auxpass
# recently advmod
# reported ROOT
# , punct
# with case
# more advmod
# traditional amod
# approaches nmod
# to case
# strength amod
# determination nmod
# via case
# tensile compound
# testing nmod
# performed acl
# by case
# other amod
# researchers nmod
# in case
# the det
# field nmod
# . punct
# Some nsubj
# of case
# the det
# more advmod
# recently advmod
# proposed amod
# AAA compound
# rupture-risk compound
# assessment compound
# methods nmod
# include ROOT
# : punct
# AAA compound
# wall compound
# stress dobj
# ; punct
# AAA compound
# expansion compound
# rate dep
# ; punct
# degree conj
# of case
# asymmetry nmod
# ; punct
# presence dep
# of case
# intraluminal amod
# thrombus nmod
# ( punct
# ILT appos
# ) punct
# ; punct
# a det
# rupture compound
# potential amod
# index dep
# ( punct
# RPI appos
# ) punct
# ; punct
# a det
# finite amod
# element compound
# analysis compound
# rupture compound
# index conj
# ( punct
# FEARI appos
# ) punct
# ; punct
# biomechanical amod
# factors conj
# coupled acl
# with case
# computer compound
# analysis nmod
# ; punct
# growth conj
# of case
# ILT nmod
# ; punct
# geometrical amod
# parameters conj
# of case
# the det
# AAA nmod
# ; punct
# and cc
# also advmod
# a det
# method conj
# of mark
# determining advcl
# AAA compound
# growth dobj
# and cc
# rupture conj
# based acl
# on case
# mathematical amod
# models nmod
# . punct
# The det
# post-operative amod
# mortality nsubj
# for case
# an det
# already advmod
# ruptured amod
# AAA nmod
# has aux
# slowly advmod
# decreased ROOT
# over case
# several amod
# decades nmod
# but cc
# remains conj
# higher amod
# than quantmod
# 40 nummod
# % dobj
# . punct
# However advmod
# , punct
# if mark
# the det
# AAA nsubjpass
# is auxpass
# surgically advmod
# repaired advcl
# before case
# rupture nmod
# , punct
# the det
# post-operative amod
# mortality compound
# rate nsubj
# is cop
# substantially advmod
# lower ROOT
# : punct
# approximately advmod
# 1 advmod
# - punct
# 6 nummod
# % dep
# . punct
# Epidemiology ROOT
# The det
# occurrence nsubj
# of case
# AAA nmod
# varies dep
# by case
# ethnicity nmod
# . punct
# In case
# the det
# United compound
# Kingdom nmod
# the det
# rate appos
# of case
# AAA nmod
# in case
# Caucasian amod
# men nmod
# older ROOT
# than quantmod
# 65 nummod
# years nsubj
# is cop
# about advmod
# 4.7 nummod
# % nmod
# , punct
# while mark
# in case
# Asian amod
# men nmod
# it nsubj
# is cop
# 0.45 nummod
# % advcl
# . punct
#   nmod:tmod
# It nsubj
# is cop
# also advmod
# less advmod
# common ROOT
# in case
# individuals nmod
# of case
# African nmod
# , punct
# and cc
# Hispanic amod
# heritage conj
# . punct
# They nsubj
# occur ROOT
# four nummod
# times quantmod
# more advmod
# often advmod
# in case
# men nmod
# than case
# women nmod
# . punct
# There expl
# are ROOT
# at advmod
# least advmod
# 13,000 nummod
# deaths nmod:npmod
# yearly advmod
# in case
# the det
# U.S. nmod
# secondary amod
# to case
# AAA compound
# rupture nmod
# . punct
# The det
# peak amod
# number nsubj
# of case
# new amod
# cases nmod
# per case
# year nmod
# among case
# males nmod
# is cop
# around case
# 70 nummod
# years nmod
# of case
# age nmod
# , punct
# the det
# percentage nsubj
# of case
# males nmod
# affected ROOT
# over advmod
# 60 nummod
# years nmod
# is cop
# 2–6 compound
# % dep
# . punct
# The det
# frequency nsubj
# is cop
# much advmod
# higher ROOT
# in case
# smokers nmod
# than case
# in case
# non-smokers advcl
# ( punct
# 8:1 appos
# ) punct
# , punct
# and cc
# the det
# risk nsubj
# decreases conj
# slowly advmod
# after case
# smoking compound
# cessation nmod
# . punct
# In case
# the det
# U.S. nmod
# , punct
# the det
# incidence nsubj
# of case
# AAA nmod
# is cop
# 2–4 amod
# % ROOT
# in case
# the det
# adult amod
# population nmod
# . punct
# Rupture nsubj
# of case
# the det
# AAA nmod
# occurs ROOT
# in case
# 1–3 nummod
# % nmod
# of case
# men nmod
# aged amod
# 65 nmod:npmod
# or cc
# more conj
# , punct
# the det
# mortality nsubj
# is cop
# 70–95 nummod
# % conj
# . punct
# History ROOT
# The det
# first amod
# historical amod
# records dobj
# about case
# AAA nmod
# are dep
# from case
# Ancient compound
# Rome nmod
# in case
# the det
# 2nd amod
# century compound
# AD nmod
# , punct
# when advmod
# Greek compound
# surgeon compound
# Antyllus nsubj
# tried advcl
# to mark
# treat xcomp
# the det
# AAA dobj
# with case
# proximal amod
# and cc
# distal conj
# ligature dobj
# , punct
# central amod
# incision conj
# and cc
# removal conj
# of case
# thrombotic amod
# material nmod
# from case
# the det
# aneurysm nmod
# . punct
# However advmod
# , punct
# attempts ROOT
# to mark
# treat xcomp
# the det
# AAA dobj
# surgically advmod
# were cop
# unsuccessful xcomp
# until case
# 1923 nmod
# . punct
# In case
# that det
# year nmod
# , punct
# Rudolph compound
# Matas nsubj
# ( punct
# who nsubj
# also advmod
# proposed acl:relcl
# the det
# concept dobj
# of case
# endoaneurysmorrhaphy nmod
# ) punct
# , punct
# performed ROOT
# the det
# first amod
# successful amod
# aortic amod
# ligation dobj
# on case
# a det
# human nmod
# . punct
# Other amod
# methods nsubj
# that nsubj
# were cop
# successful acl:relcl
# in mark
# treating advcl
# the det
# AAA dobj
# included ROOT
# wrapping xcomp
# the det
# aorta dobj
# with case
# polyethene compound
# cellophane nmod
# , punct
# which nsubj
# induced acl:relcl
# fibrosis dobj
# and cc
# restricted conj
# the det
# growth dobj
# of case
# the det
# aneurysm nmod
# . punct
# Endovascular amod
# aneurysm compound
# repair nsubjpass
# was auxpass
# first advmod
# performed ROOT
# in case
# the det
# late amod
# 1980s nmod
# and cc
# has aux
# been auxpass
# widely advmod
# adopted conj
# in case
# the det
# subsequent amod
# decades nmod
# . punct
# Endovascular compound
# repair nsubjpass
# was auxpass
# first advmod
# used ROOT
# for mark
# treating advcl
# a det
# ruptured amod
# aneurysm dobj
# in case
# Nottingham nmod
# in case
# 1994 nmod
# . punct
# Society compound
# and cc
# culture conj
# Theoretical amod
# physicist compound
# Albert compound
# Einstein nsubjpass
# was auxpass
# operated ROOT
# on compound:prt
# for case
# an det
# abdominal amod
# aortic amod
# aneurysm nmod
# in case
# 1949 nmod
# by case
# Rudolph compound
# Nissen nmod
# , punct
# who nsubj
# wrapped acl:relcl
# the det
# aorta dobj
# with case
# polyethene compound
# cellophane nmod
# . punct
# Einstein nmod:poss
# 's case
# aneurysm nsubj
# ruptured ROOT
# on case
# April nmod
# 13 nummod
# , punct
# 1955 nummod
# . punct
# He nsubj
# declined ROOT
# surgery dobj
# , punct
# saying advcl
# , punct
# " punct
# " punct
# I nsubj
# want conj
# to mark
# go xcomp
# when advmod
# I nsubj
# want advcl
# . punct
# It nsubj
# is cop
# tasteless ROOT
# to mark
# prolong xcomp
# life dobj
# artificially advmod
# . punct
# I nsubj
# have aux
# done ROOT
# my nmod:poss
# share dobj
# , punct
# it nsubj
# is cop
# time conj
# to mark
# go acl:relcl
# . punct
# I nsubj
# will aux
# do ROOT
# it dobj
# elegantly advmod
# . punct
# " punct
# " punct
# He nsubj
# died dep
# five nummod
# days nmod:npmod
# later advmod
# at mark
# age compound
# 76.Actress compound
# Lucille compound
# Ball nsubj
# died advcl
# April nmod:tmod
# 26 nummod
# , punct
# 1989 nummod
# from case
# an det
# abdominal amod
# aortic amod
# aneurysm nmod
# . punct
# At case
# the det
# time nmod
# of case
# her nmod:poss
# death nmod
# , punct
# she nsubj
# was auxpass
# in case
# Cedars-Sinai amod
# Medical compound
# Center compound
# recovering nmod
# from case
# emergency compound
# surgery nmod
# performed ROOT
# just advmod
# six nummod
# days nmod:npmod
# earlier advmod
# because case
# of pcomp
# a det
# dissecting amod
# aortic amod
# aneurysm nmod
# near case
# her nmod:poss
# heart nmod
# . punct
# Ball nsubj
# was cop
# at case
# increased amod
# risk ROOT
# , punct
# as mark
# she nsubj
# had aux
# been cop
# a det
# heavy amod
# smoker advcl
# for case
# decades nmod
# . punct
# Musician compound
# Conway compound
# Twitty nsubj
# died ROOT
# in case
# June nmod
# 1993 nummod
# from case
# an det
# abdominal amod
# aortic amod
# aneurysm nmod
# , punct
# aged acl
# 59 dobj
# , punct
# two nummod
# months nmod
# before case
# the det
# release nmod
# of mark
# what nsubj
# would aux
# be cop
# his nmod:poss
# final amod
# studio compound
# album nmod
# , punct
# Final compound
# Touches conj
# . punct
# Actor compound
# George compound
# C. compound
# Scott nsubj
# died ccomp
# in case
# 1999 nmod
# from case
# a det
# ruptured amod
# abdominal amod
# aortic amod
# aneurysm nmod
# at case
# age compound
# 71.In compound
# 2001 nummod
# former amod
# presidential amod
# candidate compound
# Bob compound
# Dole nsubj
# underwent conj
# surgery dobj
# for case
# an det
# abdominal amod
# aortic amod
# aneurysm nmod
# in case
# which nmod
# a det
# team nsubj
# led acl
# by case
# vascular amod
# surgeon nmod
# Kenneth compound
# Ouriel appos
# inserted acl:relcl
# a det
# stent amod
# graft dobj
# : punct
# Ouriel nsubj
# said ROOT
# that mark
# the det
# team nsubj
# inserted ccomp
# a det
# Y-shaped amod
# tube dobj
# through case
# an det
# incision nmod
# in case
# Dole nmod:poss
# 's case
# leg nmod
# and cc
# placed conj
# it dobj
# inside case
# the det
# weakened amod
# portion nmod
# of case
# the det
# aorta nmod
# . punct
# The det
# aneurysm nsubj
# will aux
# eventually advmod
# contract ROOT
# around case
# the det
# stent nmod
# , punct
# which nsubj
# will aux
# remain acl:relcl
# in case
# place nmod
# for case
# the det
# rest nmod
# of case
# Dole nmod:poss
# 's case
# life nmod
# . punct
# — amod
# Associated compound
# Press compound
# Actor compound
# Robert compound
# Jacks ROOT
# , punct
# who nsubj
# played acl:relcl
